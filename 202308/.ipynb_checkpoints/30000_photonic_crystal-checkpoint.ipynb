# %%
##########################################################複製區塊
import matplotlib.pyplot as plt
import time
from scipy import signal
from time import sleep
import sys
import meep as mp
import numpy as np
import random
import multiprocessing as multi
#setup some constants and parameters
M=2**21
tsim=14e-12
eps0 = 8.854187e-12
hbar = 1.05457182e-34
c = 2.99792458e8
kb = 1.380649e-23
hdk=7.63823258e-12
deltap = np.sqrt(1/3/eps0/hbar/c)*kb
T=30000
frq_min = 0
frq_max = 100/2/np.pi
nfreq = 1000
fcen = (frq_min + frq_max)/2
df = frq_max - frq_min
#define square root of Dn function
def Dnsqt(wla,T):
    return np.sqrt(6*hdk**2*wla/(np.exp(hdk*wla/T)-1)/T**2/np.pi)

#generate an array of the square root of Dn function
Dsqt = []
for n in range(1,M):
    Dsqt.append(Dnsqt(2*np.pi*n/tsim,T))

#define how many times to run to average the results
Ncomp= 5
nfreq =  1000
#define the starting sum of the result
Efsum = np.zeros(nfreq)
Ens = np.zeros(2*22)
resolution = 1000
dA = 0.5
dB = 0.02
dpml = 1.0
sz = dpml*2+dA*2+dB
cell = mp.Vector3(0, 0, sz)
pml_layers = [mp.PML(dpml)]



for i in range(Ncomp):
    
    def random_En(t):
        #generate random numbers
        M0 = np.random.normal(0,1)
        Mlp = np.random.normal(0,1,M-1)
        Nlp = np.random.normal(0,1,M-1)
        MM = np.random.normal(0,1)
    
        #generate the array of the fourier transform of E field, we generate l=0 and l=-M separately. 
        #for l=1 to M-1 and l=-1 to -(M-1) are conjutated to each other. 
        #we contruct the whole array by gluing them together by the order from l=0 -> l=M-1 -> l=-M -> l=-(m-1) -> l=-1
        Ef0 = np.array([M0*np.sqrt(6*hdk/np.pi/T)])
        Eflp = np.multiply((Mlp + 1j*Nlp), Dsqt)
        Eflm = np.flip(np.conjugate(Eflp))
        EfM = np.array([MM*Dnsqt(2*np.pi*M/tsim,T)])
        Ef = np.hstack((Ef0,Eflp,EfM,Eflm))
    
        #we normalize Ef and compute its inverse fast fourier transform
        Efn = deltap*T/np.sqrt(tsim)*Ef
        En = np.fft.ifft(Efn)*M
        return En
    En0 = random_En(1)
    En1 = random_En(1)
    En2 = random_En(1)
    En3 = random_En(1)
    En4 = random_En(1)
    En5 = random_En(1)
    #generate some feedback to check the progress of the loop
    x = i/Ncomp*100
    sys.stdout.write('\r')
    sys.stdout.write("[%-20s] %d%%" % ('a'*int(x), int(x)))
    sys.stdout.flush()
    sleep(0.0001)
    
    
    def source0(t):
        f = int(t*2000)
        return En0[f]
    def source1(t):
        f = int(t*2000)
        return En1[f]
    def source2(t):
        f = int(t*2000)
        return En2[f]
    def source3(t):
        f = int(t*2000)
        return En3[f]
    def source4(t):
        f = int(t*2000)
        return En3[f]
    def source5(t):
        f = int(t*2000)
        return En3[f]


    sources = [mp.Source(mp.CustomSource(src_func=source0),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,-0.5*sz+dpml),
                     ),
              mp.Source(mp.CustomSource(src_func=source1),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,0.5*sz-dpml),
                     ),
              mp.Source(mp.CustomSource(src_func=source2),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,-0.5*sz-dpml+0.1),
                     ),
              mp.Source(mp.CustomSource(src_func=source3),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,0.5*sz-dpml-0.1),
                     ),
              mp.Source(mp.CustomSource(src_func=source4),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,-0.5*sz-dpml+0.2),
                     ),
              mp.Source(mp.CustomSource(src_func=source5),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,0.5*sz-dpml-0.2),
                     )]
    
    def BlockAB(N, center):
        geometry = []
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,0-dA/2-dB/2),
                     material=mp.Medium(epsilon=1)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dB),
                     center=mp.Vector3(0,0,0),
                     material=mp.Medium(epsilon=36)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,dB/2+dA/2),
                     material=mp.Medium(epsilon=1)))
        geometry = geometry.tolist()
        return geometry
    sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    sources=sources,   
                    dimensions = 1,
                    Courant = 1,
                    resolution=resolution,
                    geometry=BlockAB(1,0))
    
    

    # transmitted flux
    tran_fr = mp.FluxRegion(center=mp.Vector3(0,0,random.uniform(-0.01,0.01)))
    tran = sim.add_energy(fcen, df, nfreq, tran_fr)
    
    
    sim.run(until=2090)

    tran_flux = mp.get_magnetic_energy(tran)
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts,tran_flux[i])    
    Efsum += Ts
    
    

#average the final result
Efavg = Efsum/Ncomp/3

#save data to some file or reload file to write more data on it
# Out:
# [                    ] 0%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00161791 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00386381 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 21.085/2090.0 = 1.0% done in 4.0s, 392.5s to go
# on time step 21116 (time=21.116), 0.000189434 s/step
# Meep progress: 42.836/2090.0 = 2.0% done in 8.0s, 382.3s to go
# on time step 42871 (time=42.871), 0.00018387 s/step
# Meep progress: 64.042/2090.0 = 3.1% done in 12.0s, 379.6s to go
# on time step 64080 (time=64.08), 0.000188605 s/step
# Meep progress: 85.925/2090.0 = 4.1% done in 16.0s, 373.2s to go
# on time step 85965 (time=85.965), 0.000182777 s/step
# Meep progress: 107.772/2090.0 = 5.2% done in 20.0s, 367.9s to go
# on time step 107814 (time=107.814), 0.000183082 s/step
# Meep progress: 129.673/2090.0 = 6.2% done in 24.0s, 362.8s to go
# on time step 129717 (time=129.717), 0.000182627 s/step
# Meep progress: 150.315/2090.0 = 7.2% done in 28.0s, 361.3s to go
# on time step 150354 (time=150.354), 0.000193834 s/step
# Meep progress: 171.931/2090.0 = 8.2% done in 32.0s, 357.0s to go
# on time step 171981 (time=171.981), 0.000184958 s/step
# Meep progress: 193.808/2090.0 = 9.3% done in 36.0s, 352.2s to go
# on time step 193863 (time=193.863), 0.000182799 s/step
# Meep progress: 215.303/2090.0 = 10.3% done in 40.0s, 348.3s to go
# on time step 215364 (time=215.364), 0.000186038 s/step
# Meep progress: 236.721/2090.0 = 11.3% done in 44.0s, 344.5s to go
# on time step 236788 (time=236.788), 0.000186712 s/step
# Meep progress: 258.70300000000003/2090.0 = 12.4% done in 48.0s, 339.8s to go
# on time step 258776 (time=258.776), 0.000181918 s/step
# Meep progress: 280.653/2090.0 = 13.4% done in 52.0s, 335.2s to go
# on time step 280732 (time=280.732), 0.000182186 s/step
# Meep progress: 302.701/2090.0 = 14.5% done in 56.0s, 330.7s to go
# on time step 302788 (time=302.788), 0.000181361 s/step
# Meep progress: 324.296/2090.0 = 15.5% done in 60.0s, 326.7s to go
# on time step 324385 (time=324.385), 0.000185211 s/step
# Meep progress: 345.932/2090.0 = 16.6% done in 64.0s, 322.7s to go
# on time step 346025 (time=346.025), 0.000184844 s/step
# Meep progress: 367.806/2090.0 = 17.6% done in 68.0s, 318.4s to go
# on time step 367904 (time=367.904), 0.000182825 s/step
# Meep progress: 389.668/2090.0 = 18.6% done in 72.0s, 314.2s to go
# on time step 389777 (time=389.777), 0.000182877 s/step
# Meep progress: 411.206/2090.0 = 19.7% done in 76.0s, 310.3s to go
# on time step 411321 (time=411.321), 0.000185668 s/step
# Meep progress: 433.039/2090.0 = 20.7% done in 80.0s, 306.1s to go
# on time step 433163 (time=433.163), 0.000183135 s/step
# Meep progress: 454.873/2090.0 = 21.8% done in 84.0s, 302.0s to go
# on time step 455004 (time=455.004), 0.000183149 s/step
# Meep progress: 476.8/2090.0 = 22.8% done in 88.0s, 297.7s to go
# on time step 476937 (time=476.937), 0.000182375 s/step
# Meep progress: 498.671/2090.0 = 23.9% done in 92.0s, 293.6s to go
# on time step 498817 (time=498.817), 0.000182821 s/step
# Meep progress: 520.519/2090.0 = 24.9% done in 96.0s, 289.5s to go
# on time step 520667 (time=520.667), 0.000183073 s/step
# Meep progress: 542.464/2090.0 = 26.0% done in 100.0s, 285.3s to go
# on time step 542613 (time=542.613), 0.000182268 s/step
# Meep progress: 564.405/2090.0 = 27.0% done in 104.0s, 281.1s to go
# on time step 564562 (time=564.562), 0.000182244 s/step
# Meep progress: 586.316/2090.0 = 28.1% done in 108.0s, 277.0s to go
# on time step 586478 (time=586.478), 0.000182523 s/step
# Meep progress: 608.229/2090.0 = 29.1% done in 112.0s, 272.9s to go
# on time step 608396 (time=608.396), 0.000182499 s/step
# Meep progress: 629.99/2090.0 = 30.1% done in 116.0s, 268.8s to go
# on time step 630164 (time=630.164), 0.00018376 s/step
# Meep progress: 651.6270000000001/2090.0 = 31.2% done in 120.0s, 264.9s to go
# on time step 651808 (time=651.808), 0.00018481 s/step
# Meep progress: 673.4110000000001/2090.0 = 32.2% done in 124.0s, 260.9s to go
# on time step 673596 (time=673.596), 0.000183588 s/step
# Meep progress: 695.174/2090.0 = 33.3% done in 128.0s, 256.8s to go
# on time step 695363 (time=695.363), 0.00018377 s/step
# Meep progress: 716.518/2090.0 = 34.3% done in 132.0s, 253.0s to go
# on time step 716713 (time=716.713), 0.000187357 s/step
# Meep progress: 737.658/2090.0 = 35.3% done in 136.0s, 249.3s to go
# on time step 737847 (time=737.847), 0.000189269 s/step
# Meep progress: 758.787/2090.0 = 36.3% done in 140.0s, 245.6s to go
# on time step 758995 (time=758.995), 0.000189148 s/step
# Meep progress: 780.476/2090.0 = 37.3% done in 144.0s, 241.6s to go
# on time step 780690 (time=780.69), 0.000184382 s/step
# Meep progress: 802.264/2090.0 = 38.4% done in 148.0s, 237.6s to go
# on time step 802482 (time=802.482), 0.000183557 s/step
# Meep progress: 823.402/2090.0 = 39.4% done in 152.0s, 233.8s to go
# on time step 823629 (time=823.629), 0.000189154 s/step
# Meep progress: 845.174/2090.0 = 40.4% done in 156.0s, 229.8s to go
# on time step 845399 (time=845.399), 0.000183743 s/step
# Meep progress: 866.687/2090.0 = 41.5% done in 160.0s, 225.8s to go
# on time step 866918 (time=866.918), 0.000185886 s/step
# Meep progress: 888.203/2090.0 = 42.5% done in 164.0s, 221.9s to go
# on time step 888442 (time=888.442), 0.000185841 s/step
# Meep progress: 909.958/2090.0 = 43.5% done in 168.0s, 217.9s to go
# on time step 910206 (time=910.206), 0.000183793 s/step
# Meep progress: 931.658/2090.0 = 44.6% done in 172.0s, 213.9s to go
# on time step 931903 (time=931.903), 0.000184362 s/step
# Meep progress: 953.363/2090.0 = 45.6% done in 176.0s, 209.8s to go
# on time step 953612 (time=953.612), 0.000184256 s/step
# Meep progress: 974.2280000000001/2090.0 = 46.6% done in 180.0s, 206.2s to go
# on time step 974465 (time=974.465), 0.000191821 s/step
# Meep progress: 995.9970000000001/2090.0 = 47.7% done in 184.0s, 202.1s to go
# on time step 996255 (time=996.255), 0.000183576 s/step
# Meep progress: 1017.056/2090.0 = 48.7% done in 188.0s, 198.3s to go
# on time step 1017310 (time=1017.31), 0.00018998 s/step
# Meep progress: 1038.64/2090.0 = 49.7% done in 192.0s, 194.4s to go
# on time step 1038904 (time=1038.9), 0.000185241 s/step
# Meep progress: 1060.222/2090.0 = 50.7% done in 196.0s, 190.4s to go
# on time step 1060490 (time=1060.49), 0.000185306 s/step
# Meep progress: 1081.718/2090.0 = 51.8% done in 200.0s, 186.4s to go
# on time step 1081977 (time=1081.98), 0.000186166 s/step
# Meep progress: 1103.22/2090.0 = 52.8% done in 204.0s, 182.5s to go
# on time step 1103491 (time=1103.49), 0.000185934 s/step
# Meep progress: 1123.681/2090.0 = 53.8% done in 208.0s, 178.9s to go
# on time step 1123916 (time=1123.92), 0.000195846 s/step
# Meep progress: 1142.664/2090.0 = 54.7% done in 212.0s, 175.8s to go
# on time step 1142898 (time=1142.9), 0.000210735 s/step
# Meep progress: 1164.0620000000001/2090.0 = 55.7% done in 216.0s, 171.8s to go
# on time step 1164343 (time=1164.34), 0.000186524 s/step
# Meep progress: 1185.611/2090.0 = 56.7% done in 220.0s, 167.8s to go
# on time step 1185884 (time=1185.88), 0.000185694 s/step
# Meep progress: 1207.336/2090.0 = 57.8% done in 224.0s, 163.8s to go
# on time step 1207623 (time=1207.62), 0.000184009 s/step
# Meep progress: 1228.998/2090.0 = 58.8% done in 228.0s, 159.7s to go
# on time step 1229290 (time=1229.29), 0.000184613 s/step
# Meep progress: 1250.3410000000001/2090.0 = 59.8% done in 232.0s, 155.8s to go
# on time step 1250600 (time=1250.6), 0.000187709 s/step
# Meep progress: 1271.595/2090.0 = 60.8% done in 236.0s, 151.9s to go
# on time step 1271890 (time=1271.89), 0.000187883 s/step
# Meep progress: 1293.333/2090.0 = 61.9% done in 240.0s, 147.8s to go
# on time step 1293635 (time=1293.63), 0.000183955 s/step
# Meep progress: 1314.977/2090.0 = 62.9% done in 244.0s, 143.8s to go
# on time step 1315281 (time=1315.28), 0.000184792 s/step
# Meep progress: 1336.8020000000001/2090.0 = 64.0% done in 248.0s, 139.7s to go
# on time step 1337110 (time=1337.11), 0.000183243 s/step
# Meep progress: 1358.616/2090.0 = 65.0% done in 252.0s, 135.7s to go
# on time step 1358918 (time=1358.92), 0.000183427 s/step
# Meep progress: 1380.439/2090.0 = 66.0% done in 256.0s, 131.6s to go
# on time step 1380754 (time=1380.75), 0.00018319 s/step
# Meep progress: 1401.171/2090.0 = 67.0% done in 260.0s, 127.8s to go
# on time step 1401453 (time=1401.45), 0.000193257 s/step
# Meep progress: 1420.395/2090.0 = 68.0% done in 264.0s, 124.5s to go
# on time step 1420629 (time=1420.63), 0.000208602 s/step
# Meep progress: 1439.74/2090.0 = 68.9% done in 268.0s, 121.0s to go
# on time step 1440020 (time=1440.02), 0.000206284 s/step
# Meep progress: 1460.362/2090.0 = 69.9% done in 272.0s, 117.3s to go
# on time step 1460626 (time=1460.63), 0.000194123 s/step
# Meep progress: 1480.981/2090.0 = 70.9% done in 276.0s, 113.5s to go
# on time step 1481299 (time=1481.3), 0.000193493 s/step
# Meep progress: 1502.702/2090.0 = 71.9% done in 280.0s, 109.4s to go
# on time step 1503030 (time=1503.03), 0.000184072 s/step
# Meep progress: 1524.5230000000001/2090.0 = 72.9% done in 284.0s, 105.3s to go
# on time step 1524850 (time=1524.85), 0.000183326 s/step
# Meep progress: 1546.308/2090.0 = 74.0% done in 288.0s, 101.3s to go
# on time step 1546642 (time=1546.64), 0.000183558 s/step
# Meep progress: 1567.852/2090.0 = 75.0% done in 292.0s, 97.2s to go
# on time step 1568178 (time=1568.18), 0.000185745 s/step
# Meep progress: 1589.3210000000001/2090.0 = 76.0% done in 296.0s, 93.3s to go
# on time step 1589667 (time=1589.67), 0.000186144 s/step
# Meep progress: 1610.95/2090.0 = 77.1% done in 300.0s, 89.2s to go
# on time step 1611302 (time=1611.3), 0.000184892 s/step
# Meep progress: 1632.175/2090.0 = 78.1% done in 304.0s, 85.3s to go
# on time step 1632514 (time=1632.51), 0.000188573 s/step
# Meep progress: 1653.901/2090.0 = 79.1% done in 308.0s, 81.2s to go
# on time step 1654261 (time=1654.26), 0.000183938 s/step
# Meep progress: 1674.162/2090.0 = 80.1% done in 312.0s, 77.5s to go
# on time step 1674493 (time=1674.49), 0.000197714 s/step
# Meep progress: 1693.738/2090.0 = 81.0% done in 316.0s, 73.9s to go
# on time step 1694098 (time=1694.1), 0.000204037 s/step
# Meep progress: 1715.4850000000001/2090.0 = 82.1% done in 320.0s, 69.9s to go
# on time step 1715843 (time=1715.84), 0.000183958 s/step
# Meep progress: 1737.1390000000001/2090.0 = 83.1% done in 324.0s, 65.8s to go
# on time step 1737511 (time=1737.51), 0.000184612 s/step
# Meep progress: 1756.2740000000001/2090.0 = 84.0% done in 328.0s, 62.3s to go
# on time step 1756549 (time=1756.55), 0.00021011 s/step
# Meep progress: 1774.737/2090.0 = 84.9% done in 332.0s, 59.0s to go
# on time step 1775065 (time=1775.07), 0.000216032 s/step
# Meep progress: 1794.973/2090.0 = 85.9% done in 336.0s, 55.2s to go
# on time step 1795353 (time=1795.35), 0.000197168 s/step
# Meep progress: 1816.656/2090.0 = 86.9% done in 340.0s, 51.2s to go
# on time step 1817041 (time=1817.04), 0.000184438 s/step
# Meep progress: 1836.056/2090.0 = 87.8% done in 344.0s, 47.6s to go
# on time step 1836396 (time=1836.4), 0.000206666 s/step
# Meep progress: 1855.352/2090.0 = 88.8% done in 348.0s, 44.0s to go
# on time step 1855744 (time=1855.74), 0.000206742 s/step
# Meep progress: 1875.4370000000001/2090.0 = 89.7% done in 352.0s, 40.3s to go
# on time step 1875775 (time=1875.78), 0.000199694 s/step
# Meep progress: 1894.762/2090.0 = 90.7% done in 356.0s, 36.7s to go
# on time step 1895163 (time=1895.16), 0.000206317 s/step
# Meep progress: 1916.1190000000001/2090.0 = 91.7% done in 360.0s, 32.7s to go
# on time step 1916515 (time=1916.52), 0.000187337 s/step
# Meep progress: 1937.814/2090.0 = 92.7% done in 364.0s, 28.6s to go
# on time step 1938219 (time=1938.22), 0.000184298 s/step
# Meep progress: 1959.406/2090.0 = 93.8% done in 368.0s, 24.5s to go
# on time step 1959809 (time=1959.81), 0.000185279 s/step
# Meep progress: 1981.106/2090.0 = 94.8% done in 372.0s, 20.4s to go
# on time step 1981518 (time=1981.52), 0.00018426 s/step
# Meep progress: 2002.875/2090.0 = 95.8% done in 376.0s, 16.4s to go
# on time step 2003284 (time=2003.28), 0.000183781 s/step
# Meep progress: 2024.646/2090.0 = 96.9% done in 380.0s, 12.3s to go
# on time step 2025066 (time=2025.07), 0.00018364 s/step
# Meep progress: 2046.3310000000001/2090.0 = 97.9% done in 384.0s, 8.2s to go
# on time step 2046748 (time=2046.75), 0.000184492 s/step
# Meep progress: 2067.953/2090.0 = 98.9% done in 388.0s, 4.1s to go
# on time step 2068371 (time=2068.37), 0.000184996 s/step
# Meep progress: 2089.422/2090.0 = 100.0% done in 392.0s, 0.1s to go
# on time step 2089846 (time=2089.85), 0.000186268 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 33%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000549078 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00327921 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 21.703/2090.0 = 1.0% done in 4.0s, 381.2s to go
# on time step 21712 (time=21.712), 0.000184235 s/step
# Meep progress: 43.866/2090.0 = 2.1% done in 8.0s, 373.2s to go
# on time step 43879 (time=43.879), 0.000180454 s/step
# Meep progress: 66.184/2090.0 = 3.2% done in 12.0s, 366.9s to go
# on time step 66200 (time=66.2), 0.000179206 s/step
# Meep progress: 88.447/2090.0 = 4.2% done in 16.0s, 362.1s to go
# on time step 88465 (time=88.465), 0.000179656 s/step
# Meep progress: 110.342/2090.0 = 5.3% done in 20.0s, 358.8s to go
# on time step 110360 (time=110.36), 0.000182691 s/step
# Meep progress: 132.022/2090.0 = 6.3% done in 24.0s, 355.9s to go
# on time step 132042 (time=132.042), 0.000184485 s/step
# Meep progress: 153.264/2090.0 = 7.3% done in 28.0s, 353.8s to go
# on time step 153286 (time=153.286), 0.000188289 s/step
# Meep progress: 174.683/2090.0 = 8.4% done in 32.0s, 350.9s to go
# on time step 174706 (time=174.706), 0.000186743 s/step
# Meep progress: 196.442/2090.0 = 9.4% done in 36.0s, 347.0s to go
# on time step 196468 (time=196.468), 0.000183811 s/step
# Meep progress: 218.272/2090.0 = 10.4% done in 40.0s, 343.0s to go
# on time step 218300 (time=218.3), 0.000183223 s/step
# Meep progress: 238.695/2090.0 = 11.4% done in 44.0s, 341.3s to go
# on time step 238721 (time=238.721), 0.00019588 s/step
# Meep progress: 258.692/2090.0 = 12.4% done in 48.0s, 339.8s to go
# on time step 258726 (time=258.726), 0.000199954 s/step
# Meep progress: 280.36400000000003/2090.0 = 13.4% done in 52.0s, 335.6s to go
# on time step 280398 (time=280.398), 0.000184578 s/step
# Meep progress: 301.909/2090.0 = 14.4% done in 56.0s, 331.7s to go
# on time step 301946 (time=301.946), 0.000185632 s/step
# Meep progress: 323.632/2090.0 = 15.5% done in 60.0s, 327.5s to go
# on time step 323672 (time=323.672), 0.000184113 s/step
# Meep progress: 345.556/2090.0 = 16.5% done in 64.0s, 323.1s to go
# on time step 345600 (time=345.6), 0.000182423 s/step
# Meep progress: 367.539/2090.0 = 17.6% done in 68.0s, 318.7s to go
# on time step 367587 (time=367.587), 0.000181928 s/step
# Meep progress: 387.911/2090.0 = 18.6% done in 72.0s, 315.9s to go
# on time step 387957 (time=387.957), 0.000196368 s/step
# Meep progress: 408.289/2090.0 = 19.5% done in 76.0s, 313.0s to go
# on time step 408338 (time=408.338), 0.000196269 s/step
# Meep progress: 428.798/2090.0 = 20.5% done in 80.0s, 309.9s to go
# on time step 428847 (time=428.847), 0.000195043 s/step
# Meep progress: 449.095/2090.0 = 21.5% done in 84.0s, 306.9s to go
# on time step 449148 (time=449.148), 0.000197039 s/step
# Meep progress: 469.294/2090.0 = 22.5% done in 88.0s, 303.9s to go
# on time step 469346 (time=469.346), 0.000198047 s/step
# Meep progress: 490.992/2090.0 = 23.5% done in 92.0s, 299.6s to go
# on time step 491055 (time=491.055), 0.000184263 s/step
# Meep progress: 512.8770000000001/2090.0 = 24.5% done in 96.0s, 295.2s to go
# on time step 512941 (time=512.941), 0.000182767 s/step
# Meep progress: 534.848/2090.0 = 25.6% done in 100.0s, 290.8s to go
# on time step 534915 (time=534.915), 0.000182038 s/step
# Meep progress: 556.819/2090.0 = 26.6% done in 104.0s, 286.4s to go
# on time step 556888 (time=556.888), 0.000182047 s/step
# Meep progress: 578.821/2090.0 = 27.7% done in 108.0s, 282.0s to go
# on time step 578892 (time=578.892), 0.000181788 s/step
# Meep progress: 600.811/2090.0 = 28.7% done in 112.0s, 277.6s to go
# on time step 600885 (time=600.885), 0.000181881 s/step
# Meep progress: 622.795/2090.0 = 29.8% done in 116.0s, 273.3s to go
# on time step 622869 (time=622.869), 0.000181951 s/step
# Meep progress: 644.813/2090.0 = 30.9% done in 120.0s, 269.0s to go
# on time step 644890 (time=644.89), 0.000181645 s/step
# Meep progress: 664.849/2090.0 = 31.8% done in 124.0s, 265.8s to go
# on time step 664922 (time=664.922), 0.000199682 s/step
# Meep progress: 686.586/2090.0 = 32.9% done in 128.0s, 261.6s to go
# on time step 686667 (time=686.667), 0.000183951 s/step
# Meep progress: 708.624/2090.0 = 33.9% done in 132.0s, 257.3s to go
# on time step 708709 (time=708.709), 0.000181477 s/step
# Meep progress: 730.625/2090.0 = 35.0% done in 136.0s, 253.0s to go
# on time step 730714 (time=730.714), 0.000181777 s/step
# Meep progress: 752.6460000000001/2090.0 = 36.0% done in 140.0s, 248.8s to go
# on time step 752738 (time=752.738), 0.000181621 s/step
# Meep progress: 774.607/2090.0 = 37.1% done in 144.0s, 244.5s to go
# on time step 774701 (time=774.701), 0.000182129 s/step
# Meep progress: 796.558/2090.0 = 38.1% done in 148.0s, 240.3s to go
# on time step 796653 (time=796.653), 0.000182218 s/step
# Meep progress: 818.548/2090.0 = 39.2% done in 152.0s, 236.1s to go
# on time step 818646 (time=818.646), 0.000181879 s/step
# Meep progress: 840.1460000000001/2090.0 = 40.2% done in 156.0s, 232.1s to go
# on time step 840239 (time=840.239), 0.000185253 s/step
# Meep progress: 862.0790000000001/2090.0 = 41.2% done in 160.0s, 227.9s to go
# on time step 862183 (time=862.183), 0.000182288 s/step
# Meep progress: 884.1270000000001/2090.0 = 42.3% done in 164.0s, 223.7s to go
# on time step 884233 (time=884.233), 0.000181406 s/step
# Meep progress: 906.046/2090.0 = 43.4% done in 168.0s, 219.5s to go
# on time step 906155 (time=906.155), 0.000182468 s/step
# Meep progress: 928.0310000000001/2090.0 = 44.4% done in 172.0s, 215.4s to go
# on time step 928143 (time=928.143), 0.000181923 s/step
# Meep progress: 949.993/2090.0 = 45.5% done in 176.0s, 211.2s to go
# on time step 950107 (time=950.107), 0.000182124 s/step
# Meep progress: 972.004/2090.0 = 46.5% done in 180.0s, 207.0s to go
# on time step 972121 (time=972.121), 0.00018171 s/step
# Meep progress: 993.987/2090.0 = 47.6% done in 184.0s, 202.9s to go
# on time step 994102 (time=994.102), 0.000181976 s/step
# Meep progress: 1015.952/2090.0 = 48.6% done in 188.0s, 198.8s to go
# on time step 1016074 (time=1016.07), 0.000182055 s/step
# Meep progress: 1037.958/2090.0 = 49.7% done in 192.0s, 194.6s to go
# on time step 1038080 (time=1038.08), 0.000181769 s/step
# Meep progress: 1059.97/2090.0 = 50.7% done in 196.0s, 190.5s to go
# on time step 1060096 (time=1060.1), 0.000181688 s/step
# Meep progress: 1081.992/2090.0 = 51.8% done in 200.0s, 186.3s to go
# on time step 1082119 (time=1082.12), 0.000181628 s/step
# Meep progress: 1104.0/2090.0 = 52.8% done in 204.0s, 182.2s to go
# on time step 1104130 (time=1104.13), 0.000181734 s/step
# Meep progress: 1125.964/2090.0 = 53.9% done in 208.0s, 178.1s to go
# on time step 1126096 (time=1126.1), 0.000182104 s/step
# Meep progress: 1147.6200000000001/2090.0 = 54.9% done in 212.0s, 174.1s to go
# on time step 1147740 (time=1147.74), 0.000184817 s/step
# Meep progress: 1167.179/2090.0 = 55.8% done in 216.0s, 170.8s to go
# on time step 1167301 (time=1167.3), 0.000204489 s/step
# Meep progress: 1184.845/2090.0 = 56.7% done in 220.0s, 168.1s to go
# on time step 1184962 (time=1184.96), 0.000226489 s/step
# Meep progress: 1205.111/2090.0 = 57.7% done in 224.0s, 164.5s to go
# on time step 1205251 (time=1205.25), 0.000197158 s/step
# Meep progress: 1226.815/2090.0 = 58.7% done in 228.0s, 160.4s to go
# on time step 1226958 (time=1226.96), 0.000184276 s/step
# Meep progress: 1248.482/2090.0 = 59.7% done in 232.0s, 156.4s to go
# on time step 1248619 (time=1248.62), 0.000184667 s/step
# Meep progress: 1270.178/2090.0 = 60.8% done in 236.0s, 152.3s to go
# on time step 1270323 (time=1270.32), 0.000184299 s/step
# Meep progress: 1290.715/2090.0 = 61.8% done in 240.0s, 148.6s to go
# on time step 1290866 (time=1290.87), 0.000194716 s/step
# Meep progress: 1311.957/2090.0 = 62.8% done in 244.0s, 144.7s to go
# on time step 1312111 (time=1312.11), 0.000188287 s/step
# Meep progress: 1333.392/2090.0 = 63.8% done in 248.0s, 140.7s to go
# on time step 1333543 (time=1333.54), 0.000186637 s/step
# Meep progress: 1355.152/2090.0 = 64.8% done in 252.0s, 136.7s to go
# on time step 1355309 (time=1355.31), 0.000183776 s/step
# Meep progress: 1376.8410000000001/2090.0 = 65.9% done in 256.0s, 132.6s to go
# on time step 1377003 (time=1377), 0.000184388 s/step
# Meep progress: 1398.555/2090.0 = 66.9% done in 260.0s, 128.5s to go
# on time step 1398719 (time=1398.72), 0.000184198 s/step
# Meep progress: 1420.006/2090.0 = 67.9% done in 264.0s, 124.6s to go
# on time step 1420171 (time=1420.17), 0.000186471 s/step
# Meep progress: 1441.612/2090.0 = 69.0% done in 268.0s, 120.5s to go
# on time step 1441777 (time=1441.78), 0.000185136 s/step
# Meep progress: 1461.785/2090.0 = 69.9% done in 272.0s, 116.9s to go
# on time step 1461924 (time=1461.92), 0.000198547 s/step
# Meep progress: 1482.8690000000001/2090.0 = 71.0% done in 276.0s, 113.0s to go
# on time step 1483045 (time=1483.05), 0.000189389 s/step
# Meep progress: 1501.968/2090.0 = 71.9% done in 280.0s, 109.6s to go
# on time step 1502125 (time=1502.12), 0.000209652 s/step
# Meep progress: 1520.155/2090.0 = 72.7% done in 284.0s, 106.5s to go
# on time step 1520299 (time=1520.3), 0.000220102 s/step
# Meep progress: 1540.986/2090.0 = 73.7% done in 288.0s, 102.6s to go
# on time step 1541166 (time=1541.17), 0.000191699 s/step
# Meep progress: 1562.332/2090.0 = 74.8% done in 292.0s, 98.6s to go
# on time step 1562520 (time=1562.52), 0.00018732 s/step
# Meep progress: 1583.609/2090.0 = 75.8% done in 296.0s, 94.7s to go
# on time step 1583803 (time=1583.8), 0.00018795 s/step
# Meep progress: 1605.229/2090.0 = 76.8% done in 300.0s, 90.6s to go
# on time step 1605424 (time=1605.42), 0.000185013 s/step
# Meep progress: 1626.5900000000001/2090.0 = 77.8% done in 304.0s, 86.6s to go
# on time step 1626781 (time=1626.78), 0.000187293 s/step
# Meep progress: 1645.164/2090.0 = 78.7% done in 308.0s, 83.3s to go
# on time step 1645323 (time=1645.32), 0.000215728 s/step
# Meep progress: 1662.796/2090.0 = 79.6% done in 312.0s, 80.2s to go
# on time step 1662972 (time=1662.97), 0.000226652 s/step
# Meep progress: 1681.113/2090.0 = 80.4% done in 316.0s, 76.9s to go
# on time step 1681312 (time=1681.31), 0.000218105 s/step
# Meep progress: 1701.794/2090.0 = 81.4% done in 320.0s, 73.0s to go
# on time step 1702003 (time=1702), 0.000193323 s/step
# Meep progress: 1723.47/2090.0 = 82.5% done in 324.0s, 68.9s to go
# on time step 1723684 (time=1723.68), 0.000184498 s/step
# Meep progress: 1745.068/2090.0 = 83.5% done in 328.0s, 64.8s to go
# on time step 1745276 (time=1745.28), 0.000185259 s/step
# Meep progress: 1766.587/2090.0 = 84.5% done in 332.0s, 60.8s to go
# on time step 1766798 (time=1766.8), 0.000185861 s/step
# Meep progress: 1787.957/2090.0 = 85.5% done in 336.0s, 56.8s to go
# on time step 1788162 (time=1788.16), 0.000187232 s/step
# Meep progress: 1808.608/2090.0 = 86.5% done in 340.0s, 52.9s to go
# on time step 1808830 (time=1808.83), 0.000193537 s/step
# Meep progress: 1830.095/2090.0 = 87.6% done in 344.0s, 48.9s to go
# on time step 1830312 (time=1830.31), 0.00018621 s/step
# Meep progress: 1849.776/2090.0 = 88.5% done in 348.0s, 45.2s to go
# on time step 1849954 (time=1849.95), 0.00020365 s/step
# Meep progress: 1870.726/2090.0 = 89.5% done in 352.0s, 41.3s to go
# on time step 1870952 (time=1870.95), 0.000190498 s/step
# Meep progress: 1892.304/2090.0 = 90.5% done in 356.0s, 37.2s to go
# on time step 1892528 (time=1892.53), 0.000185398 s/step
# Meep progress: 1913.6870000000001/2090.0 = 91.6% done in 360.0s, 33.2s to go
# on time step 1913913 (time=1913.91), 0.000187056 s/step
# Meep progress: 1935.018/2090.0 = 92.6% done in 364.0s, 29.2s to go
# on time step 1935257 (time=1935.26), 0.00018741 s/step
# Meep progress: 1955.404/2090.0 = 93.6% done in 368.0s, 25.3s to go
# on time step 1955598 (time=1955.6), 0.000196652 s/step
# Meep progress: 1973.88/2090.0 = 94.4% done in 372.0s, 21.9s to go
# on time step 1974077 (time=1974.08), 0.000216465 s/step
# Meep progress: 1991.921/2090.0 = 95.3% done in 376.0s, 18.5s to go
# on time step 1992108 (time=1992.11), 0.000221852 s/step
# Meep progress: 2012.689/2090.0 = 96.3% done in 380.0s, 14.6s to go
# on time step 2012936 (time=2012.94), 0.000192056 s/step
# Meep progress: 2034.016/2090.0 = 97.3% done in 384.0s, 10.6s to go
# on time step 2034271 (time=2034.27), 0.000187492 s/step
# Meep progress: 2055.656/2090.0 = 98.4% done in 388.0s, 6.5s to go
# on time step 2055898 (time=2055.9), 0.000184962 s/step
# Meep progress: 2075.608/2090.0 = 99.3% done in 392.0s, 2.7s to go
# on time step 2075816 (time=2075.82), 0.000200834 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 66%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000816107 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00335407 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 20.932000000000002/2090.0 = 1.0% done in 4.0s, 395.4s to go
# on time step 20941 (time=20.941), 0.000191013 s/step
# Meep progress: 42.396/2090.0 = 2.0% done in 8.0s, 386.4s to go
# on time step 42409 (time=42.409), 0.000186325 s/step
# Meep progress: 63.055/2090.0 = 3.0% done in 12.0s, 385.8s to go
# on time step 63069 (time=63.069), 0.000193618 s/step
# Meep progress: 84.635/2090.0 = 4.0% done in 16.0s, 379.1s to go
# on time step 84651 (time=84.651), 0.000185343 s/step
# Meep progress: 106.247/2090.0 = 5.1% done in 20.0s, 373.4s to go
# on time step 106264 (time=106.264), 0.000185082 s/step
# Meep progress: 127.843/2090.0 = 6.1% done in 24.0s, 368.4s to go
# on time step 127866 (time=127.866), 0.000185173 s/step
# Meep progress: 149.223/2090.0 = 7.1% done in 28.0s, 364.2s to go
# on time step 149247 (time=149.247), 0.000187087 s/step
# Meep progress: 170.601/2090.0 = 8.2% done in 32.0s, 360.0s to go
# on time step 170628 (time=170.628), 0.000187089 s/step
# Meep progress: 192.02700000000002/2090.0 = 9.2% done in 36.0s, 355.8s to go
# on time step 192057 (time=192.057), 0.000186665 s/step
# Meep progress: 213.553/2090.0 = 10.2% done in 40.0s, 351.5s to go
# on time step 213587 (time=213.587), 0.000185793 s/step
# Meep progress: 235.06900000000002/2090.0 = 11.2% done in 44.0s, 347.2s to go
# on time step 235106 (time=235.106), 0.000185883 s/step
# Meep progress: 256.232/2090.0 = 12.3% done in 48.0s, 343.5s to go
# on time step 256263 (time=256.263), 0.000189067 s/step
# Meep progress: 277.665/2090.0 = 13.3% done in 52.0s, 339.4s to go
# on time step 277713 (time=277.713), 0.000186485 s/step
# Meep progress: 298.895/2090.0 = 14.3% done in 56.0s, 335.6s to go
# on time step 298948 (time=298.948), 0.000188374 s/step
# Meep progress: 320.29900000000004/2090.0 = 15.3% done in 60.0s, 331.5s to go
# on time step 320355 (time=320.355), 0.000186867 s/step
# Meep progress: 341.361/2090.0 = 16.3% done in 64.0s, 327.9s to go
# on time step 341401 (time=341.401), 0.000190069 s/step
# Meep progress: 363.004/2090.0 = 17.4% done in 68.0s, 323.5s to go
# on time step 363067 (time=363.067), 0.000184627 s/step
# Meep progress: 383.636/2090.0 = 18.4% done in 72.0s, 320.3s to go
# on time step 383708 (time=383.708), 0.000193795 s/step
# Meep progress: 405.314/2090.0 = 19.4% done in 76.0s, 315.9s to go
# on time step 405394 (time=405.394), 0.000184451 s/step
# Meep progress: 426.809/2090.0 = 20.4% done in 80.0s, 311.8s to go
# on time step 426885 (time=426.885), 0.000186133 s/step
# Meep progress: 448.497/2090.0 = 21.5% done in 84.0s, 307.4s to go
# on time step 448585 (time=448.585), 0.000184334 s/step
# Meep progress: 470.14300000000003/2090.0 = 22.5% done in 88.0s, 303.2s to go
# on time step 470236 (time=470.236), 0.000184751 s/step
# Meep progress: 491.35900000000004/2090.0 = 23.5% done in 92.0s, 299.3s to go
# on time step 491451 (time=491.451), 0.000188553 s/step
# Meep progress: 512.571/2090.0 = 24.5% done in 96.0s, 295.4s to go
# on time step 512683 (time=512.683), 0.000188403 s/step
# Meep progress: 534.199/2090.0 = 25.6% done in 100.0s, 291.2s to go
# on time step 534315 (time=534.315), 0.000184922 s/step
# Meep progress: 555.8820000000001/2090.0 = 26.6% done in 104.0s, 287.0s to go
# on time step 556005 (time=556.005), 0.000184422 s/step
# Meep progress: 577.211/2090.0 = 27.6% done in 108.0s, 283.1s to go
# on time step 577337 (time=577.337), 0.000187512 s/step
# Meep progress: 598.684/2090.0 = 28.6% done in 112.0s, 279.0s to go
# on time step 598815 (time=598.815), 0.000186241 s/step
# Meep progress: 620.4060000000001/2090.0 = 29.7% done in 116.0s, 274.8s to go
# on time step 620541 (time=620.541), 0.000184119 s/step
# Meep progress: 641.806/2090.0 = 30.7% done in 120.0s, 270.8s to go
# on time step 641945 (time=641.945), 0.000186885 s/step
# Meep progress: 661.283/2090.0 = 31.6% done in 124.0s, 267.9s to go
# on time step 661400 (time=661.4), 0.000205605 s/step
# Meep progress: 682.639/2090.0 = 32.7% done in 128.0s, 263.9s to go
# on time step 682790 (time=682.79), 0.000187004 s/step
# Meep progress: 704.148/2090.0 = 33.7% done in 132.0s, 259.8s to go
# on time step 704294 (time=704.294), 0.000186016 s/step
# Meep progress: 725.588/2090.0 = 34.7% done in 136.0s, 255.7s to go
# on time step 725744 (time=725.744), 0.000186484 s/step
# Meep progress: 746.634/2090.0 = 35.7% done in 140.0s, 251.9s to go
# on time step 746790 (time=746.79), 0.000190064 s/step
# Meep progress: 768.3820000000001/2090.0 = 36.8% done in 144.0s, 247.7s to go
# on time step 768554 (time=768.554), 0.000183792 s/step
# Meep progress: 789.947/2090.0 = 37.8% done in 148.0s, 243.6s to go
# on time step 790122 (time=790.122), 0.000185462 s/step
# Meep progress: 810.481/2090.0 = 38.8% done in 152.0s, 240.0s to go
# on time step 810617 (time=810.617), 0.000195177 s/step
# Meep progress: 831.269/2090.0 = 39.8% done in 156.0s, 236.2s to go
# on time step 831458 (time=831.458), 0.000191935 s/step
# Meep progress: 852.548/2090.0 = 40.8% done in 160.0s, 232.2s to go
# on time step 852734 (time=852.734), 0.000188013 s/step
# Meep progress: 872.9250000000001/2090.0 = 41.8% done in 164.0s, 228.7s to go
# on time step 873121 (time=873.121), 0.000196206 s/step
# Meep progress: 892.755/2090.0 = 42.7% done in 168.0s, 225.3s to go
# on time step 892957 (time=892.957), 0.000201658 s/step
# Meep progress: 914.115/2090.0 = 43.7% done in 172.0s, 221.3s to go
# on time step 914321 (time=914.321), 0.000187238 s/step
# Meep progress: 935.221/2090.0 = 44.7% done in 176.0s, 217.3s to go
# on time step 935434 (time=935.434), 0.000189462 s/step
# Meep progress: 956.61/2090.0 = 45.8% done in 180.0s, 213.3s to go
# on time step 956817 (time=956.817), 0.000187065 s/step
# Meep progress: 978.052/2090.0 = 46.8% done in 184.0s, 209.2s to go
# on time step 978260 (time=978.26), 0.000186547 s/step
# Meep progress: 999.5740000000001/2090.0 = 47.8% done in 188.0s, 205.1s to go
# on time step 999772 (time=999.772), 0.000185946 s/step
# Meep progress: 1021.033/2090.0 = 48.9% done in 192.0s, 201.0s to go
# on time step 1021270 (time=1021.27), 0.000186069 s/step
# Meep progress: 1042.794/2090.0 = 49.9% done in 196.0s, 196.8s to go
# on time step 1043022 (time=1043.02), 0.000183894 s/step
# Meep progress: 1064.396/2090.0 = 50.9% done in 200.0s, 192.7s to go
# on time step 1064627 (time=1064.63), 0.000185145 s/step
# Meep progress: 1085.18/2090.0 = 51.9% done in 204.0s, 188.9s to go
# on time step 1085413 (time=1085.41), 0.000192441 s/step
# Meep progress: 1106.384/2090.0 = 52.9% done in 208.0s, 184.9s to go
# on time step 1106635 (time=1106.63), 0.000188487 s/step
# Meep progress: 1126.719/2090.0 = 53.9% done in 212.0s, 181.3s to go
# on time step 1126920 (time=1126.92), 0.000197201 s/step
# Meep progress: 1148.226/2090.0 = 54.9% done in 216.0s, 177.2s to go
# on time step 1148479 (time=1148.48), 0.000185545 s/step
# Meep progress: 1166.672/2090.0 = 55.8% done in 220.0s, 174.1s to go
# on time step 1166874 (time=1166.87), 0.000217453 s/step
# Meep progress: 1184.853/2090.0 = 56.7% done in 224.0s, 171.1s to go
# on time step 1185122 (time=1185.12), 0.000219213 s/step
# Meep progress: 1206.568/2090.0 = 57.7% done in 228.0s, 166.9s to go
# on time step 1206832 (time=1206.83), 0.000184255 s/step
# Meep progress: 1228.035/2090.0 = 58.8% done in 232.0s, 162.8s to go
# on time step 1228313 (time=1228.31), 0.000186216 s/step
# Meep progress: 1249.7830000000001/2090.0 = 59.8% done in 236.0s, 158.7s to go
# on time step 1250062 (time=1250.06), 0.000183917 s/step
# Meep progress: 1270.752/2090.0 = 60.8% done in 240.0s, 154.7s to go
# on time step 1270986 (time=1270.99), 0.000191174 s/step
# Meep progress: 1292.305/2090.0 = 61.8% done in 244.0s, 150.6s to go
# on time step 1292595 (time=1292.6), 0.000185111 s/step
# Meep progress: 1313.6480000000001/2090.0 = 62.9% done in 248.0s, 146.6s to go
# on time step 1313939 (time=1313.94), 0.000187412 s/step
# Meep progress: 1334.987/2090.0 = 63.9% done in 252.0s, 142.5s to go
# on time step 1335274 (time=1335.27), 0.000187488 s/step
# Meep progress: 1356.339/2090.0 = 64.9% done in 256.0s, 138.5s to go
# on time step 1356640 (time=1356.64), 0.00018722 s/step
# Meep progress: 1378.037/2090.0 = 65.9% done in 260.0s, 134.3s to go
# on time step 1378318 (time=1378.32), 0.000184525 s/step
# Meep progress: 1397.281/2090.0 = 66.9% done in 264.0s, 130.9s to go
# on time step 1397542 (time=1397.54), 0.000208084 s/step
# Meep progress: 1418.814/2090.0 = 67.9% done in 268.0s, 126.8s to go
# on time step 1419135 (time=1419.13), 0.000185252 s/step
# Meep progress: 1440.313/2090.0 = 68.9% done in 272.0s, 122.7s to go
# on time step 1440630 (time=1440.63), 0.000186093 s/step
# Meep progress: 1461.816/2090.0 = 69.9% done in 276.0s, 118.6s to go
# on time step 1462137 (time=1462.14), 0.00018599 s/step
# Meep progress: 1483.184/2090.0 = 71.0% done in 280.0s, 114.6s to go
# on time step 1483519 (time=1483.52), 0.000187075 s/step
# Meep progress: 1503.298/2090.0 = 71.9% done in 284.0s, 110.8s to go
# on time step 1503596 (time=1503.6), 0.000199242 s/step
# Meep progress: 1522.595/2090.0 = 72.9% done in 288.0s, 107.3s to go
# on time step 1522928 (time=1522.93), 0.00020692 s/step
# Meep progress: 1544.255/2090.0 = 73.9% done in 292.0s, 103.2s to go
# on time step 1544598 (time=1544.6), 0.00018459 s/step
# Meep progress: 1565.8500000000001/2090.0 = 74.9% done in 296.0s, 99.1s to go
# on time step 1566183 (time=1566.18), 0.00018532 s/step
# Meep progress: 1586.332/2090.0 = 75.9% done in 300.0s, 95.3s to go
# on time step 1586671 (time=1586.67), 0.000195244 s/step
# Meep progress: 1607.5720000000001/2090.0 = 76.9% done in 304.0s, 91.2s to go
# on time step 1607906 (time=1607.91), 0.000188374 s/step
# Meep progress: 1629.118/2090.0 = 77.9% done in 308.0s, 87.1s to go
# on time step 1629453 (time=1629.45), 0.000185648 s/step
# Meep progress: 1650.605/2090.0 = 79.0% done in 312.0s, 83.1s to go
# on time step 1650966 (time=1650.97), 0.000185937 s/step
# Meep progress: 1671.669/2090.0 = 80.0% done in 316.0s, 79.1s to go
# on time step 1672037 (time=1672.04), 0.000189836 s/step
# Meep progress: 1691.654/2090.0 = 80.9% done in 320.0s, 75.4s to go
# on time step 1691957 (time=1691.96), 0.000200816 s/step
# Meep progress: 1710.199/2090.0 = 81.8% done in 324.0s, 72.0s to go
# on time step 1710527 (time=1710.53), 0.000215402 s/step
# Meep progress: 1728.739/2090.0 = 82.7% done in 328.0s, 68.5s to go
# on time step 1729026 (time=1729.03), 0.000216233 s/step
# Meep progress: 1750.169/2090.0 = 83.7% done in 332.0s, 64.5s to go
# on time step 1750538 (time=1750.54), 0.000185949 s/step
# Meep progress: 1771.612/2090.0 = 84.8% done in 336.0s, 60.4s to go
# on time step 1772006 (time=1772.01), 0.000186331 s/step
# Meep progress: 1793.0810000000001/2090.0 = 85.8% done in 340.0s, 56.3s to go
# on time step 1793462 (time=1793.46), 0.000186433 s/step
# Meep progress: 1814.333/2090.0 = 86.8% done in 344.0s, 52.3s to go
# on time step 1814726 (time=1814.73), 0.000188112 s/step
# Meep progress: 1834.295/2090.0 = 87.8% done in 348.0s, 48.5s to go
# on time step 1834632 (time=1834.63), 0.000200945 s/step
# Meep progress: 1852.969/2090.0 = 88.7% done in 352.0s, 45.0s to go
# on time step 1853299 (time=1853.3), 0.000214293 s/step
# Meep progress: 1874.477/2090.0 = 89.7% done in 356.0s, 40.9s to go
# on time step 1874864 (time=1874.86), 0.000185491 s/step
# Meep progress: 1895.8990000000001/2090.0 = 90.7% done in 360.0s, 36.9s to go
# on time step 1896314 (time=1896.31), 0.000186487 s/step
# Meep progress: 1915.867/2090.0 = 91.7% done in 364.0s, 33.1s to go
# on time step 1916233 (time=1916.23), 0.000200822 s/step
# Meep progress: 1934.539/2090.0 = 92.6% done in 368.0s, 29.6s to go
# on time step 1934905 (time=1934.9), 0.000214234 s/step
# Meep progress: 1954.002/2090.0 = 93.5% done in 372.0s, 25.9s to go
# on time step 1954436 (time=1954.44), 0.00020481 s/step
# Meep progress: 1975.06/2090.0 = 94.5% done in 376.0s, 21.9s to go
# on time step 1975467 (time=1975.47), 0.0001902 s/step
# Meep progress: 1993.968/2090.0 = 95.4% done in 380.0s, 18.3s to go
# on time step 1994335 (time=1994.34), 0.000212005 s/step
# Meep progress: 2013.9940000000001/2090.0 = 96.4% done in 384.0s, 14.5s to go
# on time step 2014439 (time=2014.44), 0.000198968 s/step
# Meep progress: 2033.733/2090.0 = 97.3% done in 388.0s, 10.7s to go
# on time step 2034125 (time=2034.12), 0.000203196 s/step
# Meep progress: 2052.829/2090.0 = 98.2% done in 392.0s, 7.1s to go
# on time step 2053232 (time=2053.23), 0.000209348 s/step
# Meep progress: 2073.17/2090.0 = 99.2% done in 396.0s, 3.2s to go
# on time step 2073614 (time=2073.61), 0.000196261 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)

# %%
plt.figure(dpi=150)
freqs = np.linspace(0,30e15,1000)
plt.plot(freqs,Efavg*tsim*eps0*4*np.pi*3/2**21,'g''.')
plt.xlim(4e15,20e15)
plt.yscale("log")
plt.ylim(0.1e-28,400e-28)
plt.grid()
plt.savefig('6_source_test_detector_photonic_crystal_30000.png')
plt.show()

#np.savez("test_custom_source_photonic_crystal_30000.npz", Efavg_30000 = Efavg)

# %%
from PIL import Image

def transPNG(srcImageName, dstImageName):
    img = Image.open(srcImageName)
    img = img.convert("RGBA")
    datas = img.getdata()
    newData = list()
    for item in datas:
        if item[0] > 225 and item[1] > 225 and item[2] > 225:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
            
    img.putdata(newData)
    img.save(dstImageName, "PNG")
transPNG('test_detector_photonic_crystal_30000.png','trans_test_detector_photonic_crystal_30000.png')
