# %%
import numpy as np
data = np.load('10_7ps.npz')
print(data.files)
# Out:
# ['Efavg_30000']

# %%
import matplotlib.pyplot as plt
Es = data['Efavg_30000']
freqs = np.linspace(0,30e15,1000)
plt.plot(freqs,Es,'.',label='30000K')
#plt.xlim(0,2e-15)
#plt.ylim(-1.5,1.5)
plt.legend()


plt.xlabel('time')
plt.ylabel('Electric field source Es')
plt.savefig('time_35.png')
