# %%
##########################################################複製區塊
# import numpy as np
import matplotlib.pyplot as plt
import time
from scipy import signal
from time import sleep
import sys
import meep as mp
import numpy as np

#setup some constants and parameters
M=2**21
tsim=7e-12
eps0 = 8.854187e-12
hbar = 1.05457182e-34
c = 2.99792458e8
kb = 1.380649e-23
hdk=7.63823258e-12
deltap = np.sqrt(1/3/eps0/hbar/c)*kb
T=30000
frq_min = 0
frq_max = 100/2/np.pi
nfreq = 1000
fcen = (frq_min + frq_max)/2
df = frq_max - frq_min
#define square root of Dn function
def Dnsqt(wla,T):
    return np.sqrt(6*hdk**2*wla/(np.exp(hdk*wla/T)-1)/T**2/np.pi)

#generate an array of the square root of Dn function
Dsqt = []
for n in range(1,M):
    Dsqt.append(Dnsqt(2*np.pi*n/tsim,T))

#define how many times to run to average the results
Ncomp= 20
nfreq =  1000
#define the starting sum of the result
Efsum = np.zeros(nfreq)
Ens = np.zeros(2*22)
resolution = 1000
dA = 0.5
dB = 0.02
dpml = 1.0
sz = dpml*2+dA*2+dB
cell = mp.Vector3(0, 0, sz)
pml_layers = [mp.PML(dpml)]



for i in range(Ncomp):
    
    def random_En(t):
        #generate random numbers
        M0 = np.random.normal(0,1)
        Mlp = np.random.normal(0,1,M-1)
        Nlp = np.random.normal(0,1,M-1)
        MM = np.random.normal(0,1)
    
        #generate the array of the fourier transform of E field, we generate l=0 and l=-M separately. 
        #for l=1 to M-1 and l=-1 to -(M-1) are conjutated to each other. 
        #we contruct the whole array by gluing them together by the order from l=0 -> l=M-1 -> l=-M -> l=-(m-1) -> l=-1
        Ef0 = np.array([M0*np.sqrt(6*hdk/np.pi/T)])
        Eflp = np.multiply((Mlp + 1j*Nlp), Dsqt)
        Eflm = np.flip(np.conjugate(Eflp))
        EfM = np.array([MM*Dnsqt(2*np.pi*M/tsim,T)])
        Ef = np.hstack((Ef0,Eflp,EfM,Eflm))
    
        #we normalize Ef and compute its inverse fast fourier transform
        Efn = deltap*T/np.sqrt(tsim)*Ef
        En = np.fft.ifft(Efn)*M
        return En
    En0 = random_En(1)
    En1 = random_En(1)
    
    #generate some feedback to check the progress of the loop
    x = i/Ncomp*100
    sys.stdout.write('\r')
    sys.stdout.write("[%-20s] %d%%" % ('a'*int(x), int(x)))
    sys.stdout.flush()
    sleep(0.0001)
    
    
    def source0(t):
        f = int(t*2000)
        return En0[f]
    def source1(t):
        f = int(t*2000)
        return En1[f]


    sources = [mp.Source(mp.CustomSource(src_func=source0),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,-0.5*sz+dpml),
                     ),
              mp.Source(mp.CustomSource(src_func=source1),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,0.5*sz-dpml),
                     )]
    
    def BlockAB(N, center):
        geometry = []
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,0-dA/2-dB/2),
                     material=mp.Medium(epsilon=1)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dB),
                     center=mp.Vector3(0,0,0),
                     material=mp.Medium(epsilon=36)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,dB/2+dA/2),
                     material=mp.Medium(epsilon=1)))
        geometry = geometry.tolist()
        return geometry
    sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    sources=sources,   
                    dimensions = 1,
                    Courant = 1,
                    resolution=resolution,
                    geometry=BlockAB(1,0))
    

    # transmitted flux
    tran_fr = mp.FluxRegion(center=mp.Vector3(0,0,0.005))
    tran = sim.add_energy(fcen, df, nfreq, tran_fr)
    
    
    sim.run(until=2090)

    tran_flux = mp.get_magnetic_energy(tran)
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts,tran_flux[i])    
    Efsum += Ts
    
    

#average the final result
Efavg = Efsum/Ncomp

#save data to some file or reload file to write more data on it
# Out:
# [                    ] 0%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00236511 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00146699 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 32.605000000000004/2090.0 = 1.6% done in 4.0s, 252.4s to go
# on time step 33042 (time=33.042), 0.00012106 s/step
# Meep progress: 62.981/2090.0 = 3.0% done in 8.0s, 257.5s to go
# on time step 63409 (time=63.409), 0.000131724 s/step
# Meep progress: 93.19800000000001/2090.0 = 4.5% done in 12.0s, 257.1s to go
# on time step 93438 (time=93.438), 0.00013321 s/step
# Meep progress: 125.319/2090.0 = 6.0% done in 16.0s, 250.8s to go
# on time step 125850 (time=125.85), 0.000123411 s/step
# Meep progress: 157.647/2090.0 = 7.5% done in 20.0s, 245.2s to go
# on time step 158200 (time=158.2), 0.000123649 s/step
# Meep progress: 190.02700000000002/2090.0 = 9.1% done in 24.0s, 240.0s to go
# on time step 190579 (time=190.579), 0.00012354 s/step
# Meep progress: 221.788/2090.0 = 10.6% done in 28.0s, 235.9s to go
# on time step 222328 (time=222.328), 0.000125991 s/step
# Meep progress: 253.69/2090.0 = 12.1% done in 32.0s, 231.6s to go
# on time step 254234 (time=254.234), 0.00012537 s/step
# Meep progress: 286.692/2090.0 = 13.7% done in 36.0s, 226.4s to go
# on time step 287252 (time=287.252), 0.000121149 s/step
# Meep progress: 319.487/2090.0 = 15.3% done in 40.0s, 221.7s to go
# on time step 320052 (time=320.052), 0.000121954 s/step
# Meep progress: 351.797/2090.0 = 16.8% done in 44.0s, 217.4s to go
# on time step 352308 (time=352.308), 0.000124009 s/step
# Meep progress: 384.502/2090.0 = 18.4% done in 48.0s, 212.9s to go
# on time step 385046 (time=385.046), 0.000122185 s/step
# Meep progress: 417.545/2090.0 = 20.0% done in 52.0s, 208.3s to go
# on time step 418132 (time=418.132), 0.000120897 s/step
# Meep progress: 450.219/2090.0 = 21.5% done in 56.0s, 204.0s to go
# on time step 450805 (time=450.805), 0.000122426 s/step
# Meep progress: 483.29900000000004/2090.0 = 23.1% done in 60.0s, 199.5s to go
# on time step 483914 (time=483.914), 0.000120815 s/step
# Meep progress: 515.816/2090.0 = 24.7% done in 64.0s, 195.3s to go
# on time step 516432 (time=516.432), 0.000123012 s/step
# Meep progress: 548.9830000000001/2090.0 = 26.3% done in 68.0s, 190.9s to go
# on time step 549580 (time=549.58), 0.000120673 s/step
# Meep progress: 581.945/2090.0 = 27.8% done in 72.0s, 186.6s to go
# on time step 582559 (time=582.559), 0.000121292 s/step
# Meep progress: 614.874/2090.0 = 29.4% done in 76.0s, 182.3s to go
# on time step 615426 (time=615.426), 0.000121706 s/step
# Meep progress: 647.577/2090.0 = 31.0% done in 80.0s, 178.2s to go
# on time step 648196 (time=648.196), 0.000122067 s/step
# Meep progress: 679.633/2090.0 = 32.5% done in 84.0s, 174.3s to go
# on time step 680275 (time=680.275), 0.000124695 s/step
# Meep progress: 711.569/2090.0 = 34.0% done in 88.0s, 170.5s to go
# on time step 712161 (time=712.161), 0.000125449 s/step
# Meep progress: 743.746/2090.0 = 35.6% done in 92.0s, 166.5s to go
# on time step 744403 (time=744.403), 0.000124064 s/step
# Meep progress: 776.076/2090.0 = 37.1% done in 96.0s, 162.5s to go
# on time step 776660 (time=776.66), 0.000124005 s/step
# Meep progress: 808.116/2090.0 = 38.7% done in 100.0s, 158.6s to go
# on time step 808808 (time=808.808), 0.000124425 s/step
# Meep progress: 840.5/2090.0 = 40.2% done in 104.0s, 154.6s to go
# on time step 841101 (time=841.101), 0.000123866 s/step
# Meep progress: 873.46/2090.0 = 41.8% done in 108.0s, 150.4s to go
# on time step 874140 (time=874.14), 0.000121071 s/step
# Meep progress: 906.303/2090.0 = 43.4% done in 112.0s, 146.3s to go
# on time step 906987 (time=906.987), 0.000121777 s/step
# Meep progress: 937.155/2090.0 = 44.8% done in 116.0s, 142.7s to go
# on time step 937603 (time=937.603), 0.000130671 s/step
# Meep progress: 964.953/2090.0 = 46.2% done in 120.0s, 139.9s to go
# on time step 965336 (time=965.336), 0.000144239 s/step
# Meep progress: 982.597/2090.0 = 47.0% done in 124.0s, 139.8s to go
# on time step 982926 (time=982.926), 0.000227404 s/step
# Meep progress: 1000.048/2090.0 = 47.8% done in 128.0s, 139.5s to go
# on time step 1000398 (time=1000.4), 0.00022894 s/step
# Meep progress: 1017.33/2090.0 = 48.7% done in 132.0s, 139.2s to go
# on time step 1017748 (time=1017.75), 0.00023056 s/step
# Meep progress: 1046.996/2090.0 = 50.1% done in 136.0s, 135.5s to go
# on time step 1047773 (time=1047.77), 0.000133223 s/step
# Meep progress: 1080.465/2090.0 = 51.7% done in 140.0s, 130.8s to go
# on time step 1081231 (time=1081.23), 0.000119555 s/step
# Meep progress: 1114.5520000000001/2090.0 = 53.3% done in 144.0s, 126.0s to go
# on time step 1115297 (time=1115.3), 0.000117419 s/step
# Meep progress: 1146.973/2090.0 = 54.9% done in 148.0s, 121.7s to go
# on time step 1147777 (time=1147.78), 0.000123155 s/step
# Meep progress: 1179.904/2090.0 = 56.5% done in 152.0s, 117.2s to go
# on time step 1180669 (time=1180.67), 0.000121612 s/step
# Meep progress: 1210.428/2090.0 = 57.9% done in 156.0s, 113.4s to go
# on time step 1211039 (time=1211.04), 0.00013171 s/step
# Meep progress: 1242.266/2090.0 = 59.4% done in 160.0s, 109.2s to go
# on time step 1242898 (time=1242.9), 0.000125558 s/step
# Meep progress: 1270.288/2090.0 = 60.8% done in 164.0s, 105.8s to go
# on time step 1271026 (time=1271.03), 0.000142212 s/step
# Meep progress: 1301.952/2090.0 = 62.3% done in 168.0s, 101.7s to go
# on time step 1302710 (time=1302.71), 0.000126249 s/step
# Meep progress: 1333.967/2090.0 = 63.8% done in 172.0s, 97.5s to go
# on time step 1334764 (time=1334.76), 0.000124792 s/step
# Meep progress: 1366.351/2090.0 = 65.4% done in 176.0s, 93.2s to go
# on time step 1367065 (time=1367.07), 0.000123841 s/step
# Meep progress: 1398.749/2090.0 = 66.9% done in 180.0s, 89.0s to go
# on time step 1399606 (time=1399.61), 0.000122924 s/step
# Meep progress: 1432.088/2090.0 = 68.5% done in 184.0s, 84.5s to go
# on time step 1432962 (time=1432.96), 0.000119922 s/step
# Meep progress: 1464.962/2090.0 = 70.1% done in 188.0s, 80.2s to go
# on time step 1465807 (time=1465.81), 0.000121788 s/step
# Meep progress: 1484.983/2090.0 = 71.1% done in 192.0s, 78.2s to go
# on time step 1485438 (time=1485.44), 0.000203769 s/step
# Meep progress: 1502.825/2090.0 = 71.9% done in 196.0s, 76.6s to go
# on time step 1503306 (time=1503.31), 0.00022387 s/step
# Meep progress: 1520.692/2090.0 = 72.8% done in 200.0s, 74.9s to go
# on time step 1521114 (time=1521.11), 0.000224621 s/step
# Meep progress: 1542.016/2090.0 = 73.8% done in 204.0s, 72.5s to go
# on time step 1542845 (time=1542.85), 0.000184076 s/step
# Meep progress: 1575.118/2090.0 = 75.4% done in 208.0s, 68.0s to go
# on time step 1575982 (time=1575.98), 0.000120715 s/step
# Meep progress: 1607.963/2090.0 = 76.9% done in 212.0s, 63.6s to go
# on time step 1608846 (time=1608.85), 0.000121717 s/step
# Meep progress: 1639.74/2090.0 = 78.5% done in 216.0s, 59.3s to go
# on time step 1640414 (time=1640.41), 0.000126711 s/step
# Meep progress: 1671.259/2090.0 = 80.0% done in 220.0s, 55.1s to go
# on time step 1672225 (time=1672.23), 0.000125743 s/step
# Meep progress: 1704.829/2090.0 = 81.6% done in 224.0s, 50.6s to go
# on time step 1705800 (time=1705.8), 0.000119137 s/step
# Meep progress: 1735.726/2090.0 = 83.0% done in 228.0s, 46.5s to go
# on time step 1736676 (time=1736.68), 0.000129554 s/step
# Meep progress: 1768.334/2090.0 = 84.6% done in 232.0s, 42.2s to go
# on time step 1769232 (time=1769.23), 0.000122865 s/step
# Meep progress: 1800.237/2090.0 = 86.1% done in 236.0s, 38.0s to go
# on time step 1801047 (time=1801.05), 0.000125728 s/step
# Meep progress: 1832.976/2090.0 = 87.7% done in 240.0s, 33.7s to go
# on time step 1833934 (time=1833.93), 0.000121629 s/step
# Meep progress: 1866.387/2090.0 = 89.3% done in 244.0s, 29.2s to go
# on time step 1867392 (time=1867.39), 0.000119555 s/step
# Meep progress: 1899.842/2090.0 = 90.9% done in 248.0s, 24.8s to go
# on time step 1900807 (time=1900.81), 0.000119709 s/step
# Meep progress: 1932.056/2090.0 = 92.4% done in 252.0s, 20.6s to go
# on time step 1933023 (time=1933.02), 0.000124164 s/step
# Meep progress: 1964.401/2090.0 = 94.0% done in 256.0s, 16.4s to go
# on time step 1965418 (time=1965.42), 0.000123478 s/step
# Meep progress: 1997.487/2090.0 = 95.6% done in 260.0s, 12.0s to go
# on time step 1998336 (time=1998.34), 0.000121516 s/step
# Meep progress: 2031.2150000000001/2090.0 = 97.2% done in 264.0s, 7.6s to go
# on time step 2032173 (time=2032.17), 0.000118216 s/step
# Meep progress: 2063.703/2090.0 = 98.7% done in 268.0s, 3.4s to go
# on time step 2064661 (time=2064.66), 0.000123123 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaa               ] 5%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00251007 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00111103 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 31.692/2090.0 = 1.5% done in 4.0s, 259.8s to go
# on time step 31748 (time=31.748), 0.000125994 s/step
# Meep progress: 63.942/2090.0 = 3.1% done in 8.0s, 253.5s to go
# on time step 64016 (time=64.016), 0.000123965 s/step
# Meep progress: 96.44/2090.0 = 4.6% done in 12.0s, 248.1s to go
# on time step 96519 (time=96.519), 0.000123066 s/step
# Meep progress: 129.786/2090.0 = 6.2% done in 16.0s, 241.7s to go
# on time step 129878 (time=129.878), 0.000119923 s/step
# Meep progress: 161.196/2090.0 = 7.7% done in 20.0s, 239.3s to go
# on time step 161286 (time=161.286), 0.000127357 s/step
# Meep progress: 193.586/2090.0 = 9.3% done in 24.0s, 235.1s to go
# on time step 193694 (time=193.694), 0.000123426 s/step
# Meep progress: 226.092/2090.0 = 10.8% done in 28.0s, 230.8s to go
# on time step 226197 (time=226.197), 0.000123067 s/step
# Meep progress: 258.988/2090.0 = 12.4% done in 32.0s, 226.2s to go
# on time step 259094 (time=259.094), 0.000121594 s/step
# Meep progress: 291.38100000000003/2090.0 = 13.9% done in 36.0s, 222.2s to go
# on time step 291495 (time=291.495), 0.000123453 s/step
# Meep progress: 323.567/2090.0 = 15.5% done in 40.0s, 218.4s to go
# on time step 323694 (time=323.694), 0.000124228 s/step
# Meep progress: 355.94100000000003/2090.0 = 17.0% done in 44.0s, 214.4s to go
# on time step 356065 (time=356.065), 0.000123572 s/step
# Meep progress: 387.969/2090.0 = 18.6% done in 48.0s, 210.6s to go
# on time step 388094 (time=388.094), 0.000124887 s/step
# Meep progress: 419.926/2090.0 = 20.1% done in 52.0s, 206.8s to go
# on time step 420074 (time=420.074), 0.000125083 s/step
# Meep progress: 452.081/2090.0 = 21.6% done in 56.0s, 202.9s to go
# on time step 452236 (time=452.236), 0.000124371 s/step
# Meep progress: 484.512/2090.0 = 23.2% done in 60.0s, 198.8s to go
# on time step 484674 (time=484.674), 0.000123313 s/step
# Meep progress: 517.4350000000001/2090.0 = 24.8% done in 64.0s, 194.5s to go
# on time step 517607 (time=517.607), 0.000121461 s/step
# Meep progress: 551.072/2090.0 = 26.4% done in 68.0s, 189.9s to go
# on time step 551241 (time=551.241), 0.000118927 s/step
# Meep progress: 584.048/2090.0 = 27.9% done in 72.0s, 185.7s to go
# on time step 584221 (time=584.221), 0.000121289 s/step
# Meep progress: 616.628/2090.0 = 29.5% done in 76.0s, 181.6s to go
# on time step 616806 (time=616.806), 0.000122758 s/step
# Meep progress: 648.218/2090.0 = 31.0% done in 80.0s, 177.9s to go
# on time step 648408 (time=648.408), 0.000126576 s/step
# Meep progress: 680.813/2090.0 = 32.6% done in 84.0s, 173.9s to go
# on time step 681017 (time=681.017), 0.000122669 s/step
# Meep progress: 713.761/2090.0 = 34.2% done in 88.0s, 169.7s to go
# on time step 713965 (time=713.965), 0.000121405 s/step
# Meep progress: 746.309/2090.0 = 35.7% done in 92.0s, 165.6s to go
# on time step 746521 (time=746.521), 0.000122866 s/step
# Meep progress: 779.466/2090.0 = 37.3% done in 96.0s, 161.4s to go
# on time step 779608 (time=779.608), 0.000120896 s/step
# Meep progress: 811.417/2090.0 = 38.8% done in 100.0s, 157.6s to go
# on time step 811639 (time=811.639), 0.000124882 s/step
# Meep progress: 843.554/2090.0 = 40.4% done in 104.0s, 153.7s to go
# on time step 843783 (time=843.783), 0.000124443 s/step
# Meep progress: 876.293/2090.0 = 41.9% done in 108.0s, 149.6s to go
# on time step 876517 (time=876.517), 0.0001222 s/step
# Meep progress: 909.181/2090.0 = 43.5% done in 112.0s, 145.5s to go
# on time step 909433 (time=909.433), 0.000121525 s/step
# Meep progress: 942.375/2090.0 = 45.1% done in 116.0s, 141.3s to go
# on time step 942621 (time=942.621), 0.000120526 s/step
# Meep progress: 974.914/2090.0 = 46.6% done in 120.0s, 137.3s to go
# on time step 975158 (time=975.158), 0.00012294 s/step
# Meep progress: 1007.57/2090.0 = 48.2% done in 124.0s, 133.2s to go
# on time step 1007824 (time=1007.82), 0.000122454 s/step
# Meep progress: 1040.505/2090.0 = 49.8% done in 128.0s, 129.1s to go
# on time step 1040757 (time=1040.76), 0.00012146 s/step
# Meep progress: 1073.577/2090.0 = 51.4% done in 132.0s, 125.0s to go
# on time step 1073821 (time=1073.82), 0.00012098 s/step
# Meep progress: 1107.31/2090.0 = 53.0% done in 136.0s, 120.7s to go
# on time step 1107586 (time=1107.59), 0.000118469 s/step
# Meep progress: 1139.998/2090.0 = 54.5% done in 140.0s, 116.7s to go
# on time step 1140277 (time=1140.28), 0.00012236 s/step
# Meep progress: 1171.742/2090.0 = 56.1% done in 144.0s, 112.9s to go
# on time step 1171999 (time=1172), 0.000126097 s/step
# Meep progress: 1203.5810000000001/2090.0 = 57.6% done in 148.0s, 109.0s to go
# on time step 1203868 (time=1203.87), 0.000125517 s/step
# Meep progress: 1235.949/2090.0 = 59.1% done in 152.0s, 105.0s to go
# on time step 1236219 (time=1236.22), 0.000123648 s/step
# Meep progress: 1269.077/2090.0 = 60.7% done in 156.0s, 100.9s to go
# on time step 1269385 (time=1269.38), 0.000120608 s/step
# Meep progress: 1301.799/2090.0 = 62.3% done in 160.0s, 96.9s to go
# on time step 1302113 (time=1302.11), 0.000122222 s/step
# Meep progress: 1334.83/2090.0 = 63.9% done in 164.0s, 92.8s to go
# on time step 1335148 (time=1335.15), 0.000121086 s/step
# Meep progress: 1368.3210000000001/2090.0 = 65.5% done in 168.0s, 88.6s to go
# on time step 1368600 (time=1368.6), 0.000119577 s/step
# Meep progress: 1401.5/2090.0 = 67.1% done in 172.0s, 84.5s to go
# on time step 1401822 (time=1401.82), 0.000120403 s/step
# Meep progress: 1428.232/2090.0 = 68.3% done in 176.0s, 81.6s to go
# on time step 1428410 (time=1428.41), 0.00015045 s/step
# Meep progress: 1446.353/2090.0 = 69.2% done in 180.0s, 80.1s to go
# on time step 1446533 (time=1446.53), 0.000220721 s/step
# Meep progress: 1464.3890000000001/2090.0 = 70.1% done in 184.0s, 78.6s to go
# on time step 1464570 (time=1464.57), 0.000221772 s/step
# Meep progress: 1482.582/2090.0 = 70.9% done in 188.0s, 77.0s to go
# on time step 1482767 (time=1482.77), 0.000219824 s/step
# Meep progress: 1513.32/2090.0 = 72.4% done in 192.0s, 73.2s to go
# on time step 1513683 (time=1513.68), 0.000129384 s/step
# Meep progress: 1547.074/2090.0 = 74.0% done in 196.0s, 68.8s to go
# on time step 1547444 (time=1547.44), 0.000118482 s/step
# Meep progress: 1579.9850000000001/2090.0 = 75.6% done in 200.0s, 64.6s to go
# on time step 1580361 (time=1580.36), 0.000121519 s/step
# Meep progress: 1612.622/2090.0 = 77.2% done in 204.0s, 60.4s to go
# on time step 1612995 (time=1613), 0.000122574 s/step
# Meep progress: 1645.3310000000001/2090.0 = 78.7% done in 208.0s, 56.2s to go
# on time step 1645710 (time=1645.71), 0.000122269 s/step
# Meep progress: 1678.477/2090.0 = 80.3% done in 212.0s, 52.0s to go
# on time step 1678834 (time=1678.83), 0.00012076 s/step
# Meep progress: 1712.303/2090.0 = 81.9% done in 216.0s, 47.6s to go
# on time step 1712712 (time=1712.71), 0.000118071 s/step
# Meep progress: 1745.656/2090.0 = 83.5% done in 220.0s, 43.4s to go
# on time step 1746057 (time=1746.06), 0.00011996 s/step
# Meep progress: 1778.454/2090.0 = 85.1% done in 224.0s, 39.2s to go
# on time step 1778858 (time=1778.86), 0.00012195 s/step
# Meep progress: 1812.038/2090.0 = 86.7% done in 228.0s, 35.0s to go
# on time step 1812465 (time=1812.47), 0.000119024 s/step
# Meep progress: 1845.568/2090.0 = 88.3% done in 232.0s, 30.7s to go
# on time step 1845996 (time=1846), 0.000119296 s/step
# Meep progress: 1877.987/2090.0 = 89.9% done in 236.0s, 26.6s to go
# on time step 1878406 (time=1878.41), 0.000123421 s/step
# Meep progress: 1910.301/2090.0 = 91.4% done in 240.0s, 22.6s to go
# on time step 1910667 (time=1910.67), 0.000123991 s/step
# Meep progress: 1942.6970000000001/2090.0 = 93.0% done in 244.0s, 18.5s to go
# on time step 1943135 (time=1943.13), 0.0001232 s/step
# Meep progress: 1975.844/2090.0 = 94.5% done in 248.0s, 14.3s to go
# on time step 1976290 (time=1976.29), 0.000120659 s/step
# Meep progress: 2008.241/2090.0 = 96.1% done in 252.0s, 10.3s to go
# on time step 2008669 (time=2008.67), 0.000123539 s/step
# Meep progress: 2040.727/2090.0 = 97.6% done in 256.0s, 6.2s to go
# on time step 2041181 (time=2041.18), 0.000123034 s/step
# Meep progress: 2074.204/2090.0 = 99.2% done in 260.0s, 2.0s to go
# on time step 2074652 (time=2074.65), 0.000119507 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaa          ] 10%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000933886 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00146699 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 32.648/2090.0 = 1.6% done in 4.0s, 252.1s to go
# on time step 32732 (time=32.732), 0.000122215 s/step
# Meep progress: 65.895/2090.0 = 3.2% done in 8.0s, 245.7s to go
# on time step 65981 (time=65.981), 0.000120305 s/step
# Meep progress: 98.762/2090.0 = 4.7% done in 12.0s, 241.9s to go
# on time step 98862 (time=98.862), 0.000121653 s/step
# Meep progress: 132.291/2090.0 = 6.3% done in 16.0s, 236.8s to go
# on time step 132399 (time=132.399), 0.000119276 s/step
# Meep progress: 164.731/2090.0 = 7.9% done in 20.0s, 233.8s to go
# on time step 164849 (time=164.849), 0.000123267 s/step
# Meep progress: 198.501/2090.0 = 9.5% done in 24.0s, 228.7s to go
# on time step 198615 (time=198.615), 0.000118465 s/step
# Meep progress: 232.053/2090.0 = 11.1% done in 28.0s, 224.2s to go
# on time step 232181 (time=232.181), 0.000119173 s/step
# Meep progress: 264.871/2090.0 = 12.7% done in 32.0s, 220.5s to go
# on time step 265028 (time=265.028), 0.000121778 s/step
# Meep progress: 296.7/2090.0 = 14.2% done in 36.0s, 217.6s to go
# on time step 296864 (time=296.864), 0.000125645 s/step
# Meep progress: 330.301/2090.0 = 15.8% done in 40.0s, 213.1s to go
# on time step 330481 (time=330.481), 0.000118989 s/step
# Meep progress: 364.062/2090.0 = 17.4% done in 44.0s, 208.6s to go
# on time step 364245 (time=364.245), 0.00011847 s/step
# Meep progress: 396.967/2090.0 = 19.0% done in 48.0s, 204.7s to go
# on time step 397160 (time=397.16), 0.000121526 s/step
# Meep progress: 429.129/2090.0 = 20.5% done in 52.0s, 201.3s to go
# on time step 429339 (time=429.339), 0.000124307 s/step
# Meep progress: 461.279/2090.0 = 22.1% done in 56.0s, 197.7s to go
# on time step 461513 (time=461.513), 0.000124325 s/step
# Meep progress: 494.887/2090.0 = 23.7% done in 60.0s, 193.4s to go
# on time step 495127 (time=495.127), 0.000119 s/step
# Meep progress: 528.1270000000001/2090.0 = 25.3% done in 64.0s, 189.3s to go
# on time step 528366 (time=528.366), 0.000120343 s/step
# Meep progress: 561.484/2090.0 = 26.9% done in 68.0s, 185.1s to go
# on time step 561722 (time=561.722), 0.000119919 s/step
# Meep progress: 594.504/2090.0 = 28.4% done in 72.0s, 181.1s to go
# on time step 594781 (time=594.781), 0.000120997 s/step
# Meep progress: 627.666/2090.0 = 30.0% done in 76.0s, 177.1s to go
# on time step 627963 (time=627.963), 0.00012055 s/step
# Meep progress: 660.274/2090.0 = 31.6% done in 80.0s, 173.2s to go
# on time step 660553 (time=660.553), 0.000122739 s/step
# Meep progress: 693.716/2090.0 = 33.2% done in 84.0s, 169.1s to go
# on time step 694029 (time=694.029), 0.000119492 s/step
# Meep progress: 726.635/2090.0 = 34.8% done in 88.0s, 165.1s to go
# on time step 726961 (time=726.961), 0.000121463 s/step
# Meep progress: 759.735/2090.0 = 36.4% done in 92.0s, 161.1s to go
# on time step 760083 (time=760.083), 0.000120766 s/step
# Meep progress: 792.643/2090.0 = 37.9% done in 96.0s, 157.1s to go
# on time step 792987 (time=792.987), 0.000121571 s/step
# Meep progress: 825.907/2090.0 = 39.5% done in 100.0s, 153.1s to go
# on time step 826274 (time=826.274), 0.000120168 s/step
# Meep progress: 859.287/2090.0 = 41.1% done in 104.0s, 149.0s to go
# on time step 859655 (time=859.655), 0.00011983 s/step
# Meep progress: 892.2950000000001/2090.0 = 42.7% done in 108.0s, 145.0s to go
# on time step 892677 (time=892.677), 0.000121134 s/step
# Meep progress: 924.269/2090.0 = 44.2% done in 112.0s, 141.3s to go
# on time step 924650 (time=924.65), 0.000125106 s/step
# Meep progress: 957.135/2090.0 = 45.8% done in 116.0s, 137.3s to go
# on time step 957541 (time=957.541), 0.000121616 s/step
# Meep progress: 990.318/2090.0 = 47.4% done in 120.0s, 133.3s to go
# on time step 990753 (time=990.753), 0.00012044 s/step
# Meep progress: 1023.8000000000001/2090.0 = 49.0% done in 124.0s, 129.1s to go
# on time step 1024236 (time=1024.24), 0.000119464 s/step
# Meep progress: 1057.253/2090.0 = 50.6% done in 128.0s, 125.0s to go
# on time step 1057673 (time=1057.67), 0.000119631 s/step
# Meep progress: 1089.967/2090.0 = 52.2% done in 132.0s, 121.1s to go
# on time step 1090394 (time=1090.39), 0.000122246 s/step
# Meep progress: 1122.981/2090.0 = 53.7% done in 136.0s, 117.1s to go
# on time step 1123415 (time=1123.41), 0.000121136 s/step
# Meep progress: 1155.5040000000001/2090.0 = 55.3% done in 140.0s, 113.2s to go
# on time step 1155944 (time=1155.94), 0.000122968 s/step
# Meep progress: 1189.931/2090.0 = 56.9% done in 144.0s, 108.9s to go
# on time step 1190407 (time=1190.41), 0.000116067 s/step
# Meep progress: 1223.13/2090.0 = 58.5% done in 148.0s, 104.9s to go
# on time step 1223596 (time=1223.6), 0.000120525 s/step
# Meep progress: 1255.298/2090.0 = 60.1% done in 152.0s, 101.1s to go
# on time step 1255779 (time=1255.78), 0.000124292 s/step
# Meep progress: 1286.513/2090.0 = 61.6% done in 156.0s, 97.4s to go
# on time step 1286993 (time=1286.99), 0.000128149 s/step
# Meep progress: 1319.695/2090.0 = 63.1% done in 160.0s, 93.4s to go
# on time step 1320196 (time=1320.2), 0.000120472 s/step
# Meep progress: 1353.121/2090.0 = 64.7% done in 164.0s, 89.3s to go
# on time step 1353626 (time=1353.63), 0.000119653 s/step
# Meep progress: 1386.411/2090.0 = 66.3% done in 168.0s, 85.3s to go
# on time step 1386921 (time=1386.92), 0.00012014 s/step
# Meep progress: 1419.455/2090.0 = 67.9% done in 172.0s, 81.3s to go
# on time step 1419952 (time=1419.95), 0.000121101 s/step
# Meep progress: 1451.871/2090.0 = 69.5% done in 176.0s, 77.4s to go
# on time step 1452352 (time=1452.35), 0.00012346 s/step
# Meep progress: 1483.582/2090.0 = 71.0% done in 180.0s, 73.6s to go
# on time step 1484071 (time=1484.07), 0.00012611 s/step
# Meep progress: 1516.445/2090.0 = 72.6% done in 184.0s, 69.6s to go
# on time step 1516926 (time=1516.93), 0.000121749 s/step
# Meep progress: 1548.7640000000001/2090.0 = 74.1% done in 188.0s, 65.7s to go
# on time step 1549249 (time=1549.25), 0.000123755 s/step
# Meep progress: 1578.685/2090.0 = 75.5% done in 192.0s, 62.2s to go
# on time step 1578929 (time=1578.93), 0.000134775 s/step
# Meep progress: 1595.726/2090.0 = 76.4% done in 196.0s, 60.7s to go
# on time step 1595962 (time=1595.96), 0.000234859 s/step
# Meep progress: 1612.828/2090.0 = 77.2% done in 200.0s, 59.2s to go
# on time step 1613126 (time=1613.13), 0.000233047 s/step
# Meep progress: 1629.914/2090.0 = 78.0% done in 204.0s, 57.6s to go
# on time step 1630230 (time=1630.23), 0.000233882 s/step
# Meep progress: 1646.909/2090.0 = 78.8% done in 208.0s, 56.0s to go
# on time step 1647201 (time=1647.2), 0.000235698 s/step
# Meep progress: 1670.152/2090.0 = 79.9% done in 212.0s, 53.3s to go
# on time step 1670741 (time=1670.74), 0.000169927 s/step
# Meep progress: 1702.031/2090.0 = 81.4% done in 216.0s, 49.2s to go
# on time step 1702637 (time=1702.64), 0.000125408 s/step
# Meep progress: 1734.834/2090.0 = 83.0% done in 220.0s, 45.0s to go
# on time step 1735393 (time=1735.39), 0.000122116 s/step
# Meep progress: 1765.93/2090.0 = 84.5% done in 224.0s, 41.1s to go
# on time step 1766513 (time=1766.51), 0.000128538 s/step
# Meep progress: 1797.43/2090.0 = 86.0% done in 228.0s, 37.1s to go
# on time step 1798000 (time=1798), 0.000127044 s/step
# Meep progress: 1829.094/2090.0 = 87.5% done in 232.0s, 33.1s to go
# on time step 1829660 (time=1829.66), 0.000126345 s/step
# Meep progress: 1859.628/2090.0 = 89.0% done in 236.0s, 29.2s to go
# on time step 1860205 (time=1860.2), 0.000130955 s/step
# Meep progress: 1881.228/2090.0 = 90.0% done in 240.0s, 26.6s to go
# on time step 1881572 (time=1881.57), 0.000187205 s/step
# Meep progress: 1898.857/2090.0 = 90.9% done in 244.0s, 24.6s to go
# on time step 1899213 (time=1899.21), 0.000226754 s/step
# Meep progress: 1916.752/2090.0 = 91.7% done in 248.0s, 22.4s to go
# on time step 1917070 (time=1917.07), 0.000224016 s/step
# Meep progress: 1934.481/2090.0 = 92.6% done in 252.0s, 20.3s to go
# on time step 1934813 (time=1934.81), 0.000225453 s/step
# Meep progress: 1962.6570000000002/2090.0 = 93.9% done in 256.0s, 16.6s to go
# on time step 1963303 (time=1963.3), 0.0001404 s/step
# Meep progress: 1994.239/2090.0 = 95.4% done in 260.0s, 12.5s to go
# on time step 1994902 (time=1994.9), 0.000126589 s/step
# Meep progress: 2026.402/2090.0 = 97.0% done in 264.0s, 8.3s to go
# on time step 2027068 (time=2027.07), 0.000124357 s/step
# Meep progress: 2058.136/2090.0 = 98.5% done in 268.0s, 4.1s to go
# on time step 2058747 (time=2058.75), 0.000126268 s/step
# Meep progress: 2083.415/2090.0 = 99.7% done in 272.0s, 0.9s to go
# on time step 2083721 (time=2083.72), 0.000160171 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaa     ] 15%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00325799 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00420284 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 17.618000000000002/2090.0 = 0.8% done in 4.0s, 470.5s to go
# on time step 17678 (time=17.678), 0.000226275 s/step
# Meep progress: 35.429/2090.0 = 1.7% done in 8.0s, 463.9s to go
# on time step 35489 (time=35.489), 0.000224583 s/step
# Meep progress: 53.468/2090.0 = 2.6% done in 12.0s, 457.1s to go
# on time step 53533 (time=53.533), 0.000221683 s/step
# Meep progress: 82.828/2090.0 = 4.0% done in 16.0s, 387.7s to go
# on time step 82968 (time=82.968), 0.000135896 s/step
# Meep progress: 114.906/2090.0 = 5.5% done in 20.0s, 343.8s to go
# on time step 115045 (time=115.045), 0.000124702 s/step
# Meep progress: 141.64600000000002/2090.0 = 6.8% done in 24.0s, 330.1s to go
# on time step 141757 (time=141.757), 0.000149747 s/step
# Meep progress: 167.981/2090.0 = 8.0% done in 28.0s, 320.4s to go
# on time step 168056 (time=168.056), 0.000152106 s/step
# Meep progress: 185.43200000000002/2090.0 = 8.9% done in 32.0s, 328.7s to go
# on time step 185498 (time=185.498), 0.000229338 s/step
# Meep progress: 202.011/2090.0 = 9.7% done in 36.0s, 336.5s to go
# on time step 202091 (time=202.091), 0.000241073 s/step
# Meep progress: 217.869/2090.0 = 10.4% done in 40.0s, 343.7s to go
# on time step 217947 (time=217.947), 0.000252271 s/step
# Meep progress: 234.35/2090.0 = 11.2% done in 44.0s, 348.4s to go
# on time step 234419 (time=234.419), 0.000242841 s/step
# Meep progress: 259.1/2090.0 = 12.4% done in 48.0s, 339.2s to go
# on time step 259258 (time=259.258), 0.00016104 s/step
# Meep progress: 288.097/2090.0 = 13.8% done in 52.0s, 325.2s to go
# on time step 288272 (time=288.272), 0.000137866 s/step
# Meep progress: 318.053/2090.0 = 15.2% done in 56.0s, 312.0s to go
# on time step 318209 (time=318.209), 0.000133617 s/step
# Meep progress: 347.623/2090.0 = 16.6% done in 60.0s, 300.7s to go
# on time step 347775 (time=347.775), 0.0001353 s/step
# Meep progress: 376.77500000000003/2090.0 = 18.0% done in 64.0s, 291.0s to go
# on time step 376956 (time=376.956), 0.000137078 s/step
# Meep progress: 403.22700000000003/2090.0 = 19.3% done in 68.0s, 284.5s to go
# on time step 403336 (time=403.336), 0.000151631 s/step
# Meep progress: 420.13/2090.0 = 20.1% done in 72.0s, 286.2s to go
# on time step 420235 (time=420.235), 0.000236703 s/step
# Meep progress: 436.532/2090.0 = 20.9% done in 76.0s, 287.9s to go
# on time step 436658 (time=436.658), 0.000243564 s/step
# Meep progress: 453.421/2090.0 = 21.7% done in 80.0s, 288.8s to go
# on time step 453539 (time=453.539), 0.000236954 s/step
# Meep progress: 471.824/2090.0 = 22.6% done in 84.0s, 288.1s to go
# on time step 472087 (time=472.087), 0.000215661 s/step
# Meep progress: 503.98400000000004/2090.0 = 24.1% done in 88.0s, 276.9s to go
# on time step 504254 (time=504.254), 0.000124352 s/step
# Meep progress: 536.675/2090.0 = 25.7% done in 92.0s, 266.3s to go
# on time step 536928 (time=536.928), 0.000122423 s/step
# Meep progress: 563.947/2090.0 = 27.0% done in 96.0s, 259.8s to go
# on time step 564160 (time=564.16), 0.000146893 s/step
# Meep progress: 592.063/2090.0 = 28.3% done in 100.0s, 253.0s to go
# on time step 592294 (time=592.294), 0.000142178 s/step
# Meep progress: 618.573/2090.0 = 29.6% done in 104.0s, 247.4s to go
# on time step 618715 (time=618.715), 0.000151395 s/step
# Meep progress: 633.804/2090.0 = 30.3% done in 108.0s, 248.1s to go
# on time step 633941 (time=633.941), 0.000262715 s/step
# Meep progress: 649.1/2090.0 = 31.1% done in 112.0s, 248.6s to go
# on time step 649252 (time=649.252), 0.000261272 s/step
# Meep progress: 665.8870000000001/2090.0 = 31.9% done in 116.0s, 248.1s to go
# on time step 666039 (time=666.039), 0.000238284 s/step
# Meep progress: 682.741/2090.0 = 32.7% done in 120.0s, 247.4s to go
# on time step 682901 (time=682.901), 0.000237235 s/step
# Meep progress: 709.365/2090.0 = 33.9% done in 124.0s, 241.3s to go
# on time step 709670 (time=709.67), 0.000149427 s/step
# Meep progress: 739.518/2090.0 = 35.4% done in 128.0s, 233.8s to go
# on time step 739785 (time=739.785), 0.000132827 s/step
# Meep progress: 769.2/2090.0 = 36.8% done in 132.0s, 226.7s to go
# on time step 769502 (time=769.502), 0.000134603 s/step
# Meep progress: 795.972/2090.0 = 38.1% done in 136.0s, 221.1s to go
# on time step 796291 (time=796.291), 0.000149316 s/step
# Meep progress: 824.506/2090.0 = 39.5% done in 140.0s, 214.9s to go
# on time step 824814 (time=824.814), 0.000140238 s/step
# Meep progress: 844.756/2090.0 = 40.4% done in 144.0s, 212.3s to go
# on time step 844937 (time=844.937), 0.000198782 s/step
# Meep progress: 859.963/2090.0 = 41.1% done in 148.0s, 211.7s to go
# on time step 860126 (time=860.126), 0.000263368 s/step
# Meep progress: 875.333/2090.0 = 41.9% done in 152.0s, 210.9s to go
# on time step 875533 (time=875.533), 0.000259635 s/step
# Meep progress: 890.7280000000001/2090.0 = 42.6% done in 156.0s, 210.0s to go
# on time step 890910 (time=890.91), 0.000260129 s/step
# Meep progress: 908.855/2090.0 = 43.5% done in 160.0s, 207.9s to go
# on time step 909249 (time=909.249), 0.00021812 s/step
# Meep progress: 938.552/2090.0 = 44.9% done in 164.0s, 201.2s to go
# on time step 938954 (time=938.954), 0.000134661 s/step
# Meep progress: 969.1700000000001/2090.0 = 46.4% done in 168.0s, 194.3s to go
# on time step 969547 (time=969.547), 0.000130752 s/step
# Meep progress: 998.059/2090.0 = 47.8% done in 172.0s, 188.2s to go
# on time step 998463 (time=998.463), 0.000138333 s/step
# Meep progress: 1027.463/2090.0 = 49.2% done in 176.0s, 182.0s to go
# on time step 1027832 (time=1027.83), 0.000136202 s/step
# Meep progress: 1056.0240000000001/2090.0 = 50.5% done in 180.0s, 176.2s to go
# on time step 1056431 (time=1056.43), 0.00013987 s/step
# Meep progress: 1077.545/2090.0 = 51.6% done in 184.0s, 172.9s to go
# on time step 1077784 (time=1077.78), 0.000187337 s/step
# Meep progress: 1094.401/2090.0 = 52.4% done in 188.0s, 171.0s to go
# on time step 1094641 (time=1094.64), 0.000237291 s/step
# Meep progress: 1110.53/2090.0 = 53.1% done in 192.0s, 169.3s to go
# on time step 1110745 (time=1110.75), 0.000248389 s/step
# Meep progress: 1126.63/2090.0 = 53.9% done in 196.0s, 167.6s to go
# on time step 1126883 (time=1126.88), 0.000247871 s/step
# Meep progress: 1148.017/2090.0 = 54.9% done in 200.0s, 164.1s to go
# on time step 1148468 (time=1148.47), 0.000185315 s/step
# Meep progress: 1177.545/2090.0 = 56.3% done in 204.0s, 158.1s to go
# on time step 1178010 (time=1178.01), 0.000135404 s/step
# Meep progress: 1206.66/2090.0 = 57.7% done in 208.0s, 152.3s to go
# on time step 1207113 (time=1207.11), 0.000137446 s/step
# Meep progress: 1235.4750000000001/2090.0 = 59.1% done in 212.0s, 146.6s to go
# on time step 1235955 (time=1235.95), 0.000138688 s/step
# Meep progress: 1264.532/2090.0 = 60.5% done in 216.0s, 141.0s to go
# on time step 1265071 (time=1265.07), 0.000137382 s/step
# Meep progress: 1297.365/2090.0 = 62.1% done in 220.0s, 134.4s to go
# on time step 1297807 (time=1297.81), 0.000122192 s/step
# Meep progress: 1328.0140000000001/2090.0 = 63.5% done in 224.0s, 128.5s to go
# on time step 1328471 (time=1328.47), 0.000130464 s/step
# Meep progress: 1353.019/2090.0 = 64.7% done in 228.0s, 124.2s to go
# on time step 1353306 (time=1353.31), 0.000161065 s/step
# Meep progress: 1370.022/2090.0 = 65.6% done in 232.0s, 121.9s to go
# on time step 1370313 (time=1370.31), 0.000235201 s/step
# Meep progress: 1386.582/2090.0 = 66.3% done in 236.0s, 119.7s to go
# on time step 1386872 (time=1386.87), 0.000241573 s/step
# Meep progress: 1403.029/2090.0 = 67.1% done in 240.0s, 117.5s to go
# on time step 1403317 (time=1403.32), 0.000243247 s/step
# Meep progress: 1419.234/2090.0 = 67.9% done in 244.0s, 115.3s to go
# on time step 1419564 (time=1419.56), 0.00024621 s/step
# Meep progress: 1448.182/2090.0 = 69.3% done in 248.0s, 109.9s to go
# on time step 1448708 (time=1448.71), 0.000137251 s/step
# Meep progress: 1478.4370000000001/2090.0 = 70.7% done in 252.0s, 104.2s to go
# on time step 1478975 (time=1478.98), 0.000132158 s/step
# Meep progress: 1508.964/2090.0 = 72.2% done in 256.0s, 98.6s to go
# on time step 1509540 (time=1509.54), 0.00013087 s/step
# Meep progress: 1539.106/2090.0 = 73.6% done in 260.0s, 93.1s to go
# on time step 1539709 (time=1539.71), 0.000132587 s/step
# Meep progress: 1569.605/2090.0 = 75.1% done in 264.0s, 87.5s to go
# on time step 1570170 (time=1570.17), 0.000131318 s/step
# Meep progress: 1594.778/2090.0 = 76.3% done in 268.0s, 83.2s to go
# on time step 1595040 (time=1595.04), 0.000160841 s/step
# Meep progress: 1611.832/2090.0 = 77.1% done in 272.0s, 80.7s to go
# on time step 1612161 (time=1612.16), 0.000233642 s/step
# Meep progress: 1628.699/2090.0 = 77.9% done in 276.0s, 78.2s to go
# on time step 1629049 (time=1629.05), 0.000236856 s/step
# Meep progress: 1645.915/2090.0 = 78.8% done in 280.0s, 75.5s to go
# on time step 1646250 (time=1646.25), 0.000232551 s/step
# Meep progress: 1663.201/2090.0 = 79.6% done in 284.0s, 72.9s to go
# on time step 1663561 (time=1663.56), 0.000231075 s/step
# Meep progress: 1693.066/2090.0 = 81.0% done in 288.0s, 67.5s to go
# on time step 1693732 (time=1693.73), 0.000132579 s/step
# Meep progress: 1723.175/2090.0 = 82.4% done in 292.0s, 62.2s to go
# on time step 1723816 (time=1723.82), 0.000132963 s/step
# Meep progress: 1753.997/2090.0 = 83.9% done in 296.0s, 56.7s to go
# on time step 1754619 (time=1754.62), 0.000129861 s/step
# Meep progress: 1784.656/2090.0 = 85.4% done in 300.0s, 51.3s to go
# on time step 1785368 (time=1785.37), 0.000130089 s/step
# Meep progress: 1815.038/2090.0 = 86.8% done in 304.0s, 46.1s to go
# on time step 1815720 (time=1815.72), 0.00013179 s/step
# Meep progress: 1844.517/2090.0 = 88.3% done in 308.0s, 41.0s to go
# on time step 1845150 (time=1845.15), 0.000135918 s/step
# Meep progress: 1864.796/2090.0 = 89.2% done in 312.0s, 37.7s to go
# on time step 1865185 (time=1865.18), 0.00019966 s/step
# Meep progress: 1881.824/2090.0 = 90.0% done in 316.0s, 35.0s to go
# on time step 1882187 (time=1882.19), 0.000235291 s/step
# Meep progress: 1898.919/2090.0 = 90.9% done in 320.0s, 32.2s to go
# on time step 1899331 (time=1899.33), 0.000233328 s/step
# Meep progress: 1915.959/2090.0 = 91.7% done in 324.0s, 29.4s to go
# on time step 1916313 (time=1916.31), 0.000235549 s/step
# Meep progress: 1940.006/2090.0 = 92.8% done in 328.0s, 25.4s to go
# on time step 1940751 (time=1940.75), 0.000163683 s/step
# Meep progress: 1970.406/2090.0 = 94.3% done in 332.0s, 20.2s to go
# on time step 1971155 (time=1971.15), 0.000131563 s/step
# Meep progress: 2000.662/2090.0 = 95.7% done in 336.0s, 15.0s to go
# on time step 2001391 (time=2001.39), 0.000132296 s/step
# Meep progress: 2030.9070000000002/2090.0 = 97.2% done in 340.0s, 9.9s to go
# on time step 2031700 (time=2031.7), 0.000131974 s/step
# Meep progress: 2061.494/2090.0 = 98.6% done in 344.0s, 4.8s to go
# on time step 2062186 (time=2062.19), 0.000131209 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaa] 20%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00090313 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0010469 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 20.405/2090.0 = 1.0% done in 4.0s, 405.7s to go
# on time step 20449 (time=20.449), 0.000195615 s/step
# Meep progress: 37.432/2090.0 = 1.8% done in 8.0s, 438.7s to go
# on time step 37479 (time=37.479), 0.000234883 s/step
# Meep progress: 54.548/2090.0 = 2.6% done in 12.0s, 447.8s to go
# on time step 54603 (time=54.603), 0.000233595 s/step
# Meep progress: 71.609/2090.0 = 3.4% done in 16.0s, 451.0s to go
# on time step 71673 (time=71.673), 0.000234332 s/step
# Meep progress: 94.622/2090.0 = 4.5% done in 20.0s, 421.8s to go
# on time step 94708 (time=94.708), 0.000173651 s/step
# Meep progress: 125.922/2090.0 = 6.0% done in 24.0s, 374.4s to go
# on time step 126050 (time=126.05), 0.000127626 s/step
# Meep progress: 155.816/2090.0 = 7.5% done in 28.0s, 347.6s to go
# on time step 155969 (time=155.969), 0.000133695 s/step
# Meep progress: 186.074/2090.0 = 8.9% done in 32.0s, 327.4s to go
# on time step 186229 (time=186.229), 0.00013219 s/step
# Meep progress: 216.978/2090.0 = 10.4% done in 36.0s, 310.8s to go
# on time step 217111 (time=217.111), 0.000129528 s/step
# Meep progress: 246.38/2090.0 = 11.8% done in 40.0s, 299.3s to go
# on time step 246564 (time=246.564), 0.000135813 s/step
# Meep progress: 272.557/2090.0 = 13.0% done in 44.0s, 293.4s to go
# on time step 272617 (time=272.617), 0.000153537 s/step
# Meep progress: 290.193/2090.0 = 13.9% done in 48.0s, 297.7s to go
# on time step 290292 (time=290.292), 0.000226313 s/step
# Meep progress: 308.063/2090.0 = 14.7% done in 52.0s, 300.8s to go
# on time step 308171 (time=308.171), 0.000223734 s/step
# Meep progress: 325.58/2090.0 = 15.6% done in 56.0s, 303.5s to go
# on time step 325687 (time=325.687), 0.000228374 s/step
# Meep progress: 354.89/2090.0 = 17.0% done in 60.0s, 293.4s to go
# on time step 355123 (time=355.123), 0.000135892 s/step
# Meep progress: 387.761/2090.0 = 18.6% done in 64.0s, 281.0s to go
# on time step 387999 (time=387.999), 0.00012167 s/step
# Meep progress: 421.238/2090.0 = 20.2% done in 68.0s, 269.4s to go
# on time step 421474 (time=421.474), 0.000119495 s/step
# Meep progress: 455.5/2090.0 = 21.8% done in 72.0s, 258.4s to go
# on time step 455747 (time=455.747), 0.000116711 s/step
# Meep progress: 489.161/2090.0 = 23.4% done in 76.0s, 248.7s to go
# on time step 489417 (time=489.417), 0.000118802 s/step
# Meep progress: 524.197/2090.0 = 25.1% done in 80.0s, 239.0s to go
# on time step 524458 (time=524.458), 0.000114155 s/step
# Meep progress: 558.433/2090.0 = 26.7% done in 84.0s, 230.4s to go
# on time step 558672 (time=558.672), 0.000116915 s/step
# Meep progress: 591.862/2090.0 = 28.3% done in 88.0s, 222.8s to go
# on time step 592096 (time=592.096), 0.000119675 s/step
# Meep progress: 625.0790000000001/2090.0 = 29.9% done in 92.0s, 215.6s to go
# on time step 625338 (time=625.338), 0.000120332 s/step
# Meep progress: 657.963/2090.0 = 31.5% done in 96.0s, 208.9s to go
# on time step 658240 (time=658.24), 0.000121574 s/step
# Meep progress: 691.23/2090.0 = 33.1% done in 100.0s, 202.4s to go
# on time step 691504 (time=691.504), 0.000120251 s/step
# Meep progress: 724.6750000000001/2090.0 = 34.7% done in 104.0s, 195.9s to go
# on time step 724954 (time=724.954), 0.000119581 s/step
# Meep progress: 757.6800000000001/2090.0 = 36.3% done in 108.0s, 189.9s to go
# on time step 757968 (time=757.968), 0.000121164 s/step
# Meep progress: 790.429/2090.0 = 37.8% done in 112.0s, 184.1s to go
# on time step 790724 (time=790.724), 0.000122117 s/step
# Meep progress: 823.769/2090.0 = 39.4% done in 116.0s, 178.3s to go
# on time step 824053 (time=824.053), 0.000120018 s/step
# Meep progress: 857.216/2090.0 = 41.0% done in 120.0s, 172.6s to go
# on time step 857486 (time=857.486), 0.000119644 s/step
# Meep progress: 890.421/2090.0 = 42.6% done in 124.0s, 167.1s to go
# on time step 890730 (time=890.73), 0.000120324 s/step
# Meep progress: 923.668/2090.0 = 44.2% done in 128.0s, 161.6s to go
# on time step 923963 (time=923.963), 0.000120365 s/step
# Meep progress: 955.525/2090.0 = 45.7% done in 132.0s, 156.7s to go
# on time step 955848 (time=955.848), 0.000125452 s/step
# Meep progress: 987.7090000000001/2090.0 = 47.3% done in 136.0s, 151.8s to go
# on time step 988035 (time=988.035), 0.000124277 s/step
# Meep progress: 1020.774/2090.0 = 48.8% done in 140.0s, 146.6s to go
# on time step 1021093 (time=1021.09), 0.000121001 s/step
# Meep progress: 1053.81/2090.0 = 50.4% done in 144.0s, 141.6s to go
# on time step 1054150 (time=1054.15), 0.000121004 s/step
# Meep progress: 1086.9080000000001/2090.0 = 52.0% done in 148.0s, 136.6s to go
# on time step 1087250 (time=1087.25), 0.000120848 s/step
# Meep progress: 1119.777/2090.0 = 53.6% done in 152.0s, 131.7s to go
# on time step 1120120 (time=1120.12), 0.000121692 s/step
# Meep progress: 1153.232/2090.0 = 55.2% done in 156.0s, 126.7s to go
# on time step 1153588 (time=1153.59), 0.00011952 s/step
# Meep progress: 1186.238/2090.0 = 56.8% done in 160.0s, 121.9s to go
# on time step 1186593 (time=1186.59), 0.000121195 s/step
# Meep progress: 1219.369/2090.0 = 58.3% done in 164.0s, 117.1s to go
# on time step 1219737 (time=1219.74), 0.000120687 s/step
# Meep progress: 1252.619/2090.0 = 59.9% done in 168.0s, 112.3s to go
# on time step 1252966 (time=1252.97), 0.00012038 s/step
# Meep progress: 1284.961/2090.0 = 61.5% done in 172.0s, 107.8s to go
# on time step 1285326 (time=1285.33), 0.000123613 s/step
# Meep progress: 1317.747/2090.0 = 63.1% done in 176.0s, 103.1s to go
# on time step 1318119 (time=1318.12), 0.000121981 s/step
# Meep progress: 1351.121/2090.0 = 64.6% done in 180.0s, 98.4s to go
# on time step 1351513 (time=1351.51), 0.000119785 s/step
# Meep progress: 1384.363/2090.0 = 66.2% done in 184.0s, 93.8s to go
# on time step 1384748 (time=1384.75), 0.000120355 s/step
# Meep progress: 1417.0720000000001/2090.0 = 67.8% done in 188.0s, 89.3s to go
# on time step 1417451 (time=1417.45), 0.000122316 s/step
# Meep progress: 1450.201/2090.0 = 69.4% done in 192.0s, 84.7s to go
# on time step 1450598 (time=1450.6), 0.000120677 s/step
# Meep progress: 1483.423/2090.0 = 71.0% done in 196.0s, 80.1s to go
# on time step 1483837 (time=1483.84), 0.000120342 s/step
# Meep progress: 1516.307/2090.0 = 72.6% done in 200.0s, 75.7s to go
# on time step 1516712 (time=1516.71), 0.000121673 s/step
# Meep progress: 1550.183/2090.0 = 74.2% done in 204.0s, 71.0s to go
# on time step 1550601 (time=1550.6), 0.000118035 s/step
# Meep progress: 1582.925/2090.0 = 75.7% done in 208.0s, 66.6s to go
# on time step 1583337 (time=1583.34), 0.000122191 s/step
# Meep progress: 1615.5910000000001/2090.0 = 77.3% done in 212.0s, 62.3s to go
# on time step 1615983 (time=1615.98), 0.000122528 s/step
# Meep progress: 1648.891/2090.0 = 78.9% done in 216.0s, 57.8s to go
# on time step 1649324 (time=1649.32), 0.000119973 s/step
# Meep progress: 1682.703/2090.0 = 80.5% done in 220.0s, 53.3s to go
# on time step 1683127 (time=1683.13), 0.000118335 s/step
# Meep progress: 1716.476/2090.0 = 82.1% done in 224.0s, 48.7s to go
# on time step 1716912 (time=1716.91), 0.000118398 s/step
# Meep progress: 1748.741/2090.0 = 83.7% done in 228.0s, 44.5s to go
# on time step 1749179 (time=1749.18), 0.000123986 s/step
# Meep progress: 1781.055/2090.0 = 85.2% done in 232.0s, 40.2s to go
# on time step 1781506 (time=1781.51), 0.000123739 s/step
# Meep progress: 1813.931/2090.0 = 86.8% done in 236.0s, 35.9s to go
# on time step 1814385 (time=1814.38), 0.000121659 s/step
# Meep progress: 1847.317/2090.0 = 88.4% done in 240.0s, 31.5s to go
# on time step 1847786 (time=1847.79), 0.000119759 s/step
# Meep progress: 1880.8700000000001/2090.0 = 90.0% done in 244.0s, 27.1s to go
# on time step 1881338 (time=1881.34), 0.000119219 s/step
# Meep progress: 1914.424/2090.0 = 91.6% done in 248.0s, 22.7s to go
# on time step 1914896 (time=1914.9), 0.000119198 s/step
# Meep progress: 1947.0520000000001/2090.0 = 93.2% done in 252.0s, 18.5s to go
# on time step 1947521 (time=1947.52), 0.00012261 s/step
# Meep progress: 1979.929/2090.0 = 94.7% done in 256.0s, 14.2s to go
# on time step 1980424 (time=1980.42), 0.00012157 s/step
# Meep progress: 2013.029/2090.0 = 96.3% done in 260.0s, 9.9s to go
# on time step 2013527 (time=2013.53), 0.000120836 s/step
# Meep progress: 2045.6860000000001/2090.0 = 97.9% done in 264.0s, 5.7s to go
# on time step 2046170 (time=2046.17), 0.00012254 s/step
# Meep progress: 2078.266/2090.0 = 99.4% done in 268.0s, 1.5s to go
# on time step 2078729 (time=2078.73), 0.000122856 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaa] 25%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00370383 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
# ...
# time for set_epsilon = 0.00101781 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 31.467000000000002/2090.0 = 1.5% done in 4.0s, 261.7s to go
# on time step 31536 (time=31.536), 0.00012684 s/step
# Meep progress: 64.899/2090.0 = 3.1% done in 8.0s, 249.6s to go
# on time step 64974 (time=64.974), 0.000119628 s/step
# Meep progress: 98.496/2090.0 = 4.7% done in 12.0s, 242.6s to go
# on time step 98557 (time=98.557), 0.000119109 s/step
# Meep progress: 132.429/2090.0 = 6.3% done in 16.0s, 236.5s to go
# on time step 132508 (time=132.508), 0.000117817 s/step
# Meep progress: 165.835/2090.0 = 7.9% done in 20.0s, 232.1s to go
# on time step 165930 (time=165.93), 0.000119682 s/step
# Meep progress: 198.823/2090.0 = 9.5% done in 24.0s, 228.3s to go
# on time step 198922 (time=198.922), 0.000121245 s/step
# Meep progress: 232.151/2090.0 = 11.1% done in 28.0s, 224.1s to go
# on time step 232257 (time=232.257), 0.000119995 s/step
# Meep progress: 266.23900000000003/2090.0 = 12.7% done in 32.0s, 219.2s to go
# on time step 266345 (time=266.345), 0.000117344 s/step
# Meep progress: 300.017/2090.0 = 14.4% done in 36.0s, 214.8s to go
# on time step 300119 (time=300.119), 0.000118436 s/step
# Meep progress: 333.622/2090.0 = 16.0% done in 40.0s, 210.6s to go
# on time step 333742 (time=333.742), 0.000118969 s/step
# Meep progress: 366.689/2090.0 = 17.5% done in 44.0s, 206.8s to go
# on time step 366811 (time=366.811), 0.00012096 s/step
# Meep progress: 399.571/2090.0 = 19.1% done in 48.0s, 203.1s to go
# on time step 399688 (time=399.688), 0.000121669 s/step
# Meep progress: 432.22200000000004/2090.0 = 20.7% done in 52.0s, 199.4s to go
# on time step 432356 (time=432.356), 0.000122447 s/step
# Meep progress: 465.547/2090.0 = 22.3% done in 56.0s, 195.4s to go
# on time step 465677 (time=465.677), 0.000120045 s/step
# Meep progress: 499.082/2090.0 = 23.9% done in 60.0s, 191.3s to go
# on time step 499229 (time=499.229), 0.000119219 s/step
# Meep progress: 532.205/2090.0 = 25.5% done in 64.0s, 187.3s to go
# on time step 532356 (time=532.356), 0.000120749 s/step
# Meep progress: 565.075/2090.0 = 27.0% done in 68.0s, 183.5s to go
# on time step 565235 (time=565.235), 0.000121661 s/step
# Meep progress: 599.2040000000001/2090.0 = 28.7% done in 72.0s, 179.1s to go
# on time step 599351 (time=599.351), 0.00011725 s/step
# Meep progress: 632.749/2090.0 = 30.3% done in 76.0s, 175.0s to go
# on time step 632909 (time=632.909), 0.000119198 s/step
# Meep progress: 665.6510000000001/2090.0 = 31.8% done in 80.0s, 171.2s to go
# on time step 665809 (time=665.809), 0.000121583 s/step
# Meep progress: 698.83/2090.0 = 33.4% done in 84.0s, 167.2s to go
# on time step 699009 (time=699.009), 0.000120486 s/step
# Meep progress: 732.157/2090.0 = 35.0% done in 88.0s, 163.2s to go
# on time step 732328 (time=732.328), 0.000120056 s/step
# Meep progress: 765.621/2090.0 = 36.6% done in 92.0s, 159.1s to go
# on time step 765807 (time=765.807), 0.000119481 s/step
# Meep progress: 799.2230000000001/2090.0 = 38.2% done in 96.0s, 155.0s to go
# on time step 799392 (time=799.392), 0.000119102 s/step
# Meep progress: 832.787/2090.0 = 39.8% done in 100.0s, 151.0s to go
# on time step 832960 (time=832.96), 0.000119163 s/step
# Meep progress: 865.538/2090.0 = 41.4% done in 104.0s, 147.1s to go
# on time step 865745 (time=865.745), 0.000122008 s/step
# Meep progress: 898.642/2090.0 = 43.0% done in 108.0s, 143.2s to go
# on time step 898856 (time=898.856), 0.000120808 s/step
# Meep progress: 931.873/2090.0 = 44.6% done in 112.0s, 139.2s to go
# on time step 932083 (time=932.083), 0.000120386 s/step
# Meep progress: 965.832/2090.0 = 46.2% done in 116.0s, 135.0s to go
# on time step 966046 (time=966.046), 0.000117778 s/step
# Meep progress: 999.283/2090.0 = 47.8% done in 120.0s, 131.0s to go
# on time step 999481 (time=999.481), 0.000119637 s/step
# Meep progress: 1032.141/2090.0 = 49.4% done in 124.0s, 127.1s to go
# on time step 1032380 (time=1032.38), 0.000121586 s/step
# Meep progress: 1064.765/2090.0 = 50.9% done in 128.0s, 123.2s to go
# on time step 1065010 (time=1065.01), 0.000122588 s/step
# Meep progress: 1098.3500000000001/2090.0 = 52.6% done in 132.0s, 119.2s to go
# on time step 1098582 (time=1098.58), 0.000119148 s/step
# Meep progress: 1132.1970000000001/2090.0 = 54.2% done in 136.0s, 115.1s to go
# on time step 1132419 (time=1132.42), 0.000118215 s/step
# Meep progress: 1166.186/2090.0 = 55.8% done in 140.0s, 110.9s to go
# on time step 1166444 (time=1166.44), 0.000117561 s/step
# Meep progress: 1199.626/2090.0 = 57.4% done in 144.0s, 106.9s to go
# on time step 1199891 (time=1199.89), 0.000119595 s/step
# Meep progress: 1233.233/2090.0 = 59.0% done in 148.0s, 102.8s to go
# on time step 1233495 (time=1233.5), 0.000119036 s/step
# Meep progress: 1267.252/2090.0 = 60.6% done in 152.0s, 98.7s to go
# on time step 1267523 (time=1267.52), 0.000117551 s/step
# Meep progress: 1300.984/2090.0 = 62.2% done in 156.0s, 94.6s to go
# on time step 1301241 (time=1301.24), 0.000118633 s/step
# Meep progress: 1334.766/2090.0 = 63.9% done in 160.0s, 90.5s to go
# on time step 1335045 (time=1335.05), 0.000118332 s/step
# Meep progress: 1367.593/2090.0 = 65.4% done in 164.0s, 86.6s to go
# on time step 1367889 (time=1367.89), 0.000121791 s/step
# Meep progress: 1401.249/2090.0 = 67.0% done in 168.0s, 82.6s to go
# on time step 1401543 (time=1401.54), 0.000118859 s/step
# Meep progress: 1434.814/2090.0 = 68.7% done in 172.0s, 78.5s to go
# on time step 1435109 (time=1435.11), 0.000119171 s/step
# Meep progress: 1468.748/2090.0 = 70.3% done in 176.0s, 74.4s to go
# on time step 1469049 (time=1469.05), 0.000117857 s/step
# Meep progress: 1502.253/2090.0 = 71.9% done in 180.0s, 70.4s to go
# on time step 1502553 (time=1502.55), 0.000119389 s/step
# Meep progress: 1534.835/2090.0 = 73.4% done in 184.0s, 66.6s to go
# on time step 1535156 (time=1535.16), 0.000122691 s/step
# Meep progress: 1567.603/2090.0 = 75.0% done in 188.0s, 62.7s to go
# on time step 1567934 (time=1567.93), 0.000122033 s/step
# Meep progress: 1600.337/2090.0 = 76.6% done in 192.0s, 58.7s to go
# on time step 1600649 (time=1600.65), 0.000122271 s/step
# Meep progress: 1634.311/2090.0 = 78.2% done in 196.0s, 54.7s to go
# on time step 1634649 (time=1634.65), 0.000117647 s/step
# Meep progress: 1668.094/2090.0 = 79.8% done in 200.0s, 50.6s to go
# on time step 1668439 (time=1668.44), 0.000118381 s/step
# Meep progress: 1701.627/2090.0 = 81.4% done in 204.0s, 46.6s to go
# on time step 1701958 (time=1701.96), 0.000119338 s/step
# Meep progress: 1734.9460000000001/2090.0 = 83.0% done in 208.0s, 42.6s to go
# on time step 1735300 (time=1735.3), 0.000119969 s/step
# Meep progress: 1768.22/2090.0 = 84.6% done in 212.0s, 38.6s to go
# on time step 1768575 (time=1768.58), 0.000120211 s/step
# Meep progress: 1802.25/2090.0 = 86.2% done in 216.0s, 34.5s to go
# on time step 1802607 (time=1802.61), 0.000117537 s/step
# Meep progress: 1835.674/2090.0 = 87.8% done in 220.0s, 30.5s to go
# on time step 1836054 (time=1836.05), 0.000119595 s/step
# Meep progress: 1868.738/2090.0 = 89.4% done in 224.0s, 26.5s to go
# on time step 1869115 (time=1869.12), 0.000120989 s/step
# Meep progress: 1902.477/2090.0 = 91.0% done in 228.0s, 22.5s to go
# on time step 1902854 (time=1902.85), 0.000118559 s/step
# Meep progress: 1935.635/2090.0 = 92.6% done in 232.0s, 18.5s to go
# on time step 1935998 (time=1936), 0.000120687 s/step
# Meep progress: 1969.449/2090.0 = 94.2% done in 236.0s, 14.4s to go
# on time step 1969828 (time=1969.83), 0.000118239 s/step
# Meep progress: 2003.327/2090.0 = 95.9% done in 240.0s, 10.4s to go
# on time step 2003731 (time=2003.73), 0.000117986 s/step
# Meep progress: 2037.2920000000001/2090.0 = 97.5% done in 244.0s, 6.3s to go
# on time step 2037637 (time=2037.64), 0.000117974 s/step
# Meep progress: 2070.862/2090.0 = 99.1% done in 248.0s, 2.3s to go
# on time step 2071265 (time=2071.26), 0.000118949 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 95%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000900984 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 3.02 with resolution 1000
#      block, center = (0,0,-0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,0.26)
#           size (0,0,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000956059 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 33.046/2090.0 = 1.6% done in 4.0s, 249.0s to go
# on time step 33129 (time=33.129), 0.00012074 s/step
# Meep progress: 66.926/2090.0 = 3.2% done in 8.0s, 241.8s to go
# on time step 67026 (time=67.026), 0.000118005 s/step
# Meep progress: 99.883/2090.0 = 4.8% done in 12.0s, 239.1s to go
# on time step 99987 (time=99.987), 0.000121356 s/step
# Meep progress: 132.734/2090.0 = 6.4% done in 16.0s, 235.9s to go
# on time step 132837 (time=132.837), 0.00012177 s/step
# Meep progress: 166.219/2090.0 = 8.0% done in 20.0s, 231.5s to go
# on time step 166332 (time=166.332), 0.000119424 s/step
# Meep progress: 200.617/2090.0 = 9.6% done in 24.0s, 226.0s to go
# on time step 200721 (time=200.721), 0.000116319 s/step
# Meep progress: 234.799/2090.0 = 11.2% done in 28.0s, 221.2s to go
# on time step 234927 (time=234.927), 0.000116939 s/step
# Meep progress: 267.99/2090.0 = 12.8% done in 32.0s, 217.6s to go
# on time step 268123 (time=268.123), 0.000120499 s/step
# Meep progress: 301.936/2090.0 = 14.4% done in 36.0s, 213.2s to go
# on time step 302069 (time=302.069), 0.000117837 s/step
# Meep progress: 335.48/2090.0 = 16.1% done in 40.0s, 209.2s to go
# on time step 335620 (time=335.62), 0.000119224 s/step
# Meep progress: 369.60200000000003/2090.0 = 17.7% done in 44.0s, 204.8s to go
# on time step 369740 (time=369.74), 0.000117235 s/step
# Meep progress: 403.33500000000004/2090.0 = 19.3% done in 48.0s, 200.7s to go
# on time step 403489 (time=403.489), 0.000118524 s/step
# Meep progress: 436.296/2090.0 = 20.9% done in 52.0s, 197.1s to go
# on time step 436456 (time=436.456), 0.000121335 s/step
# Meep progress: 469.449/2090.0 = 22.5% done in 56.0s, 193.3s to go
# on time step 469604 (time=469.604), 0.000120675 s/step
# Meep progress: 503.22700000000003/2090.0 = 24.1% done in 60.0s, 189.2s to go
# on time step 503379 (time=503.379), 0.000118434 s/step
# Meep progress: 536.821/2090.0 = 25.7% done in 64.0s, 185.2s to go
# on time step 536976 (time=536.976), 0.000119073 s/step
# Meep progress: 570.532/2090.0 = 27.3% done in 68.0s, 181.1s to go
# on time step 570724 (time=570.724), 0.000118527 s/step
# Meep progress: 604.2760000000001/2090.0 = 28.9% done in 72.0s, 177.0s to go
# on time step 604471 (time=604.471), 0.00011853 s/step
# Meep progress: 639.934/2090.0 = 30.6% done in 76.0s, 172.2s to go
# on time step 640137 (time=640.137), 0.000112153 s/step
# Meep progress: 675.671/2090.0 = 32.3% done in 80.0s, 167.5s to go
# on time step 675880 (time=675.88), 0.000111915 s/step
# Meep progress: 711.48/2090.0 = 34.0% done in 84.0s, 162.8s to go
# on time step 711696 (time=711.696), 0.000111685 s/step
# Meep progress: 746.89/2090.0 = 35.7% done in 88.0s, 158.3s to go
# on time step 747117 (time=747.117), 0.00011293 s/step
# Meep progress: 782.476/2090.0 = 37.4% done in 92.0s, 153.7s to go
# on time step 782701 (time=782.701), 0.000112416 s/step
# Meep progress: 818.369/2090.0 = 39.2% done in 96.0s, 149.2s to go
# on time step 818599 (time=818.599), 0.000111427 s/step
# Meep progress: 854.147/2090.0 = 40.9% done in 100.0s, 144.7s to go
# on time step 854380 (time=854.38), 0.000111794 s/step
# Meep progress: 889.775/2090.0 = 42.6% done in 104.0s, 140.3s to go
# on time step 890021 (time=890.021), 0.000112232 s/step
# Meep progress: 925.633/2090.0 = 44.3% done in 108.0s, 135.9s to go
# on time step 925884 (time=925.884), 0.000111537 s/step
# Meep progress: 961.4730000000001/2090.0 = 46.0% done in 112.0s, 131.5s to go
# on time step 961731 (time=961.731), 0.000111588 s/step
# Meep progress: 997.1750000000001/2090.0 = 47.7% done in 116.0s, 127.1s to go
# on time step 997420 (time=997.42), 0.000112081 s/step
# Meep progress: 1032.945/2090.0 = 49.4% done in 120.0s, 122.8s to go
# on time step 1033216 (time=1033.22), 0.000111745 s/step
# Meep progress: 1068.828/2090.0 = 51.1% done in 124.0s, 118.5s to go
# on time step 1069101 (time=1069.1), 0.00011147 s/step
# Meep progress: 1104.535/2090.0 = 52.8% done in 128.0s, 114.2s to go
# on time step 1104806 (time=1104.81), 0.000112032 s/step
# Meep progress: 1140.313/2090.0 = 54.6% done in 132.0s, 109.9s to go
# on time step 1140596 (time=1140.6), 0.000111766 s/step
# Meep progress: 1176.2640000000001/2090.0 = 56.3% done in 136.0s, 105.6s to go
# on time step 1176545 (time=1176.55), 0.00011127 s/step
# Meep progress: 1212.073/2090.0 = 58.0% done in 140.0s, 101.4s to go
# on time step 1212360 (time=1212.36), 0.000111687 s/step
# Meep progress: 1247.429/2090.0 = 59.7% done in 144.0s, 97.3s to go
# on time step 1247726 (time=1247.73), 0.000113105 s/step
# Meep progress: 1283.1680000000001/2090.0 = 61.4% done in 148.0s, 93.1s to go
# on time step 1283470 (time=1283.47), 0.000111908 s/step
# Meep progress: 1318.994/2090.0 = 63.1% done in 152.0s, 88.9s to go
# on time step 1319303 (time=1319.3), 0.000111632 s/step
# Meep progress: 1354.7730000000001/2090.0 = 64.8% done in 156.0s, 84.7s to go
# on time step 1355044 (time=1355.04), 0.000111919 s/step
# Meep progress: 1390.4370000000001/2090.0 = 66.5% done in 160.0s, 80.5s to go
# on time step 1390757 (time=1390.76), 0.000112005 s/step
# Meep progress: 1426.138/2090.0 = 68.2% done in 164.0s, 76.3s to go
# on time step 1426455 (time=1426.45), 0.000112053 s/step
# Meep progress: 1461.817/2090.0 = 69.9% done in 168.0s, 72.2s to go
# on time step 1462144 (time=1462.14), 0.00011208 s/step
# Meep progress: 1497.3/2090.0 = 71.6% done in 172.0s, 68.1s to go
# on time step 1497628 (time=1497.63), 0.000112729 s/step
# Meep progress: 1532.88/2090.0 = 73.3% done in 176.0s, 64.0s to go
# on time step 1533221 (time=1533.22), 0.000112383 s/step
# Meep progress: 1568.568/2090.0 = 75.1% done in 180.0s, 59.8s to go
# on time step 1568912 (time=1568.91), 0.000112075 s/step
# Meep progress: 1604.345/2090.0 = 76.8% done in 184.0s, 55.7s to go
# on time step 1604583 (time=1604.58), 0.000112139 s/step
# Meep progress: 1639.476/2090.0 = 78.4% done in 188.0s, 51.7s to go
# on time step 1639831 (time=1639.83), 0.000113482 s/step
# Meep progress: 1675.131/2090.0 = 80.1% done in 192.0s, 47.6s to go
# on time step 1675491 (time=1675.49), 0.000112171 s/step
# Meep progress: 1710.986/2090.0 = 81.9% done in 196.0s, 43.4s to go
# on time step 1711356 (time=1711.36), 0.000111532 s/step
# Meep progress: 1746.431/2090.0 = 83.6% done in 200.0s, 39.3s to go
# on time step 1746806 (time=1746.81), 0.000112837 s/step
# Meep progress: 1782.015/2090.0 = 85.3% done in 204.0s, 35.3s to go
# on time step 1782357 (time=1782.36), 0.000112516 s/step
# Meep progress: 1817.683/2090.0 = 87.0% done in 208.0s, 31.2s to go
# on time step 1818067 (time=1818.07), 0.000112014 s/step
# Meep progress: 1853.189/2090.0 = 88.7% done in 212.0s, 27.1s to go
# on time step 1853571 (time=1853.57), 0.000112665 s/step
# Meep progress: 1888.717/2090.0 = 90.4% done in 216.0s, 23.0s to go
# on time step 1889116 (time=1889.12), 0.000112535 s/step
# Meep progress: 1924.387/2090.0 = 92.1% done in 220.0s, 18.9s to go
# on time step 1924787 (time=1924.79), 0.000112136 s/step
# Meep progress: 1960.102/2090.0 = 93.8% done in 224.0s, 14.8s to go
# on time step 1960509 (time=1960.51), 0.000111976 s/step
# Meep progress: 1995.607/2090.0 = 95.5% done in 228.0s, 10.8s to go
# on time step 1996006 (time=1996.01), 0.000112687 s/step
# Meep progress: 2031.338/2090.0 = 97.2% done in 232.0s, 6.7s to go
# on time step 2031739 (time=2031.74), 0.000111943 s/step
# Meep progress: 2067.091/2090.0 = 98.9% done in 236.0s, 2.6s to go
# on time step 2067511 (time=2067.51), 0.000111821 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)

# %%
plt.figure(dpi=150)
freqs = np.linspace(0,30e15,1000)
plt.plot(freqs,Efavg*tsim*eps0*4*np.pi/2**21,'g''.')
plt.xlim(4e15,20e15)
plt.yscale("log")
plt.ylim(0.1e-28,400e-28)
plt.grid()
plt.savefig('test_detector_photonic_crystal_30000.png')
plt.show()

np.savez("test_custom_source_photonic_crystal_30000.npz", Efavg_30000 = Efavg)

# %%
from PIL import Image

def transPNG(srcImageName, dstImageName):
    img = Image.open(srcImageName)
    img = img.convert("RGBA")
    datas = img.getdata()
    newData = list()
    for item in datas:
        if item[0] > 225 and item[1] > 225 and item[2] > 225:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
            
    img.putdata(newData)
    img.save(dstImageName, "PNG")
transPNG('test_detector_photonic_crystal_30000.png','trans_test_detector_photonic_crystal_30000.png')
