# %%
##########################################################複製區塊
# import numpy as np
import matplotlib.pyplot as plt
import time
from scipy import signal
from time import sleep
import sys
import meep as mp
import numpy as np

#setup some constants and parameters
M=2**21
tsim=7e-12
eps0 = 8.854187e-12
hbar = 1.05457182e-34
c = 2.99792458e8
kb = 1.380649e-23
hdk=7.63823258e-12
deltap = np.sqrt(1/3/eps0/hbar/c)*kb
T=50000
frq_min = 0
frq_max = 3/2/np.pi
nfreq = 1000
fcen = (frq_min + frq_max)/2
df = frq_max - frq_min
#define square root of Dn function
def Dnsqt(wla,T):
    return np.sqrt(6*hdk**2*wla/(np.exp(hdk*wla/T)-1)/T**2/np.pi)

#generate an array of the square root of Dn function
Dsqt = []
for n in range(1,M):
    Dsqt.append(Dnsqt(2*np.pi*n/tsim,T))

#define how many times to run to average the results
Ncomp= 10
nfreq =  1000
#define the starting sum of the result
Efsum = np.zeros(nfreq)
Ens = np.zeros(2*22)
resolution = 1000
dA = 1
dB = 2.4
dpml = 1.0
sz = dpml*2+dA*2+dB
cell = mp.Vector3(0, 0, sz)
pml_layers = [mp.PML(dpml)]



for i in range(Ncomp):
    
    def random_En(t):
        #generate random numbers
        M0 = np.random.normal(0,1)
        Mlp = np.random.normal(0,1,M-1)
        Nlp = np.random.normal(0,1,M-1)
        MM = np.random.normal(0,1)
    
        #generate the array of the fourier transform of E field, we generate l=0 and l=-M separately. 
        #for l=1 to M-1 and l=-1 to -(M-1) are conjutated to each other. 
        #we contruct the whole array by gluing them together by the order from l=0 -> l=M-1 -> l=-M -> l=-(m-1) -> l=-1
        Ef0 = np.array([M0*np.sqrt(6*hdk/np.pi/T)])
        Eflp = np.multiply((Mlp + 1j*Nlp), Dsqt)
        Eflm = np.flip(np.conjugate(Eflp))
        EfM = np.array([MM*Dnsqt(2*np.pi*M/tsim,T)])
        Ef = np.hstack((Ef0,Eflp,EfM,Eflm))
    
        #we normalize Ef and compute its inverse fast fourier transform
        Efn = deltap*T/np.sqrt(tsim)*Ef
        En = np.fft.ifft(Efn)*M
        return En
    En0 = random_En(1)
    En1 = random_En(1)
    
    #generate some feedback to check the progress of the loop
    x = i/Ncomp*100
    sys.stdout.write('\r')
    sys.stdout.write("[%-20s] %d%%" % ('a'*int(x), int(x)))
    sys.stdout.flush()
    sleep(0.0001)
    
    
    def source0(t):
        f = int(t*2000)
        return En0[f]
    def source1(t):
        f = int(t*2000)
        return En1[f]


    sources = [mp.Source(mp.CustomSource(src_func=source0),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,-0.5*sz+dpml),
                     ),
              mp.Source(mp.CustomSource(src_func=source1),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,0.5*sz-dpml),
                     )]
    
    def BlockAB(N, center):
        geometry = []
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,0-dA/2-dB/2),
                     material=mp.Medium(epsilon=1)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dB),
                     center=mp.Vector3(0,0,0),
                     material=mp.Medium(epsilon=36)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(0,0,dA),
                     center=mp.Vector3(0,0,dB/2+dA/2),
                     material=mp.Medium(epsilon=1)))
        geometry = geometry.tolist()
        return geometry
    sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    sources=sources,   
                    dimensions = 1,
                    Courant = 1,
                    resolution=resolution,
                    geometry=BlockAB(1,0))
    

    # transmitted flux
    tran_fr = mp.FluxRegion(center=mp.Vector3(0,0,0.1))
    tran = sim.add_energy(fcen, df, nfreq, tran_fr)
    
    
    sim.run(until=2090)

    tran_flux = mp.get_magnetic_energy(tran)
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts,tran_flux[i])    
    Efsum += Ts
    
    

#average the final result
Efavg = Efsum/Ncomp

#save data to some file or reload file to write more data on it
# Out:
# [                    ] 0%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000566959 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00258183 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 34.341/2090.0 = 1.6% done in 4.0s, 239.4s to go
# on time step 34586 (time=34.586), 0.000115656 s/step
# Meep progress: 68.609/2090.0 = 3.3% done in 8.0s, 235.7s to go
# on time step 68861 (time=68.861), 0.000116706 s/step
# Meep progress: 102.996/2090.0 = 4.9% done in 12.0s, 231.5s to go
# on time step 103252 (time=103.252), 0.00011631 s/step
# Meep progress: 137.334/2090.0 = 6.6% done in 16.0s, 227.5s to go
# on time step 137593 (time=137.593), 0.00011648 s/step
# Meep progress: 171.791/2090.0 = 8.2% done in 20.0s, 223.3s to go
# on time step 172055 (time=172.055), 0.000116072 s/step
# Meep progress: 206.167/2090.0 = 9.9% done in 24.0s, 219.3s to go
# on time step 206432 (time=206.432), 0.000116359 s/step
# Meep progress: 239.931/2090.0 = 11.5% done in 28.0s, 215.9s to go
# on time step 240202 (time=240.202), 0.00011845 s/step
# Meep progress: 273.759/2090.0 = 13.1% done in 32.0s, 212.3s to go
# on time step 274035 (time=274.035), 0.000118231 s/step
# Meep progress: 307.41700000000003/2090.0 = 14.7% done in 36.0s, 208.8s to go
# on time step 307672 (time=307.672), 0.000118921 s/step
# Meep progress: 341.375/2090.0 = 16.3% done in 40.0s, 204.9s to go
# on time step 341684 (time=341.684), 0.000117608 s/step
# Meep progress: 375.563/2090.0 = 18.0% done in 44.0s, 200.9s to go
# on time step 375862 (time=375.862), 0.000117036 s/step
# Meep progress: 409.75100000000003/2090.0 = 19.6% done in 48.0s, 196.8s to go
# on time step 410062 (time=410.062), 0.000116959 s/step
# Meep progress: 443.06/2090.0 = 21.2% done in 52.0s, 193.3s to go
# on time step 443376 (time=443.376), 0.000120072 s/step
# Meep progress: 474.475/2090.0 = 22.7% done in 56.0s, 190.7s to go
# on time step 474783 (time=474.783), 0.000127361 s/step
# Meep progress: 507.83/2090.0 = 24.3% done in 60.0s, 186.9s to go
# on time step 508146 (time=508.146), 0.000119894 s/step
# Meep progress: 542.08/2090.0 = 25.9% done in 64.0s, 182.8s to go
# on time step 542408 (time=542.408), 0.00011675 s/step
# Meep progress: 576.368/2090.0 = 27.6% done in 68.0s, 178.6s to go
# on time step 576708 (time=576.708), 0.000116619 s/step
# Meep progress: 609.64/2090.0 = 29.2% done in 72.0s, 174.8s to go
# on time step 609940 (time=609.94), 0.000120369 s/step
# Meep progress: 641.486/2090.0 = 30.7% done in 76.0s, 171.6s to go
# on time step 641841 (time=641.841), 0.000125389 s/step
# Meep progress: 674.504/2090.0 = 32.3% done in 80.0s, 167.9s to go
# on time step 674855 (time=674.855), 0.000121164 s/step
# Meep progress: 708.333/2090.0 = 33.9% done in 84.0s, 163.9s to go
# on time step 708686 (time=708.686), 0.000118235 s/step
# Meep progress: 742.373/2090.0 = 35.5% done in 88.0s, 159.7s to go
# on time step 742736 (time=742.736), 0.000117475 s/step
# Meep progress: 776.399/2090.0 = 37.1% done in 92.0s, 155.7s to go
# on time step 776778 (time=776.778), 0.000117503 s/step
# Meep progress: 805.729/2090.0 = 38.6% done in 96.0s, 153.0s to go
# on time step 806098 (time=806.098), 0.000136427 s/step
# Meep progress: 837.515/2090.0 = 40.1% done in 100.0s, 149.6s to go
# on time step 837889 (time=837.889), 0.000125824 s/step
# Meep progress: 868.2810000000001/2090.0 = 41.5% done in 104.0s, 146.3s to go
# on time step 868655 (time=868.655), 0.000130017 s/step
# Meep progress: 899.341/2090.0 = 43.0% done in 108.0s, 143.0s to go
# on time step 899723 (time=899.723), 0.000128752 s/step
# Meep progress: 931.903/2090.0 = 44.6% done in 112.0s, 139.2s to go
# on time step 932292 (time=932.292), 0.000122819 s/step
# Meep progress: 965.354/2090.0 = 46.2% done in 116.0s, 135.1s to go
# on time step 965493 (time=965.493), 0.000120482 s/step
# Meep progress: 996.972/2090.0 = 47.7% done in 120.0s, 131.6s to go
# on time step 997345 (time=997.345), 0.000125581 s/step
# Meep progress: 1030.528/2090.0 = 49.3% done in 124.0s, 127.5s to go
# on time step 1030932 (time=1030.93), 0.000119097 s/step
# Meep progress: 1064.44/2090.0 = 50.9% done in 128.0s, 123.3s to go
# on time step 1064867 (time=1064.87), 0.000117873 s/step
# Meep progress: 1098.507/2090.0 = 52.6% done in 132.0s, 119.1s to go
# on time step 1098942 (time=1098.94), 0.000117389 s/step
# Meep progress: 1132.938/2090.0 = 54.2% done in 136.0s, 114.9s to go
# on time step 1133378 (time=1133.38), 0.000116159 s/step
# Meep progress: 1167.188/2090.0 = 55.8% done in 140.0s, 110.7s to go
# on time step 1167619 (time=1167.62), 0.000116821 s/step
# Meep progress: 1201.041/2090.0 = 57.5% done in 144.0s, 106.6s to go
# on time step 1201479 (time=1201.48), 0.000118136 s/step
# Meep progress: 1235.229/2090.0 = 59.1% done in 148.0s, 102.4s to go
# on time step 1235680 (time=1235.68), 0.000116959 s/step
# Meep progress: 1269.099/2090.0 = 60.7% done in 152.0s, 98.3s to go
# on time step 1269546 (time=1269.55), 0.000118113 s/step
# Meep progress: 1303.318/2090.0 = 62.4% done in 156.0s, 94.2s to go
# on time step 1303774 (time=1303.77), 0.000116865 s/step
# Meep progress: 1337.226/2090.0 = 64.0% done in 160.0s, 90.1s to go
# on time step 1337681 (time=1337.68), 0.000117971 s/step
# Meep progress: 1371.51/2090.0 = 65.6% done in 164.0s, 85.9s to go
# on time step 1371961 (time=1371.96), 0.000116687 s/step
# Meep progress: 1405.3990000000001/2090.0 = 67.2% done in 168.0s, 81.8s to go
# on time step 1405879 (time=1405.88), 0.000117935 s/step
# Meep progress: 1439.589/2090.0 = 68.9% done in 172.0s, 77.7s to go
# on time step 1440072 (time=1440.07), 0.000116983 s/step
# Meep progress: 1473.914/2090.0 = 70.5% done in 176.0s, 73.6s to go
# on time step 1474404 (time=1474.4), 0.000116511 s/step
# Meep progress: 1507.699/2090.0 = 72.1% done in 180.0s, 69.5s to go
# on time step 1508135 (time=1508.13), 0.000118587 s/step
# Meep progress: 1541.79/2090.0 = 73.8% done in 184.0s, 65.4s to go
# on time step 1542266 (time=1542.27), 0.000117196 s/step
# Meep progress: 1575.8700000000001/2090.0 = 75.4% done in 188.0s, 61.3s to go
# on time step 1576373 (time=1576.37), 0.00011728 s/step
# Meep progress: 1609.762/2090.0 = 77.0% done in 192.0s, 57.3s to go
# on time step 1610266 (time=1610.27), 0.000118019 s/step
# Meep progress: 1644.154/2090.0 = 78.7% done in 196.0s, 53.2s to go
# on time step 1644667 (time=1644.67), 0.000116278 s/step
# Meep progress: 1677.855/2090.0 = 80.3% done in 200.0s, 49.1s to go
# on time step 1678341 (time=1678.34), 0.000118788 s/step
# Meep progress: 1712.355/2090.0 = 81.9% done in 204.0s, 45.0s to go
# on time step 1712864 (time=1712.86), 0.000115868 s/step
# Meep progress: 1746.797/2090.0 = 83.6% done in 208.0s, 40.9s to go
# on time step 1747317 (time=1747.32), 0.000116101 s/step
# Meep progress: 1779.833/2090.0 = 85.2% done in 212.0s, 36.9s to go
# on time step 1780354 (time=1780.35), 0.000121077 s/step
# Meep progress: 1814.251/2090.0 = 86.8% done in 216.0s, 32.8s to go
# on time step 1814769 (time=1814.77), 0.000116232 s/step
# Meep progress: 1848.423/2090.0 = 88.4% done in 220.0s, 28.8s to go
# on time step 1848947 (time=1848.95), 0.000117036 s/step
# Meep progress: 1881.938/2090.0 = 90.0% done in 224.0s, 24.8s to go
# on time step 1882459 (time=1882.46), 0.000119362 s/step
# Meep progress: 1914.9460000000001/2090.0 = 91.6% done in 228.0s, 20.8s to go
# on time step 1915453 (time=1915.45), 0.000121236 s/step
# Meep progress: 1948.848/2090.0 = 93.2% done in 232.0s, 16.8s to go
# on time step 1949380 (time=1949.38), 0.000117903 s/step
# Meep progress: 1982.882/2090.0 = 94.9% done in 236.0s, 12.7s to go
# on time step 1983420 (time=1983.42), 0.000117509 s/step
# Meep progress: 2016.8020000000001/2090.0 = 96.5% done in 240.0s, 8.7s to go
# on time step 2017340 (time=2017.34), 0.000117928 s/step
# Meep progress: 2050.195/2090.0 = 98.1% done in 244.0s, 4.7s to go
# on time step 2050721 (time=2050.72), 0.000119831 s/step
# Meep progress: 2082.843/2090.0 = 99.7% done in 248.0s, 0.9s to go
# on time step 2083387 (time=2083.39), 0.000122452 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaa          ] 10%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000822783 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00249791 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 32.268/2090.0 = 1.5% done in 4.0s, 255.1s to go
# on time step 32322 (time=32.322), 0.000123758 s/step
# Meep progress: 64.571/2090.0 = 3.1% done in 8.0s, 250.9s to go
# on time step 64634 (time=64.634), 0.000123795 s/step
# Meep progress: 97.996/2090.0 = 4.7% done in 12.0s, 243.9s to go
# on time step 98066 (time=98.066), 0.000119648 s/step
# Meep progress: 130.577/2090.0 = 6.2% done in 16.0s, 240.1s to go
# on time step 130668 (time=130.668), 0.000122694 s/step
# Meep progress: 163.54/2090.0 = 7.8% done in 20.0s, 235.6s to go
# on time step 163632 (time=163.632), 0.000121345 s/step
# Meep progress: 196.447/2090.0 = 9.4% done in 24.0s, 231.3s to go
# on time step 196547 (time=196.547), 0.000121528 s/step
# Meep progress: 229.221/2090.0 = 11.0% done in 28.0s, 227.3s to go
# on time step 229306 (time=229.306), 0.000122105 s/step
# Meep progress: 261.835/2090.0 = 12.5% done in 32.0s, 223.4s to go
# on time step 261938 (time=261.938), 0.000122581 s/step
# Meep progress: 294.764/2090.0 = 14.1% done in 36.0s, 219.3s to go
# on time step 294879 (time=294.879), 0.000121431 s/step
# Meep progress: 326.933/2090.0 = 15.6% done in 40.0s, 215.7s to go
# on time step 327054 (time=327.054), 0.00012432 s/step
# Meep progress: 360.354/2090.0 = 17.2% done in 44.0s, 211.2s to go
# on time step 360470 (time=360.47), 0.000119704 s/step
# Meep progress: 394.546/2090.0 = 18.9% done in 48.0s, 206.3s to go
# on time step 394687 (time=394.687), 0.000116904 s/step
# Meep progress: 428.90500000000003/2090.0 = 20.5% done in 52.0s, 201.4s to go
# on time step 429053 (time=429.053), 0.000116397 s/step
# Meep progress: 463.321/2090.0 = 22.2% done in 56.0s, 196.6s to go
# on time step 463473 (time=463.473), 0.000116212 s/step
# Meep progress: 497.68600000000004/2090.0 = 23.8% done in 60.0s, 192.0s to go
# on time step 497846 (time=497.846), 0.000116373 s/step
# Meep progress: 532.004/2090.0 = 25.5% done in 64.0s, 187.4s to go
# on time step 532164 (time=532.164), 0.000116559 s/step
# Meep progress: 565.717/2090.0 = 27.1% done in 68.0s, 183.2s to go
# on time step 565879 (time=565.879), 0.000118642 s/step
# Meep progress: 599.226/2090.0 = 28.7% done in 72.0s, 179.1s to go
# on time step 599383 (time=599.383), 0.000119392 s/step
# Meep progress: 632.349/2090.0 = 30.3% done in 76.0s, 175.2s to go
# on time step 632527 (time=632.527), 0.000120689 s/step
# Meep progress: 665.991/2090.0 = 31.9% done in 80.0s, 171.1s to go
# on time step 666171 (time=666.171), 0.000118894 s/step
# Meep progress: 699.15/2090.0 = 33.5% done in 84.0s, 167.1s to go
# on time step 699342 (time=699.342), 0.000120588 s/step
# Meep progress: 732.88/2090.0 = 35.1% done in 88.0s, 163.0s to go
# on time step 733075 (time=733.075), 0.000118581 s/step
# Meep progress: 765.971/2090.0 = 36.6% done in 92.0s, 159.0s to go
# on time step 766169 (time=766.169), 0.000120871 s/step
# Meep progress: 799.765/2090.0 = 38.3% done in 96.0s, 154.9s to go
# on time step 799970 (time=799.97), 0.000118341 s/step
# Meep progress: 833.705/2090.0 = 39.9% done in 100.0s, 150.7s to go
# on time step 833901 (time=833.901), 0.000117889 s/step
# Meep progress: 867.701/2090.0 = 41.5% done in 104.0s, 146.5s to go
# on time step 867908 (time=867.908), 0.000117625 s/step
# Meep progress: 900.947/2090.0 = 43.1% done in 108.0s, 142.5s to go
# on time step 901167 (time=901.167), 0.000120271 s/step
# Meep progress: 934.918/2090.0 = 44.7% done in 112.0s, 138.4s to go
# on time step 935144 (time=935.144), 0.000117729 s/step
# Meep progress: 968.644/2090.0 = 46.3% done in 116.0s, 134.3s to go
# on time step 968858 (time=968.858), 0.000118647 s/step
# Meep progress: 1002.807/2090.0 = 48.0% done in 120.0s, 130.1s to go
# on time step 1003032 (time=1003.03), 0.00011705 s/step
# Meep progress: 1036.442/2090.0 = 49.6% done in 124.0s, 126.0s to go
# on time step 1036678 (time=1036.68), 0.000118885 s/step
# Meep progress: 1070.835/2090.0 = 51.2% done in 128.0s, 121.8s to go
# on time step 1071077 (time=1071.08), 0.000116283 s/step
# Meep progress: 1105.309/2090.0 = 52.9% done in 132.0s, 117.6s to go
# on time step 1105557 (time=1105.56), 0.000116011 s/step
# Meep progress: 1139.67/2090.0 = 54.5% done in 136.0s, 113.4s to go
# on time step 1139915 (time=1139.91), 0.000116424 s/step
# Meep progress: 1173.796/2090.0 = 56.2% done in 140.0s, 109.3s to go
# on time step 1174050 (time=1174.05), 0.000117184 s/step
# Meep progress: 1208.332/2090.0 = 57.8% done in 144.0s, 105.1s to go
# on time step 1208588 (time=1208.59), 0.000115816 s/step
# Meep progress: 1241.108/2090.0 = 59.4% done in 148.0s, 101.2s to go
# on time step 1241366 (time=1241.37), 0.000122034 s/step
# Meep progress: 1275.027/2090.0 = 61.0% done in 152.0s, 97.2s to go
# on time step 1275297 (time=1275.3), 0.000117887 s/step
# Meep progress: 1308.906/2090.0 = 62.6% done in 156.0s, 93.1s to go
# on time step 1309180 (time=1309.18), 0.000118055 s/step
# Meep progress: 1342.828/2090.0 = 64.3% done in 160.0s, 89.0s to go
# on time step 1343098 (time=1343.1), 0.000117934 s/step
# Meep progress: 1376.397/2090.0 = 65.9% done in 164.0s, 85.0s to go
# on time step 1376671 (time=1376.67), 0.000119146 s/step
# Meep progress: 1409.776/2090.0 = 67.5% done in 168.0s, 81.1s to go
# on time step 1410074 (time=1410.07), 0.000119752 s/step
# Meep progress: 1443.747/2090.0 = 69.1% done in 172.0s, 77.0s to go
# on time step 1444051 (time=1444.05), 0.000117727 s/step
# Meep progress: 1477.614/2090.0 = 70.7% done in 176.0s, 72.9s to go
# on time step 1477898 (time=1477.9), 0.000118182 s/step
# Meep progress: 1511.544/2090.0 = 72.3% done in 180.0s, 68.9s to go
# on time step 1511846 (time=1511.85), 0.000117828 s/step
# Meep progress: 1545.426/2090.0 = 73.9% done in 184.0s, 64.8s to go
# on time step 1545734 (time=1545.73), 0.00011804 s/step
# Meep progress: 1579.132/2090.0 = 75.6% done in 188.0s, 60.8s to go
# on time step 1579457 (time=1579.46), 0.000118617 s/step
# Meep progress: 1612.624/2090.0 = 77.2% done in 192.0s, 56.8s to go
# on time step 1612938 (time=1612.94), 0.000119474 s/step
# Meep progress: 1645.607/2090.0 = 78.7% done in 196.0s, 52.9s to go
# on time step 1645927 (time=1645.93), 0.000121256 s/step
# Meep progress: 1679.124/2090.0 = 80.3% done in 200.0s, 48.9s to go
# on time step 1679453 (time=1679.45), 0.000119312 s/step
# Meep progress: 1712.747/2090.0 = 81.9% done in 204.0s, 44.9s to go
# on time step 1713079 (time=1713.08), 0.000118959 s/step
# Meep progress: 1746.471/2090.0 = 83.6% done in 208.0s, 40.9s to go
# on time step 1746798 (time=1746.8), 0.00011863 s/step
# Meep progress: 1780.403/2090.0 = 85.2% done in 212.0s, 36.9s to go
# on time step 1780757 (time=1780.76), 0.000117792 s/step
# Meep progress: 1814.748/2090.0 = 86.8% done in 216.0s, 32.8s to go
# on time step 1815103 (time=1815.1), 0.000116464 s/step
# Meep progress: 1849.0900000000001/2090.0 = 88.5% done in 220.0s, 28.7s to go
# on time step 1849436 (time=1849.44), 0.000116508 s/step
# Meep progress: 1882.926/2090.0 = 90.1% done in 224.0s, 24.6s to go
# on time step 1883288 (time=1883.29), 0.000118165 s/step
# Meep progress: 1917.214/2090.0 = 91.7% done in 228.0s, 20.5s to go
# on time step 1917591 (time=1917.59), 0.000116608 s/step
# Meep progress: 1951.633/2090.0 = 93.4% done in 232.0s, 16.4s to go
# on time step 1952005 (time=1952.01), 0.000116234 s/step
# Meep progress: 1984.93/2090.0 = 95.0% done in 236.0s, 12.5s to go
# on time step 1985277 (time=1985.28), 0.000120222 s/step
# Meep progress: 2018.709/2090.0 = 96.6% done in 240.0s, 8.5s to go
# on time step 2019055 (time=2019.06), 0.000118427 s/step
# Meep progress: 2052.294/2090.0 = 98.2% done in 244.0s, 4.5s to go
# on time step 2052678 (time=2052.68), 0.000118968 s/step
# Meep progress: 2081.361/2090.0 = 99.6% done in 248.0s, 1.0s to go
# on time step 2081707 (time=2081.71), 0.000137796 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaa] 20%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000564098 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00232482 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 29.967000000000002/2090.0 = 1.4% done in 4.0s, 275.0s to go
# on time step 30054 (time=30.054), 0.000133094 s/step
# Meep progress: 60.419000000000004/2090.0 = 2.9% done in 8.0s, 268.7s to go
# on time step 60496 (time=60.496), 0.000131398 s/step
# Meep progress: 92.687/2090.0 = 4.4% done in 12.0s, 258.6s to go
# on time step 92765 (time=92.765), 0.000123961 s/step
# Meep progress: 125.14/2090.0 = 6.0% done in 16.0s, 251.2s to go
# on time step 125241 (time=125.241), 0.000123171 s/step
# Meep progress: 156.13400000000001/2090.0 = 7.5% done in 20.0s, 247.7s to go
# on time step 156242 (time=156.242), 0.000129031 s/step
# Meep progress: 187.514/2090.0 = 9.0% done in 24.0s, 243.5s to go
# on time step 187643 (time=187.643), 0.000127385 s/step
# Meep progress: 220.45600000000002/2090.0 = 10.5% done in 28.0s, 237.5s to go
# on time step 220591 (time=220.591), 0.000121405 s/step
# Meep progress: 253.766/2090.0 = 12.1% done in 32.0s, 231.6s to go
# on time step 253906 (time=253.906), 0.000120066 s/step
# Meep progress: 286.705/2090.0 = 13.7% done in 36.0s, 226.4s to go
# on time step 286832 (time=286.832), 0.000121488 s/step
# Meep progress: 319.61/2090.0 = 15.3% done in 40.0s, 221.6s to go
# on time step 319760 (time=319.76), 0.00012148 s/step
# Meep progress: 350.861/2090.0 = 16.8% done in 44.0s, 218.1s to go
# on time step 351004 (time=351.004), 0.000128027 s/step
# Meep progress: 381.919/2090.0 = 18.3% done in 48.0s, 214.7s to go
# on time step 381982 (time=381.982), 0.000129126 s/step
# Meep progress: 408.231/2090.0 = 19.5% done in 52.0s, 214.2s to go
# on time step 408375 (time=408.375), 0.000151559 s/step
# Meep progress: 434.866/2090.0 = 20.8% done in 56.0s, 213.1s to go
# on time step 435020 (time=435.02), 0.000150123 s/step
# Meep progress: 463.568/2090.0 = 22.2% done in 60.0s, 210.5s to go
# on time step 463731 (time=463.731), 0.000139323 s/step
# Meep progress: 490.902/2090.0 = 23.5% done in 64.0s, 208.5s to go
# on time step 491069 (time=491.069), 0.000146317 s/step
# Meep progress: 519.988/2090.0 = 24.9% done in 68.0s, 205.3s to go
# on time step 520167 (time=520.167), 0.00013747 s/step
# Meep progress: 548.625/2090.0 = 26.2% done in 72.0s, 202.3s to go
# on time step 548799 (time=548.799), 0.000139708 s/step
# Meep progress: 577.714/2090.0 = 27.6% done in 76.0s, 198.9s to go
# on time step 577902 (time=577.902), 0.000137445 s/step
# Meep progress: 606.808/2090.0 = 29.0% done in 80.0s, 195.5s to go
# on time step 607011 (time=607.011), 0.000137421 s/step
# Meep progress: 636.287/2090.0 = 30.4% done in 84.0s, 191.9s to go
# on time step 636480 (time=636.48), 0.000135737 s/step
# Meep progress: 665.633/2090.0 = 31.8% done in 88.0s, 188.3s to go
# on time step 665837 (time=665.837), 0.000136257 s/step
# Meep progress: 694.952/2090.0 = 33.3% done in 92.0s, 184.7s to go
# on time step 695187 (time=695.187), 0.000136287 s/step
# Meep progress: 724.395/2090.0 = 34.7% done in 96.0s, 181.0s to go
# on time step 724630 (time=724.63), 0.000135856 s/step
# Meep progress: 753.4300000000001/2090.0 = 36.0% done in 100.0s, 177.4s to go
# on time step 753627 (time=753.627), 0.000137948 s/step
# Meep progress: 782.303/2090.0 = 37.4% done in 104.0s, 173.9s to go
# on time step 782551 (time=782.551), 0.000138295 s/step
# Meep progress: 812.063/2090.0 = 38.9% done in 108.0s, 170.0s to go
# on time step 812293 (time=812.293), 0.000134494 s/step
# Meep progress: 840.8240000000001/2090.0 = 40.2% done in 112.0s, 166.4s to go
# on time step 841076 (time=841.076), 0.000138973 s/step
# Meep progress: 870.0840000000001/2090.0 = 41.6% done in 116.0s, 162.6s to go
# on time step 870349 (time=870.349), 0.000136649 s/step
# Meep progress: 899.235/2090.0 = 43.0% done in 120.0s, 158.9s to go
# on time step 899486 (time=899.486), 0.000137288 s/step
# Meep progress: 928.363/2090.0 = 44.4% done in 124.0s, 155.2s to go
# on time step 928638 (time=928.638), 0.000137215 s/step
# Meep progress: 957.205/2090.0 = 45.8% done in 128.0s, 151.5s to go
# on time step 957484 (time=957.484), 0.00013867 s/step
# Meep progress: 986.546/2090.0 = 47.2% done in 132.0s, 147.6s to go
# on time step 986816 (time=986.816), 0.000136371 s/step
# Meep progress: 1015.467/2090.0 = 48.6% done in 136.0s, 143.9s to go
# on time step 1015765 (time=1015.76), 0.000138185 s/step
# Meep progress: 1044.398/2090.0 = 50.0% done in 140.0s, 140.2s to go
# on time step 1044694 (time=1044.69), 0.000138272 s/step
# Meep progress: 1073.973/2090.0 = 51.4% done in 144.0s, 136.2s to go
# on time step 1074288 (time=1074.29), 0.000135165 s/step
# Meep progress: 1101.498/2090.0 = 52.7% done in 148.0s, 132.8s to go
# on time step 1101682 (time=1101.68), 0.000146024 s/step
# Meep progress: 1131.491/2090.0 = 54.1% done in 152.0s, 128.8s to go
# on time step 1131877 (time=1131.88), 0.000132474 s/step
# Meep progress: 1162.709/2090.0 = 55.6% done in 156.0s, 124.4s to go
# on time step 1163100 (time=1163.1), 0.000128112 s/step
# Meep progress: 1188.612/2090.0 = 56.9% done in 160.0s, 121.3s to go
# on time step 1188940 (time=1188.94), 0.0001548 s/step
# Meep progress: 1213.655/2090.0 = 58.1% done in 164.0s, 118.4s to go
# on time step 1213994 (time=1213.99), 0.000159657 s/step
# Meep progress: 1242.048/2090.0 = 59.4% done in 168.0s, 114.7s to go
# on time step 1242398 (time=1242.4), 0.000140827 s/step
# Meep progress: 1268.858/2090.0 = 60.7% done in 172.0s, 111.3s to go
# on time step 1269217 (time=1269.22), 0.000149152 s/step
# Meep progress: 1298.338/2090.0 = 62.1% done in 176.0s, 107.3s to go
# on time step 1298699 (time=1298.7), 0.000135677 s/step
# Meep progress: 1327.8600000000001/2090.0 = 63.5% done in 180.0s, 103.3s to go
# on time step 1328214 (time=1328.21), 0.000135527 s/step
# Meep progress: 1357.406/2090.0 = 64.9% done in 184.0s, 99.3s to go
# on time step 1357796 (time=1357.8), 0.000135219 s/step
# Meep progress: 1386.373/2090.0 = 66.3% done in 188.0s, 95.4s to go
# on time step 1386753 (time=1386.75), 0.000138153 s/step
# Meep progress: 1415.987/2090.0 = 67.8% done in 192.0s, 91.4s to go
# on time step 1416357 (time=1416.36), 0.00013512 s/step
# Meep progress: 1444.914/2090.0 = 69.1% done in 196.0s, 87.5s to go
# on time step 1445260 (time=1445.26), 0.000138415 s/step
# Meep progress: 1473.6290000000001/2090.0 = 70.5% done in 200.0s, 83.7s to go
# on time step 1474060 (time=1474.06), 0.000138891 s/step
# Meep progress: 1502.92/2090.0 = 71.9% done in 204.0s, 79.7s to go
# on time step 1503371 (time=1503.37), 0.000136478 s/step
# Meep progress: 1532.56/2090.0 = 73.3% done in 208.0s, 75.7s to go
# on time step 1533004 (time=1533), 0.000134986 s/step
# Meep progress: 1561.585/2090.0 = 74.7% done in 212.0s, 71.7s to go
# on time step 1562048 (time=1562.05), 0.000137722 s/step
# Meep progress: 1589.807/2090.0 = 76.1% done in 216.0s, 68.0s to go
# on time step 1590226 (time=1590.23), 0.000141957 s/step
# Meep progress: 1617.703/2090.0 = 77.4% done in 220.0s, 64.2s to go
# on time step 1618141 (time=1618.14), 0.000143294 s/step
# Meep progress: 1647.102/2090.0 = 78.8% done in 224.0s, 60.2s to go
# on time step 1647554 (time=1647.55), 0.000136 s/step
# Meep progress: 1676.589/2090.0 = 80.2% done in 228.0s, 56.2s to go
# on time step 1677054 (time=1677.05), 0.000135596 s/step
# Meep progress: 1705.508/2090.0 = 81.6% done in 232.0s, 52.3s to go
# on time step 1705974 (time=1705.97), 0.000138313 s/step
# Meep progress: 1734.867/2090.0 = 83.0% done in 236.0s, 48.3s to go
# on time step 1735397 (time=1735.4), 0.00013595 s/step
# Meep progress: 1764.317/2090.0 = 84.4% done in 240.0s, 44.3s to go
# on time step 1764841 (time=1764.84), 0.00013586 s/step
# Meep progress: 1792.279/2090.0 = 85.8% done in 244.0s, 40.5s to go
# on time step 1792539 (time=1792.54), 0.000144422 s/step
# Meep progress: 1817.104/2090.0 = 86.9% done in 248.0s, 37.2s to go
# on time step 1817618 (time=1817.62), 0.0001595 s/step
# Meep progress: 1845.4840000000002/2090.0 = 88.3% done in 252.0s, 33.4s to go
# on time step 1846047 (time=1846.05), 0.000140704 s/step
# Meep progress: 1874.3400000000001/2090.0 = 89.7% done in 256.0s, 29.5s to go
# on time step 1874912 (time=1874.91), 0.000138578 s/step
# Meep progress: 1903.378/2090.0 = 91.1% done in 260.0s, 25.5s to go
# on time step 1903939 (time=1903.94), 0.000137804 s/step
# Meep progress: 1932.832/2090.0 = 92.5% done in 264.0s, 21.5s to go
# on time step 1933384 (time=1933.38), 0.00013585 s/step
# Meep progress: 1957.467/2090.0 = 93.7% done in 268.0s, 18.1s to go
# on time step 1958002 (time=1958), 0.000162484 s/step
# Meep progress: 1984.791/2090.0 = 95.0% done in 272.0s, 14.4s to go
# on time step 1985379 (time=1985.38), 0.000146112 s/step
# Meep progress: 2011.588/2090.0 = 96.2% done in 276.0s, 10.8s to go
# on time step 2012180 (time=2012.18), 0.000149251 s/step
# Meep progress: 2040.4170000000001/2090.0 = 97.6% done in 280.0s, 6.8s to go
# on time step 2041038 (time=2041.04), 0.000138613 s/step
# Meep progress: 2068.659/2090.0 = 99.0% done in 284.0s, 2.9s to go
# on time step 2069272 (time=2069.27), 0.000141675 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 30%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000929117 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00297403 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 27.703/2090.0 = 1.3% done in 4.0s, 297.8s to go
# on time step 27773 (time=27.773), 0.000144029 s/step
# Meep progress: 57.123000000000005/2090.0 = 2.7% done in 8.0s, 284.7s to go
# on time step 57222 (time=57.222), 0.000135831 s/step
# Meep progress: 86.20400000000001/2090.0 = 4.1% done in 12.0s, 278.9s to go
# on time step 86314 (time=86.314), 0.000137495 s/step
# Meep progress: 115.279/2090.0 = 5.5% done in 16.0s, 274.1s to go
# on time step 115390 (time=115.39), 0.000137575 s/step
# Meep progress: 144.382/2090.0 = 6.9% done in 20.0s, 269.5s to go
# on time step 144531 (time=144.531), 0.000137264 s/step
# Meep progress: 173.54/2090.0 = 8.3% done in 24.0s, 265.0s to go
# on time step 173680 (time=173.68), 0.000137231 s/step
# Meep progress: 202.077/2090.0 = 9.7% done in 28.0s, 261.6s to go
# on time step 202229 (time=202.229), 0.000140111 s/step
# Meep progress: 231.172/2090.0 = 11.1% done in 32.0s, 257.3s to go
# on time step 231345 (time=231.345), 0.000137385 s/step
# Meep progress: 260.225/2090.0 = 12.5% done in 36.0s, 253.1s to go
# on time step 260403 (time=260.403), 0.000137659 s/step
# Meep progress: 287.628/2090.0 = 13.8% done in 40.0s, 250.7s to go
# on time step 287835 (time=287.835), 0.000145816 s/step
# Meep progress: 316.973/2090.0 = 15.2% done in 44.0s, 246.1s to go
# on time step 317192 (time=317.192), 0.000136257 s/step
# Meep progress: 346.467/2090.0 = 16.6% done in 48.0s, 241.6s to go
# on time step 346699 (time=346.699), 0.000135566 s/step
# Meep progress: 375.721/2090.0 = 18.0% done in 52.0s, 237.3s to go
# on time step 375963 (time=375.963), 0.000136688 s/step
# Meep progress: 404.94100000000003/2090.0 = 19.4% done in 56.0s, 233.0s to go
# on time step 405191 (time=405.191), 0.000136856 s/step
# Meep progress: 434.399/2090.0 = 20.8% done in 60.0s, 228.7s to go
# on time step 434655 (time=434.655), 0.000135762 s/step
# Meep progress: 463.895/2090.0 = 22.2% done in 64.0s, 224.3s to go
# on time step 464185 (time=464.185), 0.000135472 s/step
# Meep progress: 492.432/2090.0 = 23.6% done in 68.0s, 220.6s to go
# on time step 492732 (time=492.732), 0.000140124 s/step
# Meep progress: 521.239/2090.0 = 24.9% done in 72.0s, 216.7s to go
# on time step 521563 (time=521.563), 0.000138751 s/step
# Meep progress: 547.702/2090.0 = 26.2% done in 76.0s, 214.0s to go
# on time step 547877 (time=547.877), 0.000152017 s/step
# Meep progress: 563.015/2090.0 = 26.9% done in 80.0s, 217.0s to go
# on time step 563187 (time=563.187), 0.0002613 s/step
# Meep progress: 578.902/2090.0 = 27.7% done in 84.0s, 219.3s to go
# on time step 579090 (time=579.09), 0.000251533 s/step
# Meep progress: 594.571/2090.0 = 28.4% done in 88.0s, 221.3s to go
# on time step 594761 (time=594.761), 0.000255257 s/step
# Meep progress: 610.138/2090.0 = 29.2% done in 92.0s, 223.1s to go
# on time step 610328 (time=610.328), 0.000256959 s/step
# Meep progress: 632.505/2090.0 = 30.3% done in 96.0s, 221.2s to go
# on time step 632857 (time=632.857), 0.000177552 s/step
# Meep progress: 657.345/2090.0 = 31.5% done in 100.0s, 218.0s to go
# on time step 657523 (time=657.523), 0.000162189 s/step
# Meep progress: 682.613/2090.0 = 32.7% done in 104.0s, 214.4s to go
# on time step 682986 (time=682.986), 0.000157103 s/step
# Meep progress: 710.077/2090.0 = 34.0% done in 108.0s, 209.9s to go
# on time step 710447 (time=710.447), 0.000145666 s/step
# Meep progress: 738.528/2090.0 = 35.3% done in 112.0s, 205.0s to go
# on time step 739030 (time=739.03), 0.000139945 s/step
# Meep progress: 768.375/2090.0 = 36.8% done in 116.0s, 199.5s to go
# on time step 768842 (time=768.842), 0.000134175 s/step
# Meep progress: 797.63/2090.0 = 38.2% done in 120.0s, 194.4s to go
# on time step 798096 (time=798.096), 0.000136745 s/step
# Meep progress: 826.982/2090.0 = 39.6% done in 124.0s, 189.4s to go
# on time step 827501 (time=827.501), 0.000136035 s/step
# Meep progress: 855.79/2090.0 = 40.9% done in 128.0s, 184.6s to go
# on time step 856055 (time=856.055), 0.000140094 s/step
# Meep progress: 877.094/2090.0 = 42.0% done in 132.0s, 182.5s to go
# on time step 877356 (time=877.356), 0.000187789 s/step
# Meep progress: 891.458/2090.0 = 42.7% done in 136.0s, 182.9s to go
# on time step 891739 (time=891.739), 0.00027812 s/step
# Meep progress: 906.649/2090.0 = 43.4% done in 140.0s, 182.7s to go
# on time step 906923 (time=906.923), 0.000263446 s/step
# Meep progress: 921.217/2090.0 = 44.1% done in 144.0s, 182.7s to go
# on time step 921496 (time=921.496), 0.000274494 s/step
# Meep progress: 936.2620000000001/2090.0 = 44.8% done in 148.0s, 182.4s to go
# on time step 936515 (time=936.515), 0.000266351 s/step
# Meep progress: 964.647/2090.0 = 46.2% done in 152.0s, 177.3s to go
# on time step 965228 (time=965.228), 0.000139313 s/step
# Meep progress: 992.517/2090.0 = 47.5% done in 156.0s, 172.5s to go
# on time step 993068 (time=993.068), 0.00014368 s/step
# Meep progress: 1018.423/2090.0 = 48.7% done in 160.0s, 168.4s to go
# on time step 1018937 (time=1018.94), 0.000154628 s/step
# Meep progress: 1044.974/2090.0 = 50.0% done in 164.0s, 164.0s to go
# on time step 1045545 (time=1045.55), 0.000150335 s/step
# Meep progress: 1073.313/2090.0 = 51.4% done in 168.0s, 159.1s to go
# on time step 1073852 (time=1073.85), 0.000141309 s/step
# Meep progress: 1101.382/2090.0 = 52.7% done in 172.0s, 154.4s to go
# on time step 1101967 (time=1101.97), 0.000142277 s/step
# Meep progress: 1126.906/2090.0 = 53.9% done in 176.0s, 150.4s to go
# on time step 1127241 (time=1127.24), 0.000158273 s/step
# Meep progress: 1142.1390000000001/2090.0 = 54.6% done in 180.0s, 149.4s to go
# on time step 1142447 (time=1142.45), 0.000263063 s/step
# Meep progress: 1157.722/2090.0 = 55.4% done in 184.0s, 148.2s to go
# on time step 1158064 (time=1158.06), 0.000256137 s/step
# Meep progress: 1174.311/2090.0 = 56.2% done in 188.0s, 146.6s to go
# on time step 1174599 (time=1174.6), 0.000241915 s/step
# Meep progress: 1192.277/2090.0 = 57.0% done in 192.0s, 144.6s to go
# on time step 1192863 (time=1192.86), 0.000219013 s/step
# Meep progress: 1220.691/2090.0 = 58.4% done in 196.0s, 139.6s to go
# on time step 1221345 (time=1221.35), 0.000140444 s/step
# Meep progress: 1248.806/2090.0 = 59.8% done in 200.0s, 134.7s to go
# on time step 1249404 (time=1249.4), 0.000142558 s/step
# Meep progress: 1277.553/2090.0 = 61.1% done in 204.0s, 129.7s to go
# on time step 1278217 (time=1278.22), 0.000138827 s/step
# Meep progress: 1305.867/2090.0 = 62.5% done in 208.0s, 124.9s to go
# on time step 1306606 (time=1306.61), 0.000140901 s/step
# Meep progress: 1334.8020000000001/2090.0 = 63.9% done in 212.0s, 119.9s to go
# on time step 1335364 (time=1335.36), 0.000139094 s/step
# Meep progress: 1362.163/2090.0 = 65.2% done in 216.0s, 115.4s to go
# on time step 1362871 (time=1362.87), 0.000145419 s/step
# Meep progress: 1390.6190000000001/2090.0 = 66.5% done in 220.0s, 110.6s to go
# on time step 1391291 (time=1391.29), 0.000140746 s/step
# Meep progress: 1419.604/2090.0 = 67.9% done in 224.0s, 105.8s to go
# on time step 1420315 (time=1420.32), 0.000137819 s/step
# Meep progress: 1439.865/2090.0 = 68.9% done in 228.0s, 103.0s to go
# on time step 1440276 (time=1440.28), 0.000200402 s/step
# Meep progress: 1455.099/2090.0 = 69.6% done in 232.0s, 101.2s to go
# on time step 1455483 (time=1455.48), 0.000263047 s/step
# Meep progress: 1470.434/2090.0 = 70.4% done in 236.0s, 99.4s to go
# on time step 1470836 (time=1470.84), 0.000260547 s/step
# Meep progress: 1485.894/2090.0 = 71.1% done in 240.0s, 97.6s to go
# on time step 1486263 (time=1486.26), 0.000259305 s/step
# Meep progress: 1506.714/2090.0 = 72.1% done in 244.0s, 94.5s to go
# on time step 1507464 (time=1507.46), 0.000188675 s/step
# Meep progress: 1531.358/2090.0 = 73.3% done in 248.0s, 90.5s to go
# on time step 1532124 (time=1532.12), 0.000162247 s/step
# Meep progress: 1556.469/2090.0 = 74.5% done in 252.0s, 86.4s to go
# on time step 1557221 (time=1557.22), 0.000159387 s/step
# Meep progress: 1580.877/2090.0 = 75.6% done in 256.0s, 82.4s to go
# on time step 1581348 (time=1581.35), 0.000165808 s/step
# Meep progress: 1604.644/2090.0 = 76.8% done in 260.0s, 78.6s to go
# on time step 1605558 (time=1605.56), 0.000165224 s/step
# Meep progress: 1631.801/2090.0 = 78.1% done in 264.0s, 74.1s to go
# on time step 1632002 (time=1632), 0.000151318 s/step
# Meep progress: 1651.277/2090.0 = 79.0% done in 268.0s, 71.2s to go
# on time step 1651680 (time=1651.68), 0.000203274 s/step
# Meep progress: 1667.112/2090.0 = 79.8% done in 272.0s, 69.0s to go
# on time step 1667421 (time=1667.42), 0.000254116 s/step
# Meep progress: 1682.104/2090.0 = 80.5% done in 276.0s, 66.9s to go
# on time step 1682536 (time=1682.54), 0.000264639 s/step
# Meep progress: 1696.693/2090.0 = 81.2% done in 280.0s, 64.9s to go
# on time step 1697101 (time=1697.1), 0.000274637 s/step
# Meep progress: 1714.963/2090.0 = 82.1% done in 284.0s, 62.1s to go
# on time step 1715664 (time=1715.66), 0.000215492 s/step
# Meep progress: 1741.866/2090.0 = 83.3% done in 288.0s, 57.6s to go
# on time step 1742710 (time=1742.71), 0.000147901 s/step
# Meep progress: 1769.69/2090.0 = 84.7% done in 292.0s, 52.9s to go
# on time step 1770637 (time=1770.64), 0.000143235 s/step
# Meep progress: 1798.604/2090.0 = 86.1% done in 296.0s, 48.0s to go
# on time step 1799483 (time=1799.48), 0.000138669 s/step
# Meep progress: 1827.657/2090.0 = 87.4% done in 300.0s, 43.1s to go
# on time step 1828541 (time=1828.54), 0.000137659 s/step
# Meep progress: 1856.538/2090.0 = 88.8% done in 304.0s, 38.2s to go
# on time step 1857297 (time=1857.3), 0.000139103 s/step
# Meep progress: 1884.034/2090.0 = 90.1% done in 308.0s, 33.7s to go
# on time step 1885115 (time=1885.12), 0.000143795 s/step
# Meep progress: 1916.651/2090.0 = 91.7% done in 312.0s, 28.2s to go
# on time step 1917691 (time=1917.69), 0.00012279 s/step
# Meep progress: 1949.874/2090.0 = 93.3% done in 316.0s, 22.7s to go
# on time step 1950941 (time=1950.94), 0.000120304 s/step
# Meep progress: 1982.622/2090.0 = 94.9% done in 320.0s, 17.3s to go
# on time step 1983669 (time=1983.67), 0.000122221 s/step
# Meep progress: 2015.296/2090.0 = 96.4% done in 324.0s, 12.0s to go
# on time step 2016360 (time=2016.36), 0.000122359 s/step
# Meep progress: 2046.944/2090.0 = 97.9% done in 328.0s, 6.9s to go
# on time step 2047851 (time=2047.85), 0.000127023 s/step
# Meep progress: 2071.989/2090.0 = 99.1% done in 332.0s, 2.9s to go
# on time step 2072862 (time=2072.86), 0.000159931 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 40%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000838041 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00368905 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 25.098/2090.0 = 1.2% done in 4.0s, 329.1s to go
# on time step 25177 (time=25.177), 0.00015888 s/step
# Meep progress: 53.036/2090.0 = 2.5% done in 8.0s, 307.3s to go
# on time step 53131 (time=53.131), 0.000143145 s/step
# Meep progress: 69.988/2090.0 = 3.3% done in 12.0s, 346.4s to go
# on time step 70057 (time=70.057), 0.00023633 s/step
# Meep progress: 83.867/2090.0 = 4.0% done in 16.0s, 382.7s to go
# on time step 83902 (time=83.902), 0.000288914 s/step
# Meep progress: 98.81700000000001/2090.0 = 4.7% done in 20.0s, 403.0s to go
# on time step 98888 (time=98.888), 0.000266921 s/step
# Meep progress: 113.075/2090.0 = 5.4% done in 24.0s, 419.6s to go
# on time step 113153 (time=113.153), 0.000280477 s/step
# Meep progress: 134.53/2090.0 = 6.4% done in 28.0s, 407.0s to go
# on time step 134705 (time=134.705), 0.000185601 s/step
# Meep progress: 159.786/2090.0 = 7.6% done in 32.0s, 386.6s to go
# on time step 159948 (time=159.948), 0.000158461 s/step
# Meep progress: 185.439/2090.0 = 8.9% done in 36.0s, 369.8s to go
# on time step 185610 (time=185.61), 0.000155878 s/step
# Meep progress: 211.25900000000001/2090.0 = 10.1% done in 40.0s, 355.7s to go
# on time step 211410 (time=211.41), 0.000155119 s/step
# Meep progress: 235.71/2090.0 = 11.3% done in 44.0s, 346.2s to go
# on time step 235911 (time=235.911), 0.000163263 s/step
# Meep progress: 259.508/2090.0 = 12.4% done in 48.0s, 338.6s to go
# on time step 259726 (time=259.726), 0.000167968 s/step
# Meep progress: 278.818/2090.0 = 13.3% done in 52.0s, 337.8s to go
# on time step 278940 (time=278.94), 0.000208186 s/step
# Meep progress: 294.084/2090.0 = 14.1% done in 56.0s, 342.0s to go
# on time step 294199 (time=294.199), 0.000262162 s/step
# Meep progress: 309.25/2090.0 = 14.8% done in 60.0s, 345.5s to go
# on time step 309379 (time=309.379), 0.000263513 s/step
# Meep progress: 324.61/2090.0 = 15.5% done in 64.0s, 348.1s to go
# on time step 324743 (time=324.743), 0.000260354 s/step
# Meep progress: 351.314/2090.0 = 16.8% done in 68.0s, 336.6s to go
# on time step 351569 (time=351.569), 0.000149111 s/step
# Meep progress: 379.255/2090.0 = 18.1% done in 72.0s, 324.8s to go
# on time step 379566 (time=379.566), 0.000142873 s/step
# Meep progress: 407.339/2090.0 = 19.5% done in 76.0s, 314.0s to go
# on time step 407540 (time=407.54), 0.000142993 s/step
# Meep progress: 434.612/2090.0 = 20.8% done in 80.0s, 304.7s to go
# on time step 434886 (time=434.886), 0.000146278 s/step
# Meep progress: 462.397/2090.0 = 22.1% done in 84.0s, 295.7s to go
# on time step 462772 (time=462.772), 0.000143445 s/step
# Meep progress: 491.218/2090.0 = 23.5% done in 88.0s, 286.4s to go
# on time step 491571 (time=491.571), 0.000138894 s/step
# Meep progress: 518.946/2090.0 = 24.8% done in 92.0s, 278.5s to go
# on time step 519260 (time=519.26), 0.000144463 s/step
# Meep progress: 546.149/2090.0 = 26.1% done in 96.0s, 271.4s to go
# on time step 546462 (time=546.462), 0.000147049 s/step
# Meep progress: 575.698/2090.0 = 27.5% done in 100.0s, 263.0s to go
# on time step 576100 (time=576.1), 0.000134962 s/step
# Meep progress: 607.826/2090.0 = 29.1% done in 104.0s, 253.6s to go
# on time step 608079 (time=608.079), 0.000125085 s/step
# Meep progress: 636.453/2090.0 = 30.5% done in 108.0s, 246.7s to go
# on time step 636795 (time=636.795), 0.000139298 s/step
# Meep progress: 667.539/2090.0 = 31.9% done in 112.0s, 238.7s to go
# on time step 667979 (time=667.979), 0.000128271 s/step
# Meep progress: 700.405/2090.0 = 33.5% done in 116.0s, 230.2s to go
# on time step 700846 (time=700.846), 0.000121703 s/step
# Meep progress: 728.5500000000001/2090.0 = 34.9% done in 120.0s, 224.3s to go
# on time step 728846 (time=728.846), 0.000142858 s/step
# Meep progress: 759.8770000000001/2090.0 = 36.4% done in 124.0s, 217.1s to go
# on time step 760322 (time=760.322), 0.000127083 s/step
# Meep progress: 792.054/2090.0 = 37.9% done in 128.0s, 209.8s to go
# on time step 792503 (time=792.503), 0.000124297 s/step
# Meep progress: 825.707/2090.0 = 39.5% done in 132.0s, 202.1s to go
# on time step 826184 (time=826.184), 0.000118764 s/step
# Meep progress: 851.283/2090.0 = 40.7% done in 136.0s, 197.9s to go
# on time step 851411 (time=851.411), 0.000158568 s/step
# Meep progress: 872.216/2090.0 = 41.7% done in 140.0s, 195.5s to go
# on time step 872706 (time=872.706), 0.000187841 s/step
# Meep progress: 901.072/2090.0 = 43.1% done in 144.0s, 190.0s to go
# on time step 901538 (time=901.538), 0.000138738 s/step
# Meep progress: 928.588/2090.0 = 44.4% done in 148.0s, 185.1s to go
# on time step 928895 (time=928.895), 0.000146216 s/step
# Meep progress: 954.535/2090.0 = 45.7% done in 152.0s, 180.8s to go
# on time step 954792 (time=954.792), 0.000154463 s/step
# Meep progress: 971.283/2090.0 = 46.5% done in 156.0s, 179.7s to go
# on time step 971550 (time=971.55), 0.000238701 s/step
# Meep progress: 989.094/2090.0 = 47.3% done in 160.0s, 178.1s to go
# on time step 989362 (time=989.362), 0.000224573 s/step
# Meep progress: 1006.926/2090.0 = 48.2% done in 164.0s, 176.4s to go
# on time step 1007193 (time=1007.19), 0.000224349 s/step
# Meep progress: 1034.861/2090.0 = 49.5% done in 168.0s, 171.3s to go
# on time step 1035382 (time=1035.38), 0.0001419 s/step
# Meep progress: 1066.654/2090.0 = 51.0% done in 172.0s, 165.0s to go
# on time step 1067137 (time=1067.14), 0.000125967 s/step
# Meep progress: 1096.396/2090.0 = 52.5% done in 176.0s, 159.5s to go
# on time step 1096877 (time=1096.88), 0.0001345 s/step
# Meep progress: 1127.337/2090.0 = 53.9% done in 180.0s, 153.7s to go
# on time step 1127868 (time=1127.87), 0.000129072 s/step
# Meep progress: 1159.685/2090.0 = 55.5% done in 184.0s, 147.6s to go
# on time step 1160211 (time=1160.21), 0.000123675 s/step
# Meep progress: 1191.587/2090.0 = 57.0% done in 188.0s, 141.7s to go
# on time step 1192115 (time=1192.12), 0.000125377 s/step
# Meep progress: 1223.969/2090.0 = 58.6% done in 192.0s, 135.9s to go
# on time step 1224522 (time=1224.52), 0.00012343 s/step
# Meep progress: 1256.803/2090.0 = 60.1% done in 196.0s, 129.9s to go
# on time step 1257354 (time=1257.35), 0.000121835 s/step
# Meep progress: 1289.538/2090.0 = 61.7% done in 200.0s, 124.2s to go
# on time step 1290094 (time=1290.09), 0.000122177 s/step
# Meep progress: 1321.766/2090.0 = 63.2% done in 204.0s, 118.6s to go
# on time step 1322317 (time=1322.32), 0.000124137 s/step
# Meep progress: 1354.4180000000001/2090.0 = 64.8% done in 208.0s, 113.0s to go
# on time step 1354981 (time=1354.98), 0.000122462 s/step
# Meep progress: 1386.726/2090.0 = 66.4% done in 212.0s, 107.5s to go
# on time step 1386956 (time=1386.96), 0.000125101 s/step
# Meep progress: 1413.54/2090.0 = 67.6% done in 216.0s, 103.4s to go
# on time step 1414058 (time=1414.06), 0.000147592 s/step
# Meep progress: 1443.094/2090.0 = 69.0% done in 220.0s, 98.6s to go
# on time step 1443612 (time=1443.61), 0.000135348 s/step
# Meep progress: 1472.752/2090.0 = 70.5% done in 224.0s, 93.9s to go
# on time step 1473251 (time=1473.25), 0.00013496 s/step
# Meep progress: 1502.047/2090.0 = 71.9% done in 228.0s, 89.2s to go
# on time step 1502547 (time=1502.55), 0.00013654 s/step
# Meep progress: 1532.2730000000001/2090.0 = 73.3% done in 232.0s, 84.4s to go
# on time step 1532824 (time=1532.82), 0.000132117 s/step
# Meep progress: 1561.689/2090.0 = 74.7% done in 236.0s, 79.8s to go
# on time step 1561896 (time=1561.9), 0.00013762 s/step
# Meep progress: 1590.073/2090.0 = 76.1% done in 240.0s, 75.5s to go
# on time step 1590847 (time=1590.85), 0.000138168 s/step
# Meep progress: 1619.7630000000001/2090.0 = 77.5% done in 244.0s, 70.8s to go
# on time step 1620531 (time=1620.53), 0.000134754 s/step
# Meep progress: 1649.803/2090.0 = 78.9% done in 248.0s, 66.2s to go
# on time step 1650592 (time=1650.59), 0.000133063 s/step
# Meep progress: 1679.742/2090.0 = 80.4% done in 252.0s, 61.5s to go
# on time step 1680540 (time=1680.54), 0.00013357 s/step
# Meep progress: 1710.078/2090.0 = 81.8% done in 256.0s, 56.9s to go
# on time step 1710831 (time=1710.83), 0.000132053 s/step
# Meep progress: 1740.265/2090.0 = 83.3% done in 260.0s, 52.3s to go
# on time step 1741093 (time=1741.09), 0.000132182 s/step
# Meep progress: 1769.145/2090.0 = 84.6% done in 264.0s, 47.9s to go
# on time step 1770006 (time=1770.01), 0.000138348 s/step
# Meep progress: 1795.431/2090.0 = 85.9% done in 268.0s, 44.0s to go
# on time step 1795810 (time=1795.81), 0.000155021 s/step
# Meep progress: 1808.863/2090.0 = 86.5% done in 272.0s, 42.3s to go
# on time step 1809224 (time=1809.22), 0.000298202 s/step
# Meep progress: 1822.429/2090.0 = 87.2% done in 276.0s, 40.5s to go
# on time step 1822837 (time=1822.84), 0.000293839 s/step
# Meep progress: 1836.88/2090.0 = 87.9% done in 280.0s, 38.6s to go
# on time step 1837341 (time=1837.34), 0.000275797 s/step
# Meep progress: 1852.1380000000001/2090.0 = 88.6% done in 284.0s, 36.5s to go
# on time step 1852575 (time=1852.58), 0.000262575 s/step
# Meep progress: 1877.617/2090.0 = 89.8% done in 288.0s, 32.6s to go
# on time step 1878393 (time=1878.39), 0.000154951 s/step
# Meep progress: 1907.1580000000001/2090.0 = 91.3% done in 292.0s, 28.0s to go
# on time step 1907995 (time=1908), 0.000135129 s/step
# Meep progress: 1935.531/2090.0 = 92.6% done in 296.0s, 23.6s to go
# on time step 1936373 (time=1936.37), 0.00014097 s/step
# Meep progress: 1964.727/2090.0 = 94.0% done in 300.0s, 19.1s to go
# on time step 1965626 (time=1965.63), 0.000136742 s/step
# Meep progress: 1994.248/2090.0 = 95.4% done in 304.0s, 14.6s to go
# on time step 1995090 (time=1995.09), 0.000135765 s/step
# Meep progress: 2023.999/2090.0 = 96.8% done in 308.0s, 10.0s to go
# on time step 2024852 (time=2024.85), 0.000134402 s/step
# Meep progress: 2053.725/2090.0 = 98.3% done in 312.0s, 5.5s to go
# on time step 2054658 (time=2054.66), 0.000134202 s/step
# Meep progress: 2082.8740000000003/2090.0 = 99.7% done in 316.0s, 1.1s to go
# on time step 2083841 (time=2083.84), 0.000137068 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)
# ...
# Meep progress: 205.314/2090.0 = 9.8% done in 28.0s, 257.0s to go
# on time step 206639 (time=206.639), 0.000143664 s/step
# Meep progress: 235.125/2090.0 = 11.2% done in 32.0s, 252.5s to go
# on time step 236773 (time=236.773), 0.000132742 s/step
# Meep progress: 262.595/2090.0 = 12.6% done in 36.0s, 250.5s to go
# on time step 264022 (time=264.022), 0.000146796 s/step
# Meep progress: 292.676/2090.0 = 14.0% done in 40.0s, 245.6s to go
# on time step 294291 (time=294.291), 0.00013215 s/step
# Meep progress: 322.455/2090.0 = 15.4% done in 44.0s, 241.2s to go
# on time step 323823 (time=323.823), 0.000135448 s/step
# Meep progress: 347.01800000000003/2090.0 = 16.6% done in 48.0s, 241.1s to go
# on time step 347885 (time=347.885), 0.000166238 s/step
# Meep progress: 376.652/2090.0 = 18.0% done in 52.0s, 236.5s to go
# on time step 378312 (time=378.312), 0.000131465 s/step
# Meep progress: 403.26800000000003/2090.0 = 19.3% done in 56.0s, 234.2s to go
# on time step 404632 (time=404.632), 0.000151978 s/step
# Meep progress: 431.732/2090.0 = 20.7% done in 60.0s, 230.5s to go
# on time step 433408 (time=433.408), 0.000139011 s/step
# Meep progress: 464.072/2090.0 = 22.2% done in 64.0s, 224.2s to go
# on time step 465636 (time=465.636), 0.000124117 s/step
# Meep progress: 492.6/2090.0 = 23.6% done in 68.0s, 220.5s to go
# on time step 494148 (time=494.148), 0.000140294 s/step
# Meep progress: 523.654/2090.0 = 25.1% done in 72.0s, 215.4s to go
# on time step 525368 (time=525.368), 0.000128126 s/step
# Meep progress: 554.0260000000001/2090.0 = 26.5% done in 76.0s, 210.7s to go
# on time step 555520 (time=555.52), 0.000132664 s/step
# Meep progress: 580.562/2090.0 = 27.8% done in 80.0s, 208.0s to go
# on time step 582130 (time=582.13), 0.000150324 s/step
# Meep progress: 605.8770000000001/2090.0 = 29.0% done in 84.0s, 205.8s to go
# on time step 607515 (time=607.515), 0.000157576 s/step
# Meep progress: 635.115/2090.0 = 30.4% done in 88.0s, 201.6s to go
# on time step 636762 (time=636.762), 0.000136769 s/step
# Meep progress: 666.738/2090.0 = 31.9% done in 92.0s, 196.4s to go
# on time step 668531 (time=668.531), 0.000125911 s/step
# Meep progress: 697.63/2090.0 = 33.4% done in 96.0s, 191.6s to go
# on time step 699030 (time=699.03), 0.000131153 s/step
# Meep progress: 726.647/2090.0 = 34.8% done in 100.0s, 187.6s to go
# on time step 728391 (time=728.391), 0.000136237 s/step
# Meep progress: 758.8100000000001/2090.0 = 36.3% done in 104.0s, 182.5s to go
# on time step 760607 (time=760.607), 0.000124165 s/step
# Meep progress: 791.732/2090.0 = 37.9% done in 108.0s, 177.1s to go
# on time step 793557 (time=793.557), 0.000121397 s/step
# Meep progress: 825.51/2090.0 = 39.5% done in 112.0s, 171.6s to go
# on time step 827398 (time=827.398), 0.0001182 s/step
# Meep progress: 859.12/2090.0 = 41.1% done in 116.0s, 166.2s to go
# on time step 861042 (time=861.042), 0.000118894 s/step
# Meep progress: 893.203/2090.0 = 42.7% done in 120.0s, 160.8s to go
# on time step 895104 (time=895.104), 0.000117441 s/step
# Meep progress: 926.692/2090.0 = 44.3% done in 124.0s, 155.7s to go
# on time step 928656 (time=928.656), 0.000119221 s/step
# Meep progress: 960.373/2090.0 = 46.0% done in 128.0s, 150.6s to go
# on time step 962176 (time=962.176), 0.00011934 s/step
# Meep progress: 993.226/2090.0 = 47.5% done in 132.0s, 145.8s to go
# on time step 995197 (time=995.197), 0.000121136 s/step
# Meep progress: 1026.775/2090.0 = 49.1% done in 136.0s, 140.8s to go
# on time step 1028664 (time=1028.66), 0.000119522 s/step
# Meep progress: 1060.223/2090.0 = 50.7% done in 140.0s, 136.0s to go
# on time step 1062092 (time=1062.09), 0.000119663 s/step
# Meep progress: 1092.849/2090.0 = 52.3% done in 144.0s, 131.4s to go
# on time step 1094712 (time=1094.71), 0.000122624 s/step
# Meep progress: 1125.978/2090.0 = 53.9% done in 148.0s, 126.7s to go
# on time step 1127910 (time=1127.91), 0.000120493 s/step
# Meep progress: 1159.461/2090.0 = 55.5% done in 152.0s, 122.0s to go
# on time step 1161382 (time=1161.38), 0.000119504 s/step
# Meep progress: 1192.992/2090.0 = 57.1% done in 156.0s, 117.3s to go
# on time step 1194915 (time=1194.91), 0.00011929 s/step
# Meep progress: 1225.934/2090.0 = 58.7% done in 160.0s, 112.8s to go
# on time step 1227851 (time=1227.85), 0.000121451 s/step
# Meep progress: 1259.647/2090.0 = 60.3% done in 164.0s, 108.1s to go
# on time step 1261585 (time=1261.59), 0.000118576 s/step
# Meep progress: 1293.384/2090.0 = 61.9% done in 168.0s, 103.5s to go
# on time step 1295367 (time=1295.37), 0.00011841 s/step
# Meep progress: 1326.7730000000001/2090.0 = 63.5% done in 172.0s, 98.9s to go
# on time step 1328804 (time=1328.8), 0.00011963 s/step
# Meep progress: 1360.992/2090.0 = 65.1% done in 176.0s, 94.3s to go
# on time step 1362969 (time=1362.97), 0.00011708 s/step
# Meep progress: 1395.219/2090.0 = 66.8% done in 180.0s, 89.6s to go
# on time step 1397191 (time=1397.19), 0.000116886 s/step
# Meep progress: 1429.362/2090.0 = 68.4% done in 184.0s, 85.0s to go
# on time step 1431405 (time=1431.4), 0.000116912 s/step
# Meep progress: 1463.2350000000001/2090.0 = 70.0% done in 188.0s, 80.5s to go
# on time step 1465268 (time=1465.27), 0.000118125 s/step
# Meep progress: 1496.2450000000001/2090.0 = 71.6% done in 192.0s, 76.2s to go
# on time step 1498253 (time=1498.25), 0.000121269 s/step
# Meep progress: 1530.128/2090.0 = 73.2% done in 196.0s, 71.7s to go
# on time step 1532155 (time=1532.15), 0.00011799 s/step
# Meep progress: 1563.913/2090.0 = 74.8% done in 200.0s, 67.3s to go
# on time step 1565941 (time=1565.94), 0.000118396 s/step
# Meep progress: 1597.189/2090.0 = 76.4% done in 204.0s, 62.9s to go
# on time step 1599210 (time=1599.21), 0.000120236 s/step
# Meep progress: 1630.478/2090.0 = 78.0% done in 208.0s, 58.6s to go
# on time step 1632544 (time=1632.54), 0.000119998 s/step
# Meep progress: 1663.351/2090.0 = 79.6% done in 212.0s, 54.4s to go
# on time step 1665397 (time=1665.4), 0.000121755 s/step
# Meep progress: 1697.261/2090.0 = 81.2% done in 216.0s, 50.0s to go
# on time step 1699325 (time=1699.33), 0.0001179 s/step
# Meep progress: 1730.557/2090.0 = 82.8% done in 220.0s, 45.7s to go
# on time step 1732578 (time=1732.58), 0.000120291 s/step
# Meep progress: 1763.536/2090.0 = 84.4% done in 224.0s, 41.5s to go
# on time step 1765588 (time=1765.59), 0.000121176 s/step
# Meep progress: 1794.333/2090.0 = 85.9% done in 228.0s, 37.6s to go
# on time step 1796231 (time=1796.23), 0.000130538 s/step
# Meep progress: 1827.198/2090.0 = 87.4% done in 232.0s, 33.4s to go
# on time step 1829247 (time=1829.25), 0.000121155 s/step
# Meep progress: 1858.903/2090.0 = 88.9% done in 236.0s, 29.3s to go
# on time step 1860938 (time=1860.94), 0.000126221 s/step
# Meep progress: 1890.219/2090.0 = 90.4% done in 240.0s, 25.4s to go
# on time step 1892146 (time=1892.15), 0.000128174 s/step
# Meep progress: 1922.328/2090.0 = 92.0% done in 244.0s, 21.3s to go
# on time step 1924407 (time=1924.41), 0.000123989 s/step
# Meep progress: 1955.827/2090.0 = 93.6% done in 248.0s, 17.0s to go
# on time step 1957745 (time=1957.75), 0.000119984 s/step
# Meep progress: 1989.182/2090.0 = 95.2% done in 252.0s, 12.8s to go
# on time step 1991269 (time=1991.27), 0.000119321 s/step
# Meep progress: 2022.675/2090.0 = 96.8% done in 256.0s, 8.5s to go
# on time step 2024648 (time=2024.65), 0.000119836 s/step
# Meep progress: 2056.126/2090.0 = 98.4% done in 260.0s, 4.3s to go
# on time step 2058181 (time=2058.18), 0.000119288 s/step
# Meep progress: 2089.157/2090.0 = 100.0% done in 264.0s, 0.1s to go
# run 0 finished at t = 2090.0 (2090000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 90%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00127411 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 6.4 with resolution 1000
#      block, center = (0,0,-1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,0)
#           size (0,0,2.4)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (36,36,36)
#      block, center = (0,0,1.7)
#           size (0,0,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00243211 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2090.0)
# Meep progress: 33.436/2090.0 = 1.6% done in 4.0s, 246.0s to go
# on time step 33480 (time=33.48), 0.000119476 s/step
# Meep progress: 67.07300000000001/2090.0 = 3.2% done in 8.0s, 241.3s to go
# on time step 67127 (time=67.127), 0.000118885 s/step
# Meep progress: 99.71600000000001/2090.0 = 4.8% done in 12.0s, 239.5s to go
# on time step 99779 (time=99.779), 0.000122507 s/step
# Meep progress: 132.845/2090.0 = 6.4% done in 16.0s, 235.7s to go
# on time step 132911 (time=132.911), 0.00012073 s/step
# Meep progress: 165.756/2090.0 = 7.9% done in 20.0s, 232.2s to go
# on time step 165816 (time=165.816), 0.000121564 s/step
# Meep progress: 199.117/2090.0 = 9.5% done in 24.0s, 227.9s to go
# on time step 199197 (time=199.197), 0.000119832 s/step
# Meep progress: 232.40800000000002/2090.0 = 11.1% done in 28.0s, 223.8s to go
# on time step 232492 (time=232.492), 0.000120139 s/step
# Meep progress: 265.857/2090.0 = 12.7% done in 32.0s, 219.6s to go
# on time step 265944 (time=265.944), 0.000119577 s/step
# Meep progress: 299.35200000000003/2090.0 = 14.3% done in 36.0s, 215.3s to go
# on time step 299441 (time=299.441), 0.000119415 s/step
# Meep progress: 333.109/2090.0 = 15.9% done in 40.0s, 211.0s to go
# on time step 333217 (time=333.217), 0.000118428 s/step
# Meep progress: 366.051/2090.0 = 17.5% done in 44.0s, 207.2s to go
# on time step 366163 (time=366.163), 0.000121412 s/step
# Meep progress: 399.839/2090.0 = 19.1% done in 48.0s, 202.9s to go
# on time step 399954 (time=399.954), 0.000118377 s/step
# Meep progress: 433.372/2090.0 = 20.7% done in 52.0s, 198.8s to go
# on time step 433495 (time=433.495), 0.000119257 s/step
# Meep progress: 467.26800000000003/2090.0 = 22.4% done in 56.0s, 194.5s to go
# on time step 467395 (time=467.395), 0.000117997 s/step
# Meep progress: 500.833/2090.0 = 24.0% done in 60.0s, 190.4s to go
# on time step 500960 (time=500.96), 0.000119174 s/step
# Meep progress: 533.516/2090.0 = 25.5% done in 64.0s, 186.7s to go
# on time step 533650 (time=533.65), 0.000122362 s/step
# Meep progress: 566.5550000000001/2090.0 = 27.1% done in 68.0s, 182.9s to go
# on time step 566686 (time=566.686), 0.00012108 s/step
# Meep progress: 599.476/2090.0 = 28.7% done in 72.0s, 179.0s to go
# on time step 599621 (time=599.621), 0.000121452 s/step
# Meep progress: 632.621/2090.0 = 30.3% done in 76.0s, 175.1s to go
# on time step 632764 (time=632.764), 0.000120689 s/step
# Meep progress: 665.745/2090.0 = 31.9% done in 80.0s, 171.2s to go
# on time step 665897 (time=665.897), 0.000120729 s/step
# Meep progress: 699.14/2090.0 = 33.5% done in 84.0s, 167.1s to go
# on time step 699298 (time=699.298), 0.00011976 s/step
# Meep progress: 732.0790000000001/2090.0 = 35.0% done in 88.0s, 163.2s to go
# on time step 732245 (time=732.245), 0.00012141 s/step
# Meep progress: 765.804/2090.0 = 36.6% done in 92.0s, 159.1s to go
# on time step 765975 (time=765.975), 0.000118589 s/step
# Meep progress: 799.508/2090.0 = 38.3% done in 96.0s, 155.0s to go
# on time step 799678 (time=799.678), 0.000118686 s/step
# Meep progress: 833.0600000000001/2090.0 = 39.9% done in 100.0s, 150.9s to go
# on time step 833237 (time=833.237), 0.000119195 s/step
# Meep progress: 866.4830000000001/2090.0 = 41.5% done in 104.0s, 146.9s to go
# on time step 866668 (time=866.668), 0.000119651 s/step
# Meep progress: 900.21/2090.0 = 43.1% done in 108.0s, 142.7s to go
# on time step 900403 (time=900.403), 0.000118572 s/step
# Meep progress: 933.828/2090.0 = 44.7% done in 112.0s, 138.7s to go
# on time step 934030 (time=934.03), 0.000118952 s/step
# Meep progress: 968.02/2090.0 = 46.3% done in 116.0s, 134.5s to go
# on time step 968225 (time=968.225), 0.000116977 s/step
# Meep progress: 1002.23/2090.0 = 48.0% done in 120.0s, 130.2s to go
# on time step 1002436 (time=1002.44), 0.000116923 s/step
# Meep progress: 1035.986/2090.0 = 49.6% done in 124.0s, 126.2s to go
# on time step 1036198 (time=1036.2), 0.000118479 s/step
# Meep progress: 1070.027/2090.0 = 51.2% done in 128.0s, 122.0s to go
# on time step 1070244 (time=1070.24), 0.000117488 s/step
# Meep progress: 1103.259/2090.0 = 52.8% done in 132.0s, 118.1s to go
# on time step 1103476 (time=1103.48), 0.000120367 s/step
# Meep progress: 1137.359/2090.0 = 54.4% done in 136.0s, 113.9s to go
# on time step 1137582 (time=1137.58), 0.000117282 s/step
# Meep progress: 1171.244/2090.0 = 56.0% done in 140.0s, 109.8s to go
# on time step 1171471 (time=1171.47), 0.000118033 s/step
# Meep progress: 1203.9270000000001/2090.0 = 57.6% done in 144.0s, 106.0s to go
# on time step 1204161 (time=1204.16), 0.000122362 s/step
# Meep progress: 1237.2/2090.0 = 59.2% done in 148.0s, 102.0s to go
# on time step 1237433 (time=1237.43), 0.000120224 s/step
# Meep progress: 1270.066/2090.0 = 60.8% done in 152.0s, 98.1s to go
# on time step 1270289 (time=1270.29), 0.000121744 s/step
# Meep progress: 1302.866/2090.0 = 62.3% done in 156.0s, 94.2s to go
# on time step 1303118 (time=1303.12), 0.000121844 s/step
# Meep progress: 1335.346/2090.0 = 63.9% done in 160.0s, 90.4s to go
# on time step 1335592 (time=1335.59), 0.000123183 s/step
# Meep progress: 1367.705/2090.0 = 65.4% done in 164.0s, 86.6s to go
# on time step 1367977 (time=1367.98), 0.000123517 s/step
# Meep progress: 1401.012/2090.0 = 67.0% done in 168.0s, 82.6s to go
# on time step 1401283 (time=1401.28), 0.0001201 s/step
# Meep progress: 1433.559/2090.0 = 68.6% done in 172.0s, 78.8s to go
# on time step 1433834 (time=1433.83), 0.000122886 s/step
# Meep progress: 1466.89/2090.0 = 70.2% done in 176.0s, 74.8s to go
# on time step 1467171 (time=1467.17), 0.000119989 s/step
# Meep progress: 1499.2450000000001/2090.0 = 71.7% done in 180.0s, 70.9s to go
# on time step 1499527 (time=1499.53), 0.000123625 s/step
# Meep progress: 1532.751/2090.0 = 73.3% done in 184.0s, 66.9s to go
# on time step 1533062 (time=1533.06), 0.00011928 s/step
# Meep progress: 1563.172/2090.0 = 74.8% done in 188.0s, 63.4s to go
# on time step 1563464 (time=1563.46), 0.000131573 s/step
# Meep progress: 1596.027/2090.0 = 76.4% done in 192.0s, 59.4s to go
# on time step 1596337 (time=1596.34), 0.000121683 s/step
# Meep progress: 1628.68/2090.0 = 77.9% done in 196.0s, 55.5s to go
# on time step 1628972 (time=1628.97), 0.000122571 s/step
# Meep progress: 1662.392/2090.0 = 79.5% done in 200.0s, 51.4s to go
# on time step 1662716 (time=1662.72), 0.000118543 s/step
# Meep progress: 1695.616/2090.0 = 81.1% done in 204.0s, 47.4s to go
# on time step 1695841 (time=1695.84), 0.000120756 s/step
# Meep progress: 1728.5230000000001/2090.0 = 82.7% done in 208.0s, 43.5s to go
# on time step 1728829 (time=1728.83), 0.000121257 s/step
# Meep progress: 1761.257/2090.0 = 84.3% done in 212.0s, 39.6s to go
# on time step 1761606 (time=1761.61), 0.000122038 s/step
# Meep progress: 1793.214/2090.0 = 85.8% done in 216.0s, 35.7s to go
# on time step 1793556 (time=1793.56), 0.000125197 s/step
# Meep progress: 1826.634/2090.0 = 87.4% done in 220.0s, 31.7s to go
# on time step 1826975 (time=1826.98), 0.000119693 s/step
# Meep progress: 1859.583/2090.0 = 89.0% done in 224.0s, 27.8s to go
# on time step 1859942 (time=1859.94), 0.000121335 s/step
# Meep progress: 1892.827/2090.0 = 90.6% done in 228.0s, 23.8s to go
# on time step 1893186 (time=1893.19), 0.000120323 s/step
# Meep progress: 1926.082/2090.0 = 92.2% done in 232.0s, 19.7s to go
# on time step 1926444 (time=1926.44), 0.000120273 s/step
# Meep progress: 1959.489/2090.0 = 93.8% done in 236.0s, 15.7s to go
# on time step 1959857 (time=1959.86), 0.000119725 s/step
# Meep progress: 1992.815/2090.0 = 95.3% done in 240.0s, 11.7s to go
# on time step 1993185 (time=1993.18), 0.00012002 s/step
# Meep progress: 2026.0620000000001/2090.0 = 96.9% done in 244.0s, 7.7s to go
# on time step 2026430 (time=2026.43), 0.000120319 s/step
# Meep progress: 2059.563/2090.0 = 98.5% done in 248.0s, 3.7s to go
# on time step 2059958 (time=2059.96), 0.000119306 s/step
# run 0 finished at t = 2090.0 (2090000 timesteps)

# %%
plt.figure(dpi=150)
freqs = np.linspace(0,0.9e15,1000)
plt.plot(freqs,Efavg*tsim*eps0*4*np.pi/2**21,'b''.')
plt.xlim(0,0.7e15)
plt.yscale("log")
#plt.ylim(0.1e-28,100e-28)
plt.grid()
plt.savefig('test_detector_photonic_crystal_50000.png')
plt.show()

np.savez("test_custom_source_photonic_crystal_50000.npz", Efavg_50000 = Efavg)

# %%
from PIL import Image

def transPNG(srcImageName, dstImageName):
    img = Image.open(srcImageName)
    img = img.convert("RGBA")
    datas = img.getdata()
    newData = list()
    for item in datas:
        if item[0] > 225 and item[1] > 225 and item[2] > 225:
            newData.append((255, 255, 255, 0))
        else:
            newData.append(item)
            
    img.putdata(newData)
    img.save(dstImageName, "PNG")
transPNG('test_detector_photonic_crystal_50000.png','trans_test_detector_photonic_crystal_50000.png')
