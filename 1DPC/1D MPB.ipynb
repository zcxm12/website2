# %%
import math
import meep as mp
import numpy as np
from meep import mpb

num_bands = 30

k_points = [mp.Vector3(-0.5),          
            mp.Vector3(0),       
            mp.Vector3(0.5),  
           ]          

k_points = mp.interpolate(4, k_points)

dA = 0.2
dB = 0.8
epsilonA = 13
epsilonB = 2
geometry = []
def BlockAB(N, center):
        geometry = []
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA/2),
                         material=mp.Medium(epsilon=epsilonA)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA + dB/2),
                         material=mp.Medium(epsilon=epsilonB)))
        geometry = geometry.tolist()
        return geometry
Np = 1 ## number of repeating
geometry = BlockAB(3,0)
#for i in range (Np):
    #geometry.append(mp.Block(mp.Vector3(0.2),material= mp.Medium(epsilon=13)))

resolution = 32
geometry_lattice = mp.Lattice(size=mp.Vector3(1))
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)
ms.run_te()
# Out:
# Initializing eigensolver data
# Computing 30 bands with 1e-07 tolerance
# Working in 1 dimensions.
# Grid size is 32 x 1 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,-1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,-0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 3 object nodes (vs. 6 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 11 k-points
#   Vector3<-0.5, 0.0, 0.0>
#   Vector3<-0.4, 0.0, 0.0>
#   Vector3<-0.3, 0.0, 0.0>
#   Vector3<-0.19999999999999996, 0.0, 0.0>
#   Vector3<-0.09999999999999998, 0.0, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.03746366500854492
# solve_kpoint (-0.5,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8, te band 9, te band 10, te band 11, te band 12, te band 13, te band 14, te band 15, te band 16, te band 17, te band 18, te band 19, te band 20, te band 21, te band 22, te band 23, te band 24, te band 25, te band 26, te band 27, te band 28, te band 29, te band 30
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 14 iterations.
#     iteration    1: trace = 59.18069329677145 (151.029% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 43.6302809790124 (30.2505% change)
#     linmin: converged after 4 iterations.
#     iteration    3: trace = 41.47089121000271 (5.07488% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 83.9024%)
#     iteration    4: trace = 41.28032778706829 (0.460569% change)
#     iteration    5: trace = 41.25214164650907 (0.0683032% change)
#     iteration    6: trace = 41.25008704742275 (0.00498071% change)
#     iteration    7: trace = 41.25000371520098 (0.000202017% change)
#     iteration    8: trace = 41.25000041813257 (7.99289e-06% change)
# Finished solving for bands 1 to 10 after 8 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 7 iterations.
#     iteration    1: trace = 346.0675285893118 (50.8556% change)
#     linmin: converged after 5 iterations.
#     iteration    2: trace = 313.624508118881 (9.83581% change)
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 84.1327%)
#     iteration    3: trace = 299.4659977166021 (4.61873% change)
#     iteration    4: trace = 297.565505257959 (0.636647% change)
#     iteration    5: trace = 294.9544425334026 (0.881342% change)
#     iteration    6: trace = 292.3122503787746 (0.899827% change)
#     iteration    7: trace = 291.5828492605613 (0.24984% change)
#     iteration    8: trace = 291.3451844163517 (0.0815417% change)
#     iteration    9: trace = 291.2791050750841 (0.0226833% change)
#     iteration   10: trace = 291.2588208498515 (0.00696409% change)
#     iteration   11: trace = 291.2519961396262 (0.0023432% change)
#     iteration   12: trace = 291.2505114407858 (0.000509766% change)
#     iteration   13: trace = 291.2501666186885 (0.000118394% change)
#     iteration   14: trace = 291.2500653825383 (3.47592e-05% change)
#     iteration   15: trace = 291.2500197319986 (1.5674e-05% change)
#     iteration   16: trace = 291.2500045936334 (5.19772e-06% change)
# Finished solving for bands 11 to 20 after 16 iterations.
# Solving for bands 21 to 30...
#     near maximum in trace
#     linmin: converged after 6 iterations.
#     iteration    1: trace = 816.8500616255662 (6.9669% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 87.3615%)
#     iteration    2: trace = 799.3954690106156 (2.15989% change)
#     iteration    3: trace = 798.1509195612042 (0.155808% change)
#     iteration    4: trace = 795.3564410097517 (0.350733% change)
#     iteration    5: trace = 793.1899569282928 (0.272763% change)
#     iteration    6: trace = 791.8851743894301 (0.164634% change)
#     iteration    7: trace = 791.4933824834413 (0.0494881% change)
#     iteration    8: trace = 791.3004037479245 (0.0243846% change)
#     iteration    9: trace = 791.2587982218558 (0.00525801% change)
#     iteration   10: trace = 791.2537286482178 (0.000640699% change)
#     iteration   11: trace = 791.2512389384954 (0.000314654% change)
#     iteration   12: trace = 791.2503173662437 (0.00011647% change)
#     iteration   13: trace = 791.2500541209953 (3.32695e-05% change)
#     iteration   14: trace = 791.2500172050217 (4.66553e-06% change)
# Finished solving for bands 21 to 30 after 14 iterations.
# Finished k-point with 12.6667 mean iterations/band.
# tefreqs:, 1, -0.5, 0, 0, 0.5, 0.353553, 0.353553, 1.06066, 1.06066, 1.76777, 1.76777, 2.47487, 2.47487, 3.18198, 3.18198, 3.88909, 3.88909, 4.59619, 4.59619, 5.3033, 5.3033, 6.01041, 6.01041, 6.71751, 6.71751, 7.42462, 7.42462, 8.13173, 8.13173, 8.83883, 8.83883, 9.54594, 9.54594, 10.253, 10.253
# elapsed time for k point: 0.1880335807800293
# solve_kpoint (-0.4,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 77.7101%)
#     iteration    1: trace = 41.30000009646939 (7.02567e-07% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.291%)
#     iteration    1: trace = 291.3000004558176 (1.52995e-06% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 83.5863%)
#     iteration    1: trace = 791.3000041132791 (2.22265e-06% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 2, -0.4, 0, 0, 0.4, 0.282843, 0.424264, 0.989949, 1.13137, 1.69706, 1.83848, 2.40416, 2.54558, 3.11127, 3.25269, 3.81838, 3.9598, 4.52548, 4.6669, 5.23259, 5.37401, 5.9397, 6.08112, 6.6468, 6.78823, 7.35391, 7.49533, 8.06102, 8.20244, 8.76812, 8.90955, 9.47523, 9.61665, 10.1823, 10.3238
# elapsed time for k point: 0.03335285186767578
# solve_kpoint (-0.3,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 77.4489%)
#     iteration    1: trace = 41.45000002721477 (1.3948e-07% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 91.0261%)
#     iteration    1: trace = 291.4500000714078 (1.51598e-07% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 93.0722%)
#     iteration    1: trace = 791.4500011286607 (4.20389e-07% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 3, -0.3, 0, 0, 0.3, 0.212132, 0.494975, 0.919239, 1.20208, 1.62635, 1.90919, 2.33345, 2.6163, 3.04056, 3.3234, 3.74767, 4.03051, 4.45477, 4.73762, 5.16188, 5.44472, 5.86899, 6.15183, 6.57609, 6.85894, 7.2832, 7.56604, 7.99031, 8.27315, 8.69741, 8.98026, 9.40452, 9.68736, 10.1116, 10.3945
# elapsed time for k point: 0.02628779411315918
# solve_kpoint (-0.2,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.8791%)
#     iteration    1: trace = 41.70000000936908 (2.84555e-08% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 84.73%)
#     iteration    1: trace = 291.7000000133634 (2.53093e-08% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 78.9823%)
#     iteration    1: trace = 791.7000004454119 (8.90678e-08% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 4, -0.2, 0, 0, 0.2, 0.141421, 0.565685, 0.848528, 1.27279, 1.55563, 1.9799, 2.26274, 2.68701, 2.96985, 3.39411, 3.67696, 4.10122, 4.38406, 4.80833, 5.09117, 5.51543, 5.79828, 6.22254, 6.50538, 6.92965, 7.21249, 7.63675, 7.9196, 8.34386, 8.6267, 9.05097, 9.33381, 9.75807, 10.0409, 10.4652
# elapsed time for k point: 0.021615028381347656
# solve_kpoint (-0.1,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 71.6124%)
#     iteration    1: trace = 42.05000000333379 (5.69813e-09% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.3902%)
#     iteration    1: trace = 292.0500000028063 (5.23676e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.1358%)
#     iteration    1: trace = 792.0500001784893 (3.08536e-08% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 5, -0.1, 0, 0, 0.1, 0.0707107, 0.636396, 0.777817, 1.3435, 1.48492, 2.05061, 2.19203, 2.75772, 2.89914, 3.46482, 3.60624, 4.17193, 4.31335, 4.87904, 5.02046, 5.58614, 5.72756, 6.29325, 6.43467, 7.00036, 7.14178, 7.70746, 7.84889, 8.41457, 8.55599, 9.12168, 9.2631, 9.82878, 9.97021, 10.5359
# elapsed time for k point: 0.020202159881591797
# solve_kpoint (0,0,0):
# Solving for bands 2 to 11...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 90.0048%)
#     iteration    1: trace = 55.00000000010034 (1.81081e-09% change)
# Finished solving for bands 2 to 11 after 1 iterations.
# Solving for bands 12 to 21...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 84.9077%)
#     iteration    1: trace = 330.0000000010657 (6.45646e-09% change)
# Finished solving for bands 12 to 21 after 1 iterations.
# Solving for bands 22 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 98.0517%)
#     iteration    1: trace = 742.5000000252771 (1.41303e-08% change)
# Finished solving for bands 22 to 30 after 1 iterations.
# Finished k-point with 0.966667 mean iterations/band.
# tefreqs:, 6, 0, 0, 0, 0, 0, 0.707107, 0.707107, 1.41421, 1.41421, 2.12132, 2.12132, 2.82843, 2.82843, 3.53553, 3.53553, 4.24264, 4.24264, 4.94975, 4.94975, 5.65685, 5.65685, 6.36396, 6.36396, 7.07107, 7.07107, 7.77817, 7.77817, 8.48528, 8.48528, 9.19239, 9.19239, 9.89949, 9.89949, 10.6066
# elapsed time for k point: 0.05827498435974121
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 75.6788%)
#     iteration    1: trace = 42.05000000067655 (6.97983e-08% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 84.3084%)
#     iteration    1: trace = 292.0500000186528 (4.51873e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 83.7266%)
#     iteration    1: trace = 795.0499999524504 (3.1333e-09% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 7, 0.1, 0, 0, 0.1, 0.0707107, 0.636396, 0.777817, 1.3435, 1.48492, 2.05061, 2.19203, 2.75772, 2.89914, 3.46482, 3.60624, 4.17193, 4.31335, 4.87904, 5.02046, 5.58614, 5.72756, 6.29325, 6.43467, 7.00036, 7.14178, 7.70746, 7.84889, 8.41457, 8.55599, 9.12168, 9.2631, 9.82878, 9.97021, 10.6773
# elapsed time for k point: 0.035376548767089844
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 75.8546%)
#     iteration    1: trace = 41.70000000003488 (1.60288e-09% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 82.056%)
#     iteration    1: trace = 291.7000000202469 (3.91076e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 81.015%)
#     iteration    1: trace = 797.6999996264684 (3.54675e-08% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 8, 0.2, 0, 0, 0.2, 0.141421, 0.565685, 0.848528, 1.27279, 1.55563, 1.9799, 2.26274, 2.68701, 2.96985, 3.39411, 3.67696, 4.10122, 4.38406, 4.80833, 5.09117, 5.51543, 5.79828, 6.22254, 6.50538, 6.92965, 7.21249, 7.63675, 7.9196, 8.34386, 8.6267, 9.05097, 9.33381, 9.75807, 10.0409, 10.748
# elapsed time for k point: 0.026201486587524414
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 85.1161%)
#     iteration    1: trace = 41.45000000001457 (8.16824e-11% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 79.6443%)
#     iteration    1: trace = 291.4500000149286 (5.08817e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.7259%)
#     iteration    1: trace = 800.4499975192313 (1.9221e-07% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 9, 0.3, 0, 0, 0.3, 0.212132, 0.494975, 0.919239, 1.20208, 1.62635, 1.90919, 2.33345, 2.6163, 3.04056, 3.3234, 3.74767, 4.03051, 4.45477, 4.73762, 5.16188, 5.44472, 5.86899, 6.15183, 6.57609, 6.85894, 7.2832, 7.56604, 7.99031, 8.27315, 8.69741, 8.98026, 9.40452, 9.68736, 10.1116, 10.8187
# elapsed time for k point: 0.02250814437866211
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 77.4826%)
#     iteration    1: trace = 41.30000000000507 (3.19142e-11% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 82.1133%)
#     iteration    1: trace = 291.3000000086941 (3.35725e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 81.9895%)
#     iteration    1: trace = 803.2999760891739 (2.55411e-06% change)
# Finished solving for bands 21 to 30 after 1 iterations.
# Finished k-point with 1 mean iterations/band.
# tefreqs:, 10, 0.4, 0, 0, 0.4, 0.282843, 0.424264, 0.989949, 1.13137, 1.69706, 1.83848, 2.40416, 2.54558, 3.11127, 3.25269, 3.81838, 3.9598, 4.52548, 4.6669, 5.23259, 5.37401, 5.9397, 6.08112, 6.6468, 6.78823, 7.35391, 7.49533, 8.06102, 8.20244, 8.76812, 8.90955, 9.47523, 9.61665, 10.1823, 10.8894
# elapsed time for k point: 0.020839214324951172
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 79.6124%)
#     iteration    1: trace = 41.25000000000147 (1.09725e-11% change)
# Finished solving for bands 1 to 10 after 1 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 1 iterations.
#     switching to approximate line minimization (decrease time by 80.204%)
#     iteration    1: trace = 291.2500000038444 (2.34814e-09% change)
# Finished solving for bands 11 to 20 after 1 iterations.
# Solving for bands 21 to 30...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 81.1423%)
#     iteration    1: trace = 806.2497589845675 (2.37909e-05% change)
#     switching back to exact line minimization
#     near maximum in trace
#     linmin: converged after 10 iterations.
#     iteration    2: trace = 799.7953261042876 (0.803767% change)
#     linmin: converged after 2 iterations.
#     iteration    3: trace = 799.7946768557113 (8.11769e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    4: trace = 799.7940158702731 (8.26444e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    5: trace = 799.7933427808041 (8.41579e-05% change)
#     linmin: converged after 2 iterations.
#     iteration    6: trace = 799.7926572007261 (8.57197e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    7: trace = 799.7919587226124 (8.73324e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    8: trace = 799.7912469165528 (8.89989e-05% change)
#     linmin: converged after 3 iterations.
#     iteration    9: trace = 799.7905213289866 (9.07222e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   10: trace = 799.7897814805305 (9.25053e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   11: trace = 799.7890268642058 (9.43519e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   12: trace = 799.7882569433553 (9.62655e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   13: trace = 799.787471149366 (9.82503e-05% change)
#     linmin: converged after 3 iterations.
#     iteration   14: trace = 799.7866688791767 (0.00010031% change)
#     linmin: converged after 3 iterations.
#     iteration   15: trace = 799.7858494925406 (0.000102451% change)
#     linmin: converged after 3 iterations.
#     iteration   16: trace = 799.7850123090202 (0.000104676% change)
#     linmin: converged after 3 iterations.
#     iteration   17: trace = 799.7841566046776 (0.000106992% change)
#     linmin: converged after 3 iterations.
#     iteration   18: trace = 799.7832816084212 (0.000109404% change)
#     linmin: converged after 3 iterations.
#     iteration   19: trace = 799.7823864979728 (0.000111919% change)
#     linmin: converged after 3 iterations.
#     iteration   20: trace = 799.781470395396 (0.000114544% change)
#     linmin: converged after 3 iterations.
#     iteration   21: trace = 799.7805323621376 (0.000117286% change)
#     linmin: converged after 3 iterations.
#     iteration   22: trace = 799.7795713935097 (0.000120154% change)
#     linmin: converged after 3 iterations.
#     iteration   23: trace = 799.7785864125397 (0.000123157% change)
#     linmin: converged after 3 iterations.
#     iteration   24: trace = 799.7775762630965 (0.000126304% change)
#     linmin: converged after 3 iterations.
#     iteration   25: trace = 799.7765397021932 (0.000129606% change)
#     linmin: converged after 3 iterations.
#     iteration   26: trace = 799.7754753913379 (0.000133076% change)
#     linmin: converged after 3 iterations.
#     iteration   27: trace = 799.7743818867976 (0.000136727% change)
#     linmin: converged after 3 iterations.
#     iteration   28: trace = 799.7732576286032 (0.000140572% change)
#     linmin: converged after 3 iterations.
#     iteration   29: trace = 799.7721009280906 (0.000144629% change)
#     linmin: converged after 3 iterations.
#     iteration   30: trace = 799.7709099537541 (0.000148914% change)
#     linmin: converged after 3 iterations.
#     iteration   31: trace = 799.7696827151142 (0.000153449% change)
#     linmin: converged after 3 iterations.
#     iteration   32: trace = 799.7684170442731 (0.000158255% change)
#     linmin: converged after 3 iterations.
#     iteration   33: trace = 799.7671105747359 (0.000163356% change)
#     linmin: converged after 3 iterations.
#     iteration   34: trace = 799.7657607170188 (0.000168781% change)
#     linmin: converged after 3 iterations.
#     iteration   35: trace = 799.7643646304226 (0.000174562% change)
#     linmin: converged after 3 iterations.
#     iteration   36: trace = 799.7629191902481 (0.000180733% change)
#     linmin: converged after 3 iterations.
#     iteration   37: trace = 799.7614209495371 (0.000187336% change)
#     linmin: converged after 3 iterations.
#     iteration   38: trace = 799.7598660942133 (0.000194415% change)
#     linmin: converged after 3 iterations.
#     iteration   39: trace = 799.7582503902202 (0.000202024% change)
#     linmin: converged after 3 iterations.
#     iteration   40: trace = 799.7565691208887 (0.000210222% change)
#     linmin: converged after 3 iterations.
#     iteration   41: trace = 799.7548170123008 (0.00021908% change)
#     linmin: converged after 3 iterations.
#     iteration   42: trace = 799.7529881437971 (0.000228679% change)
#     linmin: converged after 3 iterations.
#     iteration   43: trace = 799.7510758399612 (0.000239112% change)
#     linmin: converged after 3 iterations.
#     iteration   44: trace = 799.7490725393121 (0.000250491% change)
#     linmin: converged after 3 iterations.
#     iteration   45: trace = 799.7469696334492 (0.000262946% change)
#     linmin: converged after 3 iterations.
#     iteration   46: trace = 799.7447572683589 (0.000276634% change)
#     linmin: converged after 3 iterations.
#     iteration   47: trace = 799.7424240967473 (0.00029174% change)
#     linmin: converged after 3 iterations.
#     iteration   48: trace = 799.7399569662806 (0.000308491% change)
#     linmin: converged after 3 iterations.
#     iteration   49: trace = 799.7373405228852 (0.000327162% change)
#     linmin: converged after 3 iterations.
#     iteration   50: trace = 799.7345566999691 (0.000348093% change)
#     linmin: converged after 3 iterations.
#     iteration   51: trace = 799.7315840520974 (0.000371705% change)
#     linmin: converged after 3 iterations.
#     iteration   52: trace = 799.7283968730865 (0.000398532% change)
#     linmin: converged after 3 iterations.
#     iteration   53: trace = 799.7249640097407 (0.000429255% change)
#     linmin: converged after 3 iterations.
#     iteration   54: trace = 799.721247237023 (0.000464757% change)
#     linmin: converged after 3 iterations.
#     iteration   55: trace = 799.7171989864682 (0.000506209% change)
#     linmin: converged after 3 iterations.
#     iteration   56: trace = 799.7127590955416 (0.000555184% change)
#     linmin: converged after 3 iterations.
#     iteration   57: trace = 799.7078500299278 (0.000613855% change)
#     linmin: converged after 3 iterations.
#     iteration   58: trace = 799.7023696405813 (0.000685301% change)
#     linmin: converged after 3 iterations.
#     iteration   59: trace = 799.696179778747 (0.000774024% change)
#     linmin: converged after 3 iterations.
#     iteration   60: trace = 799.6890876181615 (0.000886861% change)
#     linmin: converged after 4 iterations.
#     iteration   61: trace = 799.6808134081004 (0.00103468% change)
#     linmin: converged after 4 iterations.
#     iteration   62: trace = 799.6709312810442 (0.00123577% change)
#     linmin: converged after 4 iterations.
#     iteration   63: trace = 799.658752335182 (0.00152301% change)
#     linmin: converged after 4 iterations.
#     iteration   64: trace = 799.64307382584 (0.00196067% change)
#     linmin: converged after 5 iterations.
#     iteration   65: trace = 799.6216051415616 (0.00268482% change)
#     linmin: converged after 5 iterations.
#     iteration   66: trace = 799.5898658930417 (0.00396936% change)
#     linmin: converged after 6 iterations.
#     iteration   67: trace = 799.5436770080404 (0.00577674% change)
#     linmin: converged after 4 iterations.
#     iteration   68: trace = 799.4976598194039 (0.0057556% change)
#     linmin: converged after 4 iterations.
#     iteration   69: trace = 799.4645699679974 (0.00413892% change)
#     resetting CG direction...
#     large trace change predicted (0.942107%)
#     linmin: converged after 5 iterations.
#     iteration   70: trace = 791.2939225453475 (1.02726% change)
#     linmin: converged after 4 iterations.
#     iteration   71: trace = 791.2542156337779 (0.0050181% change)
#     linmin: converged after 2 iterations.
#     iteration   72: trace = 791.2506997086086 (0.000444349% change)
#     linmin: converged after 2 iterations.
#     iteration   73: trace = 791.250113924629 (7.40327e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   74: trace = 791.2500048863197 (1.37805e-05% change)
#     linmin: converged after 2 iterations.
#     iteration   75: trace = 791.2500000917876 (6.05944e-07% change)
# Finished solving for bands 21 to 30 after 75 iterations.
# Finished k-point with 25.6667 mean iterations/band.
# tefreqs:, 11, 0.5, 0, 0, 0.5, 0.353553, 0.353553, 1.06066, 1.06066, 1.76777, 1.76777, 2.47487, 2.47487, 3.18198, 3.18198, 3.88909, 3.88909, 4.59619, 4.59619, 5.3033, 5.3033, 6.01041, 6.01041, 6.71751, 6.71751, 7.42462, 7.42462, 8.13173, 8.13173, 8.83883, 8.83883, 9.54594, 9.54594, 10.253, 10.253
# elapsed time for k point: 0.16355204582214355
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.35355339194817753 at Vector3<-0.5, 0.0, 0.0>
# Band 2 range: 0.353553390593746 at Vector3<0.5, 0.0, 0.0> to 0.7071067811866498 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.7071067811879899 at Vector3<0.0, 0.0, 0.0> to 1.0606601782890979 at Vector3<-0.5, 0.0, 0.0>
# Band 4 range: 1.0606601717798272 at Vector3<0.5, 0.0, 0.0> to 1.4142135623731276 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 1.4142135623733996 at Vector3<0.0, 0.0, 0.0> to 1.7677669539330645 at Vector3<-0.5, 0.0, 0.0>
# Band 6 range: 1.7677669529663813 at Vector3<0.5, 0.0, 0.0> to 2.121320343559653 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 2.121320343559663 at Vector3<0.0, 0.0, 0.0> to 2.4748737359090214 at Vector3<-0.5, 0.0, 0.0>
# Band 8 range: 2.4748737341529203 at Vector3<0.5, 0.0, 0.0> to 2.8284271247461925 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 2.8284271247464248 at Vector3<0.0, 0.0, 0.0> to 3.1819805220550155 at Vector3<-0.5, 0.0, 0.0>
# Band 10 range: 3.1819805153396334 at Vector3<0.5, 0.0, 0.0> to 3.5355339059329407 at Vector3<0.0, 0.0, 0.0>
# Band 11 range: 3.5355339059460764 at Vector3<0.0, 0.0, 0.0> to 3.88908729652588 at Vector3<0.5, 0.0, 0.0>
# Band 12 range: 3.8890872965380825 at Vector3<0.5, 0.0, 0.0> to 4.242640687116998 at Vector3<0.0, 0.0, 0.0>
# Band 13 range: 4.242640687120187 at Vector3<0.0, 0.0, 0.0> to 4.596194087397276 at Vector3<-0.5, 0.0, 0.0>
# Band 14 range: 4.596194077856671 at Vector3<0.5, 0.0, 0.0> to 4.949747468305847 at Vector3<0.0, 0.0, 0.0>
# Band 15 range: 4.949747468305939 at Vector3<0.0, 0.0, 0.0> to 5.303300881058674 at Vector3<-0.5, 0.0, 0.0>
# Band 16 range: 5.303300858899355 at Vector3<0.5, 0.0, 0.0> to 5.656854249492387 at Vector3<0.0, 0.0, 0.0>
# Band 17 range: 5.656854249492578 at Vector3<0.0, 0.0, 0.0> to 6.010407657774001 at Vector3<-0.5, 0.0, 0.0>
# Band 18 range: 6.010407640085664 at Vector3<0.5, 0.0, 0.0> to 6.363961030679213 at Vector3<0.0, 0.0, 0.0>
# Band 19 range: 6.3639610306990875 at Vector3<0.0, 0.0, 0.0> to 6.717514463452869 at Vector3<-0.5, 0.0, 0.0>
# Band 20 range: 6.717514421452536 at Vector3<0.5, 0.0, 0.0> to 7.0710678118669446 at Vector3<0.0, 0.0, 0.0>
# Band 21 range: 7.071067811921539 at Vector3<0.0, 0.0, 0.0> to 7.4246212022955955 at Vector3<0.5, 0.0, 0.0>
# Band 22 range: 7.424621203878501 at Vector3<-0.5, 0.0, 0.0> to 7.7781745930641 at Vector3<0.0, 0.0, 0.0>
# Band 23 range: 7.778174593963525 at Vector3<0.0, 0.0, 0.0> to 8.13172798364529 at Vector3<0.5, 0.0, 0.0>
# Band 24 range: 8.131727984750771 at Vector3<0.5, 0.0, 0.0> to 8.485281374237967 at Vector3<0.0, 0.0, 0.0>
# Band 25 range: 8.485281374244886 at Vector3<0.0, 0.0, 0.0> to 8.83883476483203 at Vector3<0.5, 0.0, 0.0>
# Band 26 range: 8.838834765329738 at Vector3<0.5, 0.0, 0.0> to 9.19238815542497 at Vector3<0.0, 0.0, 0.0>
# Band 27 range: 9.19238815542508 at Vector3<0.0, 0.0, 0.0> to 9.545941546018328 at Vector3<0.5, 0.0, 0.0>
# Band 28 range: 9.54594154615825 at Vector3<0.5, 0.0, 0.0> to 9.899494936611529 at Vector3<0.0, 0.0, 0.0>
# Band 29 range: 9.899494936924349 at Vector3<0.0, 0.0, 0.0> to 10.253048580749763 at Vector3<-0.5, 0.0, 0.0>
# Band 30 range: 10.25304832920098 at Vector3<0.5, 0.0, 0.0> to 10.889439695243148 at Vector3<0.4, 0.0, 0.0>
# Gap from band 2 (0.7071067811866498) to band 3 (0.7071067811879899), 1.8951015976292467e-10%
# Gap from band 4 (1.4142135623731276) to band 5 (1.4142135623733996), 1.9233632618873952e-11%
# Gap from band 6 (2.121320343559653) to band 7 (2.121320343559663), 4.605604545472374e-13%
# Gap from band 8 (2.8284271247461925) to band 9 (2.8284271247464248), 8.211583558915798e-12%
# Gap from band 10 (3.5355339059329407) to band 11 (3.5355339059460764), 3.7153411868254753e-10%
# Gap from band 11 (3.88908729652588) to band 12 (3.8890872965380825), 3.13767276942884e-10%
# Gap from band 12 (4.242640687116998) to band 13 (4.242640687120187), 7.517602692179141e-11%
# Gap from band 14 (4.949747468305847) to band 15 (4.949747468305939), 1.8661670366069784e-12%
# Gap from band 16 (5.656854249492387) to band 17 (5.656854249492578), 3.375698786170055e-12%
# Gap from band 18 (6.363961030679213) to band 19 (6.3639610306990875), 3.123018573147591e-10%
# Gap from band 20 (7.0710678118669446) to band 21 (7.071067811921539), 7.720835459998533e-10%
# Gap from band 21 (7.4246212022955955) to band 22 (7.424621203878501), 2.1319678392245475e-08%
# Gap from band 22 (7.7781745930641) to band 23 (7.778174593963525), 1.1563451195590481e-08%
# Gap from band 23 (8.13172798364529) to band 24 (8.131727984750771), 1.3594674223842997e-08%
# Gap from band 24 (8.485281374237967) to band 25 (8.485281374244886), 8.154013502094993e-11%
# Gap from band 25 (8.83883476483203) to band 26 (8.838834765329738), 5.630929350706159e-09%
# Gap from band 26 (9.19238815542497) to band 27 (9.19238815542508), 1.198101322318708e-12%
# Gap from band 27 (9.545941546018328) to band 28 (9.54594154615825), 1.4657731896551903e-09%
# Gap from band 28 (9.899494936611529) to band 29 (9.899494936924349), 3.159959110340176e-09%
# total elapsed time for run: 0.656609296798706
# done

# %%
import matplotlib.pyplot as plt

freqs = ms.all_freqs
gaps = ms.gap_list

# 设置DPI值，增大像素
dpi = 100  # 这是一个示例值，可以根据需要调整
fig, ax = plt.subplots(dpi=dpi)

x = range(len(freqs))
for xz, tz in zip(x, freqs):
    ax.scatter([xz] * len(tz), tz, color='red')
ax.plot(freqs, color='red')
ax.set_ylim([0, 2])
ax.set_xlim([x[0], x[-1]])
for gap in gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)

points_in_between = (len(freqs) - 4) / 3
tick_locs = [i * points_in_between + i for i in range(4)]
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)
#plt.ylim(0,1)
# 显示图形
plt.savefig('bg_13_1_2')
plt.show()
