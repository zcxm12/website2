# %%
import math
import meep as mp
import numpy as np
from meep import mpb

num_bands = 20

k_points = [mp.Vector3(-0.5),          
            mp.Vector3(0),       
            mp.Vector3(0.5),  
           ]          

k_points = mp.interpolate(4, k_points)



geometry = []
Np = 1 ## number of repeating
for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(0.2),material= mp.Medium(epsilon=7)))

resolution = 32
geometry_lattice = mp.Lattice(size=mp.Vector3(1))
ms = mpb.ModeSolver(num_bands=num_bands,
                    k_points=k_points,
                    geometry=geometry,
                    geometry_lattice=geometry_lattice,
                    resolution=resolution)
ms.run_te()
# Out:
# Initializing eigensolver data
# Computing 20 bands with 1e-07 tolerance
# Working in 1 dimensions.
# Grid size is 32 x 1 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (0.2,0,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 11 k-points
#   Vector3<-0.5, 0.0, 0.0>
#   Vector3<-0.4, 0.0, 0.0>
#   Vector3<-0.3, 0.0, 0.0>
#   Vector3<-0.19999999999999996, 0.0, 0.0>
#   Vector3<-0.09999999999999998, 0.0, 0.0>
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
# elapsed time for initialization: 0.021736621856689453
# solve_kpoint (-0.5,0,0):
# tefreqs:, k index, k1, k2, k3, kmag/2pi, te band 1, te band 2, te band 3, te band 4, te band 5, te band 6, te band 7, te band 8, te band 9, te band 10, te band 11, te band 12, te band 13, te band 14, te band 15, te band 16, te band 17, te band 18, te band 19, te band 20
# Solving for bands 1 to 10...
#     near maximum in trace
#     linmin: converged after 17 iterations.
#     iteration    1: trace = 67.5604231023229 (167.516% change)
#     linmin: converged after 7 iterations.
#     iteration    2: trace = 50.04727265979538 (29.7823% change)
#     linmin: converged after 5 iterations.
#     iteration    3: trace = 47.15988596339278 (5.94069% change)
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 85.0852%)
#     iteration    4: trace = 46.55400548496251 (1.29304% change)
#     iteration    5: trace = 46.48334744883955 (0.151892% change)
#     iteration    6: trace = 46.47418902695268 (0.0197045% change)
#     iteration    7: trace = 46.47290009444998 (0.00277348% change)
#     iteration    8: trace = 46.47275633747927 (0.000309336% change)
#     iteration    9: trace = 46.47274116116625 (3.26564e-05% change)
#     iteration   10: trace = 46.47273961758896 (3.32147e-06% change)
# Finished solving for bands 1 to 10 after 10 iterations.
# Solving for bands 11 to 20...
#     large trace change predicted (1604.63%)
#     large theta (-44.8794)
#     linmin: converged after 9 iterations.
#     iteration    1: trace = 451.6669513900237 (76.1857% change)
#     linmin: converged after 6 iterations.
#     iteration    2: trace = 379.1733255916117 (17.4507% change)
#     linmin: converged after 5 iterations.
#     switching to approximate line minimization (decrease time by 88.2667%)
#     iteration    3: trace = 364.6960807874474 (3.89242% change)
#     iteration    4: trace = 358.5947145377384 (1.68711% change)
#     iteration    5: trace = 356.3469382856811 (0.6288% change)
#     iteration    6: trace = 355.4808326593894 (0.243347% change)
#     iteration    7: trace = 355.0797918174881 (0.11288% change)
#     iteration    8: trace = 354.9587838682337 (0.0340849% change)
#     iteration    9: trace = 354.9037992284527 (0.0154916% change)
#     iteration   10: trace = 354.8924588651075 (0.00319539% change)
#     iteration   11: trace = 354.8900531003536 (0.000677888% change)
#     iteration   12: trace = 354.8893416008949 (0.000200485% change)
#     iteration   13: trace = 354.8891716711088 (4.78825e-05% change)
#     iteration   14: trace = 354.8891195062198 (1.46989e-05% change)
#     iteration   15: trace = 354.8891050475238 (4.07414e-06% change)
# Finished solving for bands 11 to 20 after 15 iterations.
# Finished k-point with 12.5 mean iterations/band.
# tefreqs:, 1, -0.5, 0, 0, 0.5, 0.267334, 0.477917, 1.06147, 1.1852, 1.87538, 1.88105, 2.58505, 2.67185, 3.30348, 3.44266, 4.022, 4.2092, 4.72072, 4.99765, 5.42104, 5.73511, 6.3452, 6.92637, 7.54321, 8.1436
# elapsed time for k point: 0.1157522201538086
# solve_kpoint (-0.4,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 77.0035%)
#     iteration    1: trace = 46.52690496128925 (0.0260126% change)
#     iteration    2: trace = 46.52428754034299 (0.00562577% change)
#     iteration    3: trace = 46.52408137888976 (0.000443127% change)
#     iteration    4: trace = 46.52406567816126 (3.37475e-05% change)
#     iteration    5: trace = 46.52406155346385 (8.86573e-06% change)
# Finished solving for bands 1 to 10 after 5 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 90.2622%)
#     iteration    1: trace = 354.9067726013812 (0.0218809% change)
#     iteration    2: trace = 354.8619189075308 (0.012639% change)
#     iteration    3: trace = 354.8518464894499 (0.00283845% change)
#     iteration    4: trace = 354.8505336965928 (0.000369956% change)
#     iteration    5: trace = 354.8504358803403 (2.75655e-05% change)
#     iteration    6: trace = 354.850428953754 (1.95197e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 5.5 mean iterations/band.
# tefreqs:, 2, -0.4, 0, 0, 0.4, 0.245177, 0.499683, 1.03037, 1.21589
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:499: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mark/anaconda3/envs/mp/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# , 1.80994, 1.94661, 2.54662, 2.71065, 3.27375, 3.47257, 3.99799, 4.23313, 4.70395, 5.01354, 5.41092, 5.74092, 6.34335, 6.92759, 7.54229, 8.14446
# elapsed time for k point: 0.03818702697753906
# solve_kpoint (-0.3,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 96.7158%)
#     iteration    1: trace = 46.68029609615051 (0.0267407% change)
#     iteration    2: trace = 46.67733658227653 (0.00634016% change)
#     iteration    3: trace = 46.67700593802078 (0.000708364% change)
#     iteration    4: trace = 46.67692377835381 (0.000176018% change)
#     iteration    5: trace = 46.67690446125516 (4.13847e-05% change)
#     iteration    6: trace = 46.67690310548817 (2.90458e-06% change)
# Finished solving for bands 1 to 10 after 6 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 87.7427%)
#     iteration    1: trace = 354.7912591970934 (0.0223717% change)
#     iteration    2: trace = 354.7450583425823 (0.0130228% change)
#     iteration    3: trace = 354.7346649472966 (0.00292986% change)
#     iteration    4: trace = 354.7333094255866 (0.000382123% change)
#     iteration    5: trace = 354.7332091635893 (2.82641e-05% change)
#     iteration    6: trace = 354.733202096103 (1.99234e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 6 mean iterations/band.
# tefreqs:, 3, -0.3, 0, 0, 0.3, 0.194536, 0.548919, 0.971906, 1.27291, 1.74319, 2.01378, 2.48441, 2.77413, 3.2159, 3.5311, 3.94542, 4.28554, 4.66194, 5.05273, 5.38351, 5.75533, 6.33844, 6.93082, 7.53987, 8.14674
# elapsed time for k point: 0.03953361511230469
# solve_kpoint (-0.2,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 89.182%)
#     iteration    1: trace = 46.93181968974554 (0.02937% change)
#     iteration    2: trace = 46.92771850207495 (0.00873899% change)
#     iteration    3: trace = 46.92680012274249 (0.00195703% change)
#     iteration    4: trace = 46.92635704119333 (0.000944202% change)
#     iteration    5: trace = 46.92629680563713 (0.000128362% change)
#     iteration    6: trace = 46.92629328194148 (7.509e-06% change)
# Finished solving for bands 1 to 10 after 6 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 91.8042%)
#     iteration    1: trace = 354.5960169380174 (0.0228864% change)
#     iteration    2: trace = 354.5483145964474 (0.0134535% change)
#     iteration    3: trace = 354.5375347474106 (0.00304049% change)
#     iteration    4: trace = 354.5361312319513 (0.000395873% change)
#     iteration    5: trace = 354.5360272863112 (2.93188e-05% change)
#     iteration    6: trace = 354.5360199923154 (2.05734e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 6 mean iterations/band.
# tefreqs:, 4, -0.2, 0, 0, 0.2, 0.132933, 0.607032, 0.909231, 1.3323, 1.68029, 2.07752, 2.42216, 2.83921, 3.15304, 3.59573, 3.88386, 4.34723, 4.60705, 5.10189, 5.3453, 5.77204, 6.33222, 6.93489, 7.53684, 8.14965
# elapsed time for k point: 0.035547494888305664
# solve_kpoint (-0.1,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 78.8918%)
#     iteration    1: trace = 47.26826008319625 (0.0376751% change)
#     iteration    2: trace = 47.25956792103522 (0.0183907% change)
#     iteration    3: trace = 47.25438087536119 (0.0109763% change)
#     iteration    4: trace = 47.25154312020391 (0.00600545% change)
#     iteration    5: trace = 47.25127560718332 (0.000566148% change)
#     iteration    6: trace = 47.25125734897969 (3.86407e-05% change)
#     iteration    7: trace = 47.25125077302761 (1.3917e-05% change)
#     iteration    8: trace = 47.25124666048503 (8.70356e-06% change)
# Finished solving for bands 1 to 10 after 8 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 94.1944%)
#     iteration    1: trace = 354.3335587973987 (0.0235394% change)
#     iteration    2: trace = 354.2842147489203 (0.0139268% change)
#     iteration    3: trace = 354.2730299468531 (0.00315706% change)
#     iteration    4: trace = 354.2715760924212 (0.000410378% change)
#     iteration    5: trace = 354.2714676200534 (3.06184e-05% change)
#     iteration    6: trace = 354.2714599167568 (2.17441e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 7 mean iterations/band.
# tefreqs:, 5, -0.1, 0, 0, 0.1, 0.0672042, 0.662854, 0.851342, 1.38326, 1.62788, 2.13137, 2.36887, 2.89834, 3.09483, 3.65876, 3.8223, 4.41099, 4.54685, 5.15009, 5.30496, 5.78525, 6.32704, 6.93835, 7.53433, 8.15215
# elapsed time for k point: 0.046402931213378906
# solve_kpoint (0,0,0):
# Solving for bands 2 to 11...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 87.2934%)
#     iteration    1: trace = 61.81504149404524 (0.0288646% change)
#     iteration    2: trace = 61.81074510391286 (0.00695064% change)
#     iteration    3: trace = 61.81045084868285 (0.00047606% change)
#     iteration    4: trace = 61.81043971512166 (1.80124e-05% change)
#     iteration    5: trace = 61.8104392380471 (7.71835e-07% change)
# Finished solving for bands 2 to 11 after 5 iterations.
# Solving for bands 12 to 20...
#     linmin: converged after 2 iterations.
#     switching to approximate line minimization (decrease time by 87.7237%)
#     iteration    1: trace = 339.8366206789798 (0.0251396% change)
#     iteration    2: trace = 339.786254355651 (0.0148218% change)
#     iteration    3: trace = 339.7748583243501 (0.00335394% change)
#     iteration    4: trace = 339.7733824414655 (0.000434372% change)
#     iteration    5: trace = 339.7732731370461 (3.21698e-05% change)
#     iteration    6: trace = 339.7732653356177 (2.29607e-06% change)
# Finished solving for bands 12 to 20 after 6 iterations.
# Finished k-point with 5.2 mean iterations/band.
# tefreqs:, 6, 0, 0, 0, 0, 0, 0.692507, 0.821088, 1.40627, 1.60446, 2.15595, 2.34444, 2.92885, 3.06459, 3.69714, 3.78438, 4.46, 4.49894, 5.17547, 5.28416, 5.79105, 6.32499, 6.93996, 7.53335, 8.15335
# elapsed time for k point: 0.05424904823303223
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 3 iterations.
#     switching to approximate line minimization (decrease time by 91.7119%)
#     iteration    1: trace = 47.4189115568642 (0.285787% change)
#     iteration    2: trace = 47.3461183887817 (0.153629% change)
#     iteration    3: trace = 47.29570728706211 (0.10653% change)
#     iteration    4: trace = 47.26874008047408 (0.0570346% change)
#     iteration    5: trace = 47.26130969007956 (0.0157207% change)
#     iteration    6: trace = 47.25741018755453 (0.00825128% change)
#     iteration    7: trace = 47.25536986133053 (0.00431757% change)
#     iteration    8: trace = 47.2541702313783 (0.00253864% change)
#     iteration    9: trace = 47.25343391175621 (0.00155822% change)
#     iteration   10: trace = 47.25301100221171 (0.000894986% change)
#     iteration   11: trace = 47.25278344004008 (0.000481584% change)
#     iteration   12: trace = 47.25264881862869 (0.000284897% change)
#     iteration   13: trace = 47.25253154440122 (0.000248186% change)
#     iteration   14: trace = 47.25238527856729 (0.000309541% change)
#     iteration   15: trace = 47.25222165719301 (0.000346272% change)
#     iteration   16: trace = 47.25209842808678 (0.00026079% change)
#     iteration   17: trace = 47.25202521529629 (0.000154941% change)
#     iteration   18: trace = 47.25198182365076 (9.18303e-05% change)
#     iteration   19: trace = 47.25195574316074 (5.51945e-05% change)
#     iteration   20: trace = 47.25194079843725 (3.16277e-05% change)
#     iteration   21: trace = 47.25193197507166 (1.8673e-05% change)
#     iteration   22: trace = 47.25192558059322 (1.35327e-05% change)
#     iteration   23: trace = 47.25191959654082 (1.26641e-05% change)
#     iteration   24: trace = 47.25191340614445 (1.31008e-05% change)
#     iteration   25: trace = 47.25190746189801 (1.25799e-05% change)
#     iteration   26: trace = 47.25190245370089 (1.05989e-05% change)
#     iteration   27: trace = 47.25189873922537 (7.86101e-06% change)
# Finished solving for bands 1 to 10 after 27 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 90.2979%)
#     iteration    1: trace = 354.4534425075076 (0.0243245% change)
#     iteration    2: trace = 354.4026126030166 (0.0143414% change)
#     iteration    3: trace = 354.3911430010937 (0.00323637% change)
#     iteration    4: trace = 354.3896510639485 (0.000420987% change)
#     iteration    5: trace = 354.3895380523098 (3.18891e-05% change)
#     iteration    6: trace = 354.3895295032183 (2.41234e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 16.5 mean iterations/band.
# tefreqs:, 7, 0.1, 0, 0, 0.1, 0.0672041, 0.662854, 0.851342, 1.38326, 1.62789, 2.13137, 2.36887, 2.89835, 3.09485, 3.65883, 3.82232, 4.411, 4.54686, 5.15076, 5.31044, 5.78774, 6.32713, 6.93913, 7.53439, 8.15281
# elapsed time for k point: 0.08727025985717773
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 82.5095%)
#     iteration    1: trace = 46.94750525825617 (0.0645979% change)
#     iteration    2: trace = 46.93237200021974 (0.0322396% change)
#     iteration    3: trace = 46.92842909970031 (0.00840159% change)
#     iteration    4: trace = 46.92751461011952 (0.00194871% change)
#     iteration    5: trace = 46.92743889485575 (0.000161345% change)
#     iteration    6: trace = 46.9274329938007 (1.25749e-05% change)
#     iteration    7: trace = 46.92743216650886 (1.76292e-06% change)
# Finished solving for bands 1 to 10 after 7 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 93.3972%)
#     iteration    1: trace = 354.8327164138987 (0.0241459% change)
#     iteration    2: trace = 354.7827481219171 (0.0140832% change)
#     iteration    3: trace = 354.7715142677488 (0.00316645% change)
#     iteration    4: trace = 354.7700422062935 (0.000414933% change)
#     iteration    5: trace = 354.7699287327947 (3.19851e-05% change)
#     iteration    6: trace = 354.7699199337405 (2.48021e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 6.5 mean iterations/band.
# tefreqs:, 8, 0.2, 0, 0, 0.2, 0.132933, 0.607032, 0.909231, 1.3323, 1.6803, 2.07752, 2.42216, 2.83922, 3.15307, 3.59585, 3.88392, 4.34726, 4.60706, 5.10412, 5.356, 5.77608, 6.33293, 6.93612, 7.53724, 8.15069
# elapsed time for k point: 0.0557246208190918
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 81.1273%)
#     iteration    1: trace = 46.68422609277499 (0.0348683% change)
#     iteration    2: trace = 46.67944114476794 (0.0102501% change)
#     iteration    3: trace = 46.67872528318959 (0.00153358% change)
#     iteration    4: trace = 46.67854382098962 (0.000388748% change)
#     iteration    5: trace = 46.67851759930836 (5.6175e-05% change)
#     iteration    6: trace = 46.6785159358561 (3.56364e-06% change)
# Finished solving for bands 1 to 10 after 6 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 97.9955%)
#     iteration    1: trace = 355.1400753905648 (0.0236173% change)
#     iteration    2: trace = 355.0917625746416 (0.0136048% change)
#     iteration    3: trace = 355.0809398997317 (0.0030479% change)
#     iteration    4: trace = 355.0795119806097 (0.00040214% change)
#     iteration    5: trace = 355.0794002679904 (3.14613e-05% change)
#     iteration    6: trace = 355.079391492475 (2.47142e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 6 mean iterations/band.
# tefreqs:, 9, 0.3, 0, 0, 0.3, 0.194536, 0.548919, 0.971906, 1.27291, 1.7432, 2.01378, 2.48441, 2.77415, 3.21594, 3.53128, 3.94552, 4.28559, 4.66194, 5.05641, 5.40076, 5.75928, 6.34048, 6.93198, 7.54106, 8.14774
# elapsed time for k point: 0.04830217361450195
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 83.1274%)
#     iteration    1: trace = 46.52949501484639 (0.0283989% change)
#     iteration    2: trace = 46.52645916454219 (0.00652478% change)
#     iteration    3: trace = 46.52619126435774 (0.000575803% change)
#     iteration    4: trace = 46.52616127209507 (6.44632e-05% change)
#     iteration    5: trace = 46.52615378416436 (1.6094e-05% change)
#     iteration    6: trace = 46.52615304936134 (1.57933e-06% change)
# Finished solving for bands 1 to 10 after 6 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 91.1176%)
#     iteration    1: trace = 355.3643803914669 (0.0229185% change)
#     iteration    2: trace = 355.3179320669842 (0.0130715% change)
#     iteration    3: trace = 355.3075529358282 (0.00292113% change)
#     iteration    4: trace = 355.306173572079 (0.000388218% change)
#     iteration    5: trace = 355.3060647405784 (3.06303e-05% change)
#     iteration    6: trace = 355.3060561414736 (2.4202e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 6 mean iterations/band.
# tefreqs:, 10, 0.4, 0, 0, 0.4, 0.245177, 0.499683, 1.03037, 1.21589, 1.80995, 1.94661, 2.54662, 2.71067, 3.27378, 3.47283, 3.99811, 4.23322, 4.70399, 5.01836, 5.43635, 5.74309, 6.34728, 6.92828, 7.54463, 8.14507
# elapsed time for k point: 0.04301619529724121
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 10...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 89.9176%)
#     iteration    1: trace = 46.47814343469216 (0.026387% change)
#     iteration    2: trace = 46.47552706746596 (0.0056294% change)
#     iteration    3: trace = 46.47533512925192 (0.000412989% change)
#     iteration    4: trace = 46.47532739150876 (1.66491e-05% change)
#     iteration    5: trace = 46.47532682940204 (1.20947e-06% change)
# Finished solving for bands 1 to 10 after 5 iterations.
# Solving for bands 11 to 20...
#     linmin: converged after 4 iterations.
#     switching to approximate line minimization (decrease time by 89.9558%)
#     iteration    1: trace = 355.5101251305728 (0.0222826% change)
#     iteration    2: trace = 355.4651461841819 (0.0126527% change)
#     iteration    3: trace = 355.4550916649809 (0.00282859% change)
#     iteration    4: trace = 355.4537466930375 (0.000378381% change)
#     iteration    5: trace = 355.4536401870141 (2.99634e-05% change)
#     iteration    6: trace = 355.4536318471784 (2.34625e-06% change)
# Finished solving for bands 11 to 20 after 6 iterations.
# Finished k-point with 5.5 mean iterations/band.
# tefreqs:, 11, 0.5, 0, 0, 0.5, 0.267334, 0.477917, 1.06147, 1.1852, 1.87539, 1.88105, 2.58506, 2.67186, 3.30348, 3.44301, 4.02208, 4.20938, 4.72116, 5.00299, 5.45507, 5.73531, 6.35106, 6.92652, 7.54676, 8.14375
# elapsed time for k point: 0.03572678565979004
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2673338825554999 at Vector3<0.5, 0.0, 0.0>
# Band 2 range: 0.47791685498780856 at Vector3<-0.5, 0.0, 0.0> to 0.6925067968164628 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.8210880605866516 at Vector3<0.0, 0.0, 0.0> to 1.0614694413811998 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 1.185199174357233 at Vector3<-0.5, 0.0, 0.0> to 1.406272693167917 at Vector3<0.0, 0.0, 0.0>
# Band 5 range: 1.6044603381092177 at Vector3<0.0, 0.0, 0.0> to 1.875387172319 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 1.8810459924787464 at Vector3<-0.5, 0.0, 0.0> to 2.1559493255431845 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 2.344436015090441 at Vector3<0.0, 0.0, 0.0> to 2.585057692681466 at Vector3<0.5, 0.0, 0.0>
# Band 8 range: 2.67184601356749 at Vector3<-0.5, 0.0, 0.0> to 2.9288501817791697 at Vector3<0.0, 0.0, 0.0>
# Band 9 range: 3.064590792842941 at Vector3<0.0, 0.0, 0.0> to 3.303476931247976 at Vector3<0.5, 0.0, 0.0>
# Band 10 range: 3.4426555507307395 at Vector3<-0.5, 0.0, 0.0> to 3.6971411366244933 at Vector3<0.0, 0.0, 0.0>
# Band 11 range: 3.7843839240868378 at Vector3<0.0, 0.0, 0.0> to 4.022083741036751 at Vector3<0.5, 0.0, 0.0>
# Band 12 range: 4.209198491504738 at Vector3<-0.5, 0.0, 0.0> to 4.4600027809914495 at Vector3<0.0, 0.0, 0.0>
# Band 13 range: 4.498939261946026 at Vector3<0.0, 0.0, 0.0> to 4.721155906088595 at Vector3<0.5, 0.0, 0.0>
# Band 14 range: 4.997646247481478 at Vector3<-0.5, 0.0, 0.0> to 5.175473410083963 at Vector3<0.0, 0.0, 0.0>
# Band 15 range: 5.284160479806374 at Vector3<0.0, 0.0, 0.0> to 5.4550667053826585 at Vector3<0.5, 0.0, 0.0>
# Band 16 range: 5.735113955355043 at Vector3<-0.5, 0.0, 0.0> to 5.791045770756437 at Vector3<0.0, 0.0, 0.0>
# Band 17 range: 6.32499234522726 at Vector3<0.0, 0.0, 0.0> to 6.351056871484326 at Vector3<0.5, 0.0, 0.0>
# Band 18 range: 6.926373676309324 at Vector3<-0.5, 0.0, 0.0> to 6.939962212616745 at Vector3<0.0, 0.0, 0.0>
# Band 19 range: 7.533348283788192 at Vector3<0.0, 0.0, 0.0> to 7.546762078611666 at Vector3<0.5, 0.0, 0.0>
# Band 20 range: 8.143597444230412 at Vector3<-0.5, 0.0, 0.0> to 8.153352555119337 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2673338825554999) to band 2 (0.47791685498780856), 56.513321443058935%
# Gap from band 2 (0.6925067968164628) to band 3 (0.8210880605866516), 16.990182431089472%
# Gap from band 3 (1.0614694413811998) to band 4 (1.185199174357233), 11.014506733149501%
# Gap from band 4 (1.406272693167917) to band 5 (1.6044603381092177), 13.165408083840015%
# Gap from band 5 (1.875387172319) to band 6 (1.8810459924787464), 0.3012868810112831%
# Gap from band 6 (2.1559493255431845) to band 7 (2.344436015090441), 8.376468914580483%
# Gap from band 7 (2.585057692681466) to band 8 (2.67184601356749), 3.3018798036135903%
# Gap from band 8 (2.9288501817791697) to band 9 (3.064590792842941), 4.529638704661802%
# Gap from band 9 (3.303476931247976) to band 10 (3.4426555507307395), 4.12617510416697%
# Gap from band 10 (3.6971411366244933) to band 11 (3.7843839240868378), 2.332219347108612%
# Gap from band 11 (4.022083741036751) to band 12 (4.209198491504738), 4.546430195972351%
# Gap from band 12 (4.4600027809914495) to band 13 (4.498939261946026), 0.8692205121534567%
# Gap from band 13 (4.721155906088595) to band 14 (4.997646247481478), 5.689802858911326%
# Gap from band 14 (5.175473410083963) to band 15 (5.284160479806374), 2.0782193882992632%
# Gap from band 15 (5.4550667053826585) to band 16 (5.735113955355043), 5.005231970114107%
# Gap from band 16 (5.791045770756437) to band 17 (6.32499234522726), 8.813880731630105%
# Gap from band 17 (6.351056871484326) to band 18 (6.926373676309324), 8.666086450297415%
# Gap from band 18 (6.939962212616745) to band 19 (7.533348283788192), 8.199728338846041%
# Gap from band 19 (7.546762078611666) to band 20 (8.143597444230412), 7.607669725475334%
# total elapsed time for run: 0.6250815391540527
# done

# %%
import matplotlib.pyplot as plt
freqs = ms.all_freqs
gaps = ms.gap_list
fig, ax = plt.subplots()
x = range(len(freqs))
for xz, tz in zip(x, freqs):
    ax.scatter([xz]*len(tz), tz, color='red')
ax.plot(freqs, color='red')
ax.set_ylim([0, 2])
ax.set_xlim([x[0], x[-1]])
for gap in gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)
#ax.text(12, 0.04, 'bands', color='red', size=15)
points_in_between = (len(freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
#tick_labs = ['Γ', 'X', 'M', 'Γ']
#ax.set_xticks(tick_locs)
#ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)


plt.show()
