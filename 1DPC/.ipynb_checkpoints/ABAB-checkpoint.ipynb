# %%
##########################################################複製區塊
import matplotlib.pyplot as plt
import time
from scipy import signal
from time import sleep
import sys
import meep as mp
import numpy as np
import random
import multiprocessing as multi
#setup some constants and parameters
M=2**21
tsim=7e-12
eps0 = 8.854187e-12
hbar = 1.05457182e-34
c = 2.99792458e8
kb = 1.380649e-23
hdk=7.63823258e-12
deltap = np.sqrt(1/3/eps0/hbar/c)*kb
T=30000
frq_min = 0.5 #150THz
frq_max = 1.5 #900THz
nfreq = 1000
fcen = (frq_min + frq_max)/2
df = frq_max - frq_min
#define square root of Dn function
def Dnsqt(wla,T):
    return np.sqrt(6*hdk**2*wla/(np.exp(hdk*wla/T)-1)/T**2/np.pi)

#generate an array of the square root of Dn function
Dsqt = []
for n in range(1,M):
    Dsqt.append(Dnsqt(2*np.pi*n/tsim,T))

#define how many times to run to average the results
Ncomp= 100
nfreq =  1000
#define the starting sum of the result
epsilonA = 13
epsilonB = 2
Efsum = np.zeros(nfreq)
Ens = np.zeros(2*M)
resolution = 100
va = 1
dA = 0.2
dB = 0.8
dpml = 1.0
NAB = 3
sz = 2*dpml+(dA+dB)*NAB+2*va
cell = mp.Vector3(0, 0, sz)
pml_layers = [mp.PML(dpml)]



for i in range(Ncomp):
    
    def random_En(t):
        #generate random numbers
        M0 = np.random.normal(0,1)
        Mlp = np.random.normal(0,1,M-1)
        Nlp = np.random.normal(0,1,M-1)
        MM = np.random.normal(0,1)
    
        #generate the array of the fourier transform of E field, we generate l=0 and l=-M separately. 
        #for l=1 to M-1 and l=-1 to -(M-1) are conjutated to each other. 
        #we contruct the whole array by gluing them together by the order from l=0 -> l=M-1 -> l=-M -> l=-(m-1) -> l=-1
        Ef0 = np.array([M0*np.sqrt(6*hdk/np.pi/T)])
        Eflp = np.multiply((Mlp + 1j*Nlp), Dsqt)
        Eflm = np.flip(np.conjugate(Eflp))
        EfM = np.array([MM*Dnsqt(2*np.pi*M/tsim,T)])
        Ef = np.hstack((Ef0,Eflp,EfM,Eflm))
    
        #we normalize Ef and compute its inverse fast fourier transform
        Efn = deltap*T/np.sqrt(tsim)*Ef
        En = np.fft.ifft(Efn)*M
        return En
    En0 = random_En(1)
    En1 = random_En(1)
    #generate some feedback to check the progress of the loop
    x = i/Ncomp*100
    sys.stdout.write('\r')
    sys.stdout.write("[%-20s] %d%%" % ('a'*int(x), int(x)))
    sys.stdout.flush()
    sleep(0.0001)
    
    
    def source0(t):
        f = int(t*200)
        return En0[f]
    def source1(t):
        f = int(t*200)
        return En1[f]
   


    sources = [mp.Source(mp.CustomSource(src_func=source0),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,random.uniform(-(dA+dB)*NAB/2-va,-(dA+dB)*NAB/2)),
                     ),
              mp.Source(mp.CustomSource(src_func=source1),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,random.uniform((dA+dB)*NAB/2,(dA+dB)*NAB/2+va)),
                     )
              ]
    
    def BlockAB(N, center):
        geometry = []
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA/2),
                         material=mp.Medium(epsilon=epsilonA)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA + dB/2),
                         material=mp.Medium(epsilon=epsilonB)))
        geometry = geometry.tolist()
        return geometry
    def BlockBA(N, center):
        geometry = []
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,va),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 - va/2 ),
                         material=mp.Medium(epsilon=1)))
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB/2),
                         material=mp.Medium(epsilon=epsilonB)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB + dA/2),
                         material=mp.Medium(epsilon=epsilonA)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,va),
                         center=mp.Vector3(z=center + (dA+dB)*N/2 + va/2 ),
                         material=mp.Medium(epsilon=1)))
        geometry = geometry.tolist()
        return geometry
    geometry = BlockBA(3,0)

    
    sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    sources=sources,   
                    dimensions = 1,
                    Courant = 1,
                    resolution=resolution,
                    geometry=geometry)
    
    

    # transmitted flux
    tran_fr = mp.FluxRegion(center=mp.Vector3(0,0,random.uniform(-(dA+dB)*NAB/2,(dA+dB)*NAB/2)))
    tran = sim.add_energy(fcen, df, nfreq, tran_fr)
    
    
    sim.run(until=2000)

    tran_flux = mp.get_magnetic_energy(tran)
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts,tran_flux[i])    
    Efsum = Ts
    
    

#average the final result
Efavg = Efsum/Ncomp

#save data to some file or reload file to write more data on it
# Out:
# [                    ] 0%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000113964 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000931025 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 238.27/2000.0 = 11.9% done in 4.0s, 29.6s to go
# on time step 23841 (time=238.41), 0.000167781 s/step
# Meep progress: 477.47/2000.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 47768 (time=477.68), 0.000167177 s/step
# Meep progress: 715.48/2000.0 = 35.8% done in 12.0s, 21.5s to go
# on time step 71576 (time=715.76), 0.000168018 s/step
# Meep progress: 953.71/2000.0 = 47.7% done in 16.0s, 17.6s to go
# on time step 95408 (time=954.08), 0.000167847 s/step
# Meep progress: 1192.3/2000.0 = 59.6% done in 20.0s, 13.5s to go
# on time step 119276 (time=1192.76), 0.000167589 s/step
# Meep progress: 1419.83/2000.0 = 71.0% done in 24.0s, 9.8s to go
# on time step 142039 (time=1420.39), 0.00017573 s/step
# Meep progress: 1656.92/2000.0 = 82.8% done in 28.0s, 5.8s to go
# on time step 165756 (time=1657.56), 0.000168662 s/step
# Meep progress: 1896.6100000000001/2000.0 = 94.8% done in 32.0s, 1.7s to go
# on time step 189755 (time=1897.55), 0.000166676 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [a                   ] 1%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00010705 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000940084 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.17000000000002/2000.0 = 12.0% done in 4.0s, 29.5s to go
# on time step 23962 (time=239.62), 0.000166936 s/step
# Meep progress: 478.58/2000.0 = 23.9% done in 8.0s, 25.4s to go
# on time step 47934 (time=479.34), 0.000166863 s/step
# Meep progress: 719.26/2000.0 = 36.0% done in 12.0s, 21.4s to go
# on time step 72037 (time=720.37), 0.000165961 s/step
# Meep progress: 959.95/2000.0 = 48.0% done in 16.0s, 17.3s to go
# on time step 96109 (time=961.09), 0.000166169 s/step
# Meep progress: 1200.26/2000.0 = 60.0% done in 20.0s, 13.3s to go
# on time step 120147 (time=1201.47), 0.000166408 s/step
# Meep progress: 1437.16/2000.0 = 71.9% done in 24.0s, 9.4s to go
# on time step 143843 (time=1438.43), 0.000168811 s/step
# Meep progress: 1677.53/2000.0 = 83.9% done in 28.0s, 5.4s to go
# on time step 167888 (time=1678.88), 0.000166358 s/step
# Meep progress: 1917.5900000000001/2000.0 = 95.9% done in 32.0s, 1.4s to go
# on time step 191900 (time=1919), 0.000166588 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aa                  ] 2%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000116825 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000937939 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.21/2000.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 23966 (time=239.66), 0.000166904 s/step
# Meep progress: 479.39/2000.0 = 24.0% done in 8.0s, 25.4s to go
# on time step 47990 (time=479.9), 0.000166502 s/step
# Meep progress: 718.95/2000.0 = 35.9% done in 12.0s, 21.4s to go
# on time step 71955 (time=719.55), 0.000166912 s/step
# Meep progress: 959.5/2000.0 = 48.0% done in 16.0s, 17.4s to go
# on time step 96017 (time=960.17), 0.000166241 s/step
# Meep progress: 1199.43/2000.0 = 60.0% done in 20.0s, 13.3s to go
# on time step 120017 (time=1200.17), 0.000166667 s/step
# Meep progress: 1438.91/2000.0 = 71.9% done in 24.0s, 9.4s to go
# on time step 143971 (time=1439.71), 0.000166987 s/step
# Meep progress: 1679.6100000000001/2000.0 = 84.0% done in 28.0s, 5.3s to go
# on time step 168047 (time=1680.47), 0.000166142 s/step
# Meep progress: 1918.76/2000.0 = 95.9% done in 32.0s, 1.4s to go
# on time step 191969 (time=1919.69), 0.000167215 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaa                 ] 3%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000102043 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000931025 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 238.52/2000.0 = 11.9% done in 4.0s, 29.5s to go
# on time step 23891 (time=238.91), 0.000167429 s/step
# Meep progress: 469.62/2000.0 = 23.5% done in 8.0s, 26.1s to go
# on time step 47003 (time=470.03), 0.000173072 s/step
# Meep progress: 702.32/2000.0 = 35.1% done in 12.0s, 22.2s to go
# on time step 70282 (time=702.82), 0.000171833 s/step
# Meep progress: 932.3100000000001/2000.0 = 46.6% done in 16.0s, 18.3s to go
# on time step 93285 (time=932.85), 0.000173896 s/step
# Meep progress: 1171.13/2000.0 = 58.6% done in 20.0s, 14.2s to go
# on time step 117174 (time=1171.74), 0.000167445 s/step
# Meep progress: 1410.49/2000.0 = 70.5% done in 24.0s, 10.0s to go
# on time step 141117 (time=1411.17), 0.000167068 s/step
# Meep progress: 1649.3/2000.0 = 82.5% done in 28.0s, 6.0s to go
# on time step 165002 (time=1650.02), 0.00016747 s/step
# Meep progress: 1888.39/2000.0 = 94.4% done in 32.0s, 1.9s to go
# on time step 188919 (time=1889.19), 0.000167252 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaa                ] 4%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000110149 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000926971 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 238.45000000000002/2000.0 = 11.9% done in 4.0s, 29.6s to go
# on time step 23888 (time=238.88), 0.000167455 s/step
# Meep progress: 475.93/2000.0 = 23.8% done in 8.0s, 25.6s to go
# on time step 47649 (time=476.49), 0.000168344 s/step
# Meep progress: 715.67/2000.0 = 35.8% done in 12.0s, 21.5s to go
# on time step 71627 (time=716.27), 0.000166825 s/step
# Meep progress: 956.61/2000.0 = 47.8% done in 16.0s, 17.5s to go
# on time step 95728 (time=957.28), 0.00016597 s/step
# Meep progress: 1193.83/2000.0 = 59.7% done in 20.0s, 13.5s to go
# on time step 119457 (time=1194.57), 0.000168575 s/step
# Meep progress: 1434.59/2000.0 = 71.7% done in 24.0s, 9.5s to go
# on time step 143540 (time=1435.4), 0.000166096 s/step
# Meep progress: 1674.47/2000.0 = 83.7% done in 28.0s, 5.4s to go
# on time step 167533 (time=1675.33), 0.000166716 s/step
# Meep progress: 1914.8700000000001/2000.0 = 95.7% done in 32.0s, 1.4s to go
# on time step 191581 (time=1915.81), 0.000166344 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaa               ] 5%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000110149 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000926971 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 238.81/2000.0 = 11.9% done in 4.0s, 29.5s to go
# on time step 23926 (time=239.26), 0.000167188 s/step
# Meep progress: 477.95/2000.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 47847 (time=478.47), 0.000167218 s/step
# Meep progress: 718.5/2000.0 = 35.9% done in 12.0s, 21.4s to go
# on time step 71908 (time=719.08), 0.000166249 s/step
# Meep progress: 958.78/2000.0 = 47.9% done in 16.0s, 17.4s to go
# on time step 95942 (time=959.42), 0.000166435 s/step
# Meep progress: 1198.68/2000.0 = 59.9% done in 20.0s, 13.4s to go
# on time step 119938 (time=1199.38), 0.000166697 s/step
# Meep progress: 1437.42/2000.0 = 71.9% done in 24.0s, 9.4s to go
# on time step 143818 (time=1438.18), 0.00016751 s/step
# Meep progress: 1677.54/2000.0 = 83.9% done in 28.0s, 5.4s to go
# on time step 167839 (time=1678.39), 0.000166523 s/step
# Meep progress: 1917.48/2000.0 = 95.9% done in 32.0s, 1.4s to go
# on time step 191838 (time=1918.38), 0.000166677 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaa              ] 6%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000111103 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000948191 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 225.69/2000.0 = 11.3% done in 4.0s, 31.4s to go
# on time step 22615 (time=226.15), 0.000176876 s/step
# Meep progress: 460.93/2000.0 = 23.0% done in 8.0s, 26.7s to go
# on time step 46143 (time=461.43), 0.000170013 s/step
# Meep progress: 699.59/2000.0 = 35.0% done in 12.0s, 22.3s to go
# on time step 69999 (time=699.99), 0.000167678 s/step
# Meep progress: 937.8000000000001/2000.0 = 46.9% done in 16.0s, 18.1s to go
# on time step 93844 (time=938.44), 0.000167752 s/step
# Meep progress: 1176.8700000000001/2000.0 = 58.8% done in 20.0s, 14.0s to go
# on time step 117756 (time=1177.56), 0.000167285 s/step
# Meep progress: 1411.81/2000.0 = 70.6% done in 24.0s, 10.0s to go
# on time step 141250 (time=1412.5), 0.000170256 s/step
# Meep progress: 1649.64/2000.0 = 82.5% done in 28.0s, 5.9s to go
# on time step 165046 (time=1650.46), 0.0001681 s/step
# Meep progress: 1887.73/2000.0 = 94.4% done in 32.0s, 1.9s to go
# on time step 188863 (time=1888.63), 0.000167953 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaa             ] 7%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000106096 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000926971 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 236.18/2000.0 = 11.8% done in 4.0s, 29.9s to go
# on time step 23666 (time=236.66), 0.000169024 s/step
# Meep progress: 474.99/2000.0 = 23.7% done in 8.0s, 25.7s to go
# on time step 47553 (time=475.53), 0.000167456 s/step
# Meep progress: 713.6800000000001/2000.0 = 35.7% done in 12.0s, 21.6s to go
# on time step 71430 (time=714.3), 0.000167532 s/step
# Meep progress: 953.57/2000.0 = 47.7% done in 16.0s, 17.6s to go
# on time step 95421 (time=954.21), 0.000166732 s/step
# Meep progress: 1193.95/2000.0 = 59.7% done in 20.0s, 13.5s to go
# on time step 119467 (time=1194.67), 0.000166352 s/step
# Meep progress: 1434.64/2000.0 = 71.7% done in 24.0s, 9.5s to go
# on time step 143543 (time=1435.43), 0.000166141 s/step
# Meep progress: 1675.77/2000.0 = 83.8% done in 28.0s, 5.4s to go
# on time step 167663 (time=1676.63), 0.000165839 s/step
# Meep progress: 1915.22/2000.0 = 95.8% done in 32.0s, 1.4s to go
# on time step 191615 (time=1916.15), 0.000167003 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaa            ] 8%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000104904 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000921965 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 240.31/2000.0 = 12.0% done in 4.0s, 29.3s to go
# on time step 24077 (time=240.77), 0.000166137 s/step
# Meep progress: 480.44/2000.0 = 24.0% done in 8.0s, 25.3s to go
# on time step 48095 (time=480.95), 0.000166547 s/step
# Meep progress: 720.92/2000.0 = 36.0% done in 12.0s, 21.3s to go
# on time step 72150 (time=721.5), 0.00016629 s/step
# Meep progress: 960.21/2000.0 = 48.0% done in 16.0s, 17.3s to go
# on time step 96085 (time=960.85), 0.000167126 s/step
# Meep progress: 1200.26/2000.0 = 60.0% done in 20.0s, 13.3s to go
# on time step 120098 (time=1200.98), 0.000166579 s/step
# Meep progress: 1440.72/2000.0 = 72.0% done in 24.0s, 9.3s to go
# on time step 144151 (time=1441.51), 0.000166303 s/step
# Meep progress: 1671.72/2000.0 = 83.6% done in 28.0s, 5.5s to go
# on time step 167242 (time=1672.42), 0.000173232 s/step
# Meep progress: 1907.23/2000.0 = 95.4% done in 32.0s, 1.6s to go
# on time step 190813 (time=1908.13), 0.000169703 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaa           ] 9%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000111103 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00104499 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 240.8/2000.0 = 12.0% done in 4.0s, 29.2s to go
# on time step 24094 (time=240.94), 0.000166022 s/step
# Meep progress: 483.33/2000.0 = 24.2% done in 8.0s, 25.1s to go
# on time step 48352 (time=483.52), 0.000164895 s/step
# Meep progress: 725.78/2000.0 = 36.3% done in 12.0s, 21.1s to go
# on time step 72605 (time=726.05), 0.000164932 s/step
# Meep progress: 966.95/2000.0 = 48.3% done in 16.0s, 17.1s to go
# on time step 96727 (time=967.27), 0.000165826 s/step
# Meep progress: 1208.72/2000.0 = 60.4% done in 20.0s, 13.1s to go
# on time step 120908 (time=1209.08), 0.000165421 s/step
# Meep progress: 1449.7/2000.0 = 72.5% done in 24.0s, 9.1s to go
# on time step 145013 (time=1450.13), 0.000165948 s/step
# Meep progress: 1691.17/2000.0 = 84.6% done in 28.0s, 5.1s to go
# on time step 169167 (time=1691.67), 0.000165606 s/step
# Meep progress: 1931.82/2000.0 = 96.6% done in 32.0s, 1.1s to go
# on time step 193236 (time=1932.36), 0.00016619 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaa          ] 10%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000114918 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.0018611 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.59/2000.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 24021 (time=240.21), 0.000166534 s/step
# Meep progress: 477.97/2000.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 47909 (time=479.09), 0.000167455 s/step
# Meep progress: 718.21/2000.0 = 35.9% done in 12.0s, 21.4s to go
# on time step 71961 (time=719.61), 0.000166314 s/step
# Meep progress: 958.13/2000.0 = 47.9% done in 16.0s, 17.4s to go
# on time step 95963 (time=959.63), 0.000166656 s/step
# Meep progress: 1198.75/2000.0 = 59.9% done in 20.0s, 13.4s to go
# on time step 120052 (time=1200.52), 0.000166057 s/step
# Meep progress: 1436.71/2000.0 = 71.8% done in 24.0s, 9.4s to go
# on time step 143857 (time=1438.57), 0.000168035 s/step
# Meep progress: 1678.8/2000.0 = 83.9% done in 28.0s, 5.4s to go
# on time step 168073 (time=1680.73), 0.000165185 s/step
# Meep progress: 1921.58/2000.0 = 96.1% done in 32.0s, 1.3s to go
# on time step 192362 (time=1923.62), 0.00016469 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaa         ] 11%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000101805 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000952005 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.28/2000.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 23963 (time=239.63), 0.000166929 s/step
# Meep progress: 481.92/2000.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 48229 (time=482.29), 0.000164842 s/step
# Meep progress: 716.13/2000.0 = 35.8% done in 12.0s, 21.5s to go
# on time step 71650 (time=716.5), 0.000170792 s/step
# Meep progress: 945.72/2000.0 = 47.3% done in 16.0s, 17.8s to go
# on time step 94614 (time=946.14), 0.000174186 s/step
# Meep progress: 1174.39/2000.0 = 58.7% done in 20.0s, 14.1s to go
# on time step 117485 (time=1174.85), 0.000174898 s/step
# Meep progress: 1415.46/2000.0 = 70.8% done in 24.0s, 9.9s to go
# on time step 141598 (time=1415.98), 0.000165889 s/step
# Meep progress: 1658.27/2000.0 = 82.9% done in 28.0s, 5.8s to go
# on time step 165882 (time=1658.82), 0.000164721 s/step
# Meep progress: 1900.82/2000.0 = 95.0% done in 32.0s, 1.7s to go
# on time step 190137 (time=1901.37), 0.000164918 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaa        ] 12%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000108957 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000929832 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 242.59/2000.0 = 12.1% done in 4.0s, 29.0s to go
# on time step 24266 (time=242.66), 0.000164842 s/step
# Meep progress: 485.51/2000.0 = 24.3% done in 8.0s, 25.0s to go
# on time step 48561 (time=485.61), 0.000164651 s/step
# Meep progress: 729.17/2000.0 = 36.5% done in 12.0s, 20.9s to go
# on time step 72930 (time=729.3), 0.000164146 s/step
# Meep progress: 969.14/2000.0 = 48.5% done in 16.0s, 17.0s to go
# on time step 96929 (time=969.29), 0.000166675 s/step
# Meep progress: 1211.64/2000.0 = 60.6% done in 20.0s, 13.0s to go
# on time step 121182 (time=1211.82), 0.000164932 s/step
# Meep progress: 1454.68/2000.0 = 72.7% done in 24.0s, 9.0s to go
# on time step 145488 (time=1454.88), 0.00016457 s/step
# Meep progress: 1698.3/2000.0 = 84.9% done in 28.0s, 5.0s to go
# on time step 169853 (time=1698.53), 0.000164174 s/step
# Meep progress: 1940.39/2000.0 = 97.0% done in 32.0s, 1.0s to go
# on time step 194064 (time=1940.64), 0.000165214 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaa       ] 13%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000108957 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000935078 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 240.79/2000.0 = 12.0% done in 4.0s, 29.2s to go
# on time step 24098 (time=240.98), 0.000165996 s/step
# Meep progress: 481.54/2000.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 48187 (time=481.87), 0.000166054 s/step
# Meep progress: 723.03/2000.0 = 36.2% done in 12.0s, 21.2s to go
# on time step 72344 (time=723.44), 0.000165587 s/step
# Meep progress: 963.72/2000.0 = 48.2% done in 16.0s, 17.2s to go
# on time step 96425 (time=964.25), 0.000166112 s/step
# Meep progress: 1202.8600000000001/2000.0 = 60.1% done in 20.0s, 13.3s to go
# on time step 120344 (time=1203.44), 0.000167233 s/step
# Meep progress: 1440.82/2000.0 = 72.0% done in 24.0s, 9.3s to go
# on time step 144147 (time=1441.47), 0.000168053 s/step
# Meep progress: 1682.45/2000.0 = 84.1% done in 28.0s, 5.3s to go
# on time step 168316 (time=1683.16), 0.000165506 s/step
# Meep progress: 1922.79/2000.0 = 96.1% done in 32.0s, 1.3s to go
# on time step 192359 (time=1923.59), 0.000166372 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaa      ] 14%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00011301 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000931978 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 238.81/2000.0 = 11.9% done in 4.0s, 29.5s to go
# on time step 23918 (time=239.18), 0.000167243 s/step
# Meep progress: 471.12/2000.0 = 23.6% done in 8.0s, 26.0s to go
# on time step 47168 (time=471.68), 0.000172045 s/step
# Meep progress: 704.14/2000.0 = 35.2% done in 12.0s, 22.1s to go
# on time step 70489 (time=704.89), 0.000171526 s/step
# Meep progress: 945.6800000000001/2000.0 = 47.3% done in 16.0s, 17.8s to go
# on time step 94675 (time=946.75), 0.00016539 s/step
# Meep progress: 1188.01/2000.0 = 59.4% done in 20.0s, 13.7s to go
# on time step 118918 (time=1189.18), 0.000164996 s/step
# Meep progress: 1429.79/2000.0 = 71.5% done in 24.0s, 9.6s to go
# on time step 143098 (time=1430.98), 0.000165432 s/step
# Meep progress: 1670.57/2000.0 = 83.5% done in 28.0s, 5.5s to go
# on time step 167190 (time=1671.9), 0.000166032 s/step
# Meep progress: 1913.91/2000.0 = 95.7% done in 32.0s, 1.4s to go
# on time step 191528 (time=1915.28), 0.000164356 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaa     ] 15%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000108957 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000926971 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 241.89000000000001/2000.0 = 12.1% done in 4.0s, 29.1s to go
# on time step 24233 (time=242.33), 0.000165071 s/step
# Meep progress: 481.86/2000.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 48241 (time=482.41), 0.000166616 s/step
# Meep progress: 723.24/2000.0 = 36.2% done in 12.0s, 21.2s to go
# on time step 72401 (time=724.01), 0.000165569 s/step
# Meep progress: 966.66/2000.0 = 48.3% done in 16.0s, 17.1s to go
# on time step 96754 (time=967.54), 0.000164257 s/step
# Meep progress: 1208.53/2000.0 = 60.4% done in 20.0s, 13.1s to go
# on time step 120951 (time=1209.51), 0.000165314 s/step
# Meep progress: 1451.6000000000001/2000.0 = 72.6% done in 24.0s, 9.1s to go
# on time step 145268 (time=1452.68), 0.0001645 s/step
# Meep progress: 1692.51/2000.0 = 84.6% done in 28.0s, 5.1s to go
# on time step 169365 (time=1693.65), 0.000165999 s/step
# Meep progress: 1933.3600000000001/2000.0 = 96.7% done in 32.0s, 1.1s to go
# on time step 193461 (time=1934.61), 0.000166004 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaa    ] 16%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000125885 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000929117 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 235.77/2000.0 = 11.8% done in 4.0s, 29.9s to go
# on time step 23620 (time=236.2), 0.00016935 s/step
# Meep progress: 467.18/2000.0 = 23.4% done in 8.0s, 26.2s to go
# on time step 46789 (time=467.89), 0.000172646 s/step
# Meep progress: 708.76/2000.0 = 35.4% done in 12.0s, 21.9s to go
# on time step 70978 (time=709.78), 0.000165365 s/step
# Meep progress: 947.01/2000.0 = 47.4% done in 16.0s, 17.8s to go
# on time step 94809 (time=948.09), 0.000167849 s/step
# Meep progress: 1187.67/2000.0 = 59.4% done in 20.0s, 13.7s to go
# on time step 118881 (time=1188.81), 0.000166173 s/step
# Meep progress: 1426.98/2000.0 = 71.3% done in 24.0s, 9.6s to go
# on time step 142814 (time=1428.14), 0.000167134 s/step
# Meep progress: 1664.49/2000.0 = 83.2% done in 28.0s, 5.6s to go
# on time step 166573 (time=1665.73), 0.000168361 s/step
# Meep progress: 1901.31/2000.0 = 95.1% done in 32.0s, 1.7s to go
# on time step 190262 (time=1902.62), 0.00016886 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaa   ] 17%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00011301 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000941038 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 237.19/2000.0 = 11.9% done in 4.0s, 29.7s to go
# on time step 23731 (time=237.31), 0.000168556 s/step
# Meep progress: 477.90000000000003/2000.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 47809 (time=478.09), 0.00016613 s/step
# Meep progress: 718.54/2000.0 = 35.9% done in 12.0s, 21.4s to go
# on time step 71880 (time=718.8), 0.000166181 s/step
# Meep progress: 958.97/2000.0 = 47.9% done in 16.0s, 17.4s to go
# on time step 95927 (time=959.27), 0.00016635 s/step
# Meep progress: 1199.29/2000.0 = 60.0% done in 20.0s, 13.4s to go
# on time step 119965 (time=1199.65), 0.000166409 s/step
# Meep progress: 1436.38/2000.0 = 71.8% done in 24.0s, 9.4s to go
# on time step 143680 (time=1436.8), 0.000168672 s/step
# Meep progress: 1677.99/2000.0 = 83.9% done in 28.0s, 5.4s to go
# on time step 167849 (time=1678.49), 0.000165502 s/step
# Meep progress: 1918.02/2000.0 = 95.9% done in 32.0s, 1.4s to go
# on time step 191860 (time=1918.6), 0.000166593 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaa  ] 18%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000111103 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
# ...
# Initializing structure...
# time for choose_chunkdivision = 0.000108004 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000930071 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 242.4/2000.0 = 12.1% done in 4.0s, 29.0s to go
# on time step 24284 (time=242.84), 0.000164724 s/step
# Meep progress: 483.85/2000.0 = 24.2% done in 8.0s, 25.1s to go
# on time step 48439 (time=484.39), 0.000165599 s/step
# Meep progress: 726.47/2000.0 = 36.3% done in 12.0s, 21.0s to go
# on time step 72708 (time=727.08), 0.000164825 s/step
# Meep progress: 967.19/2000.0 = 48.4% done in 16.0s, 17.1s to go
# on time step 96785 (time=967.85), 0.000166137 s/step
# Meep progress: 1209.06/2000.0 = 60.5% done in 20.0s, 13.1s to go
# on time step 120981 (time=1209.81), 0.000165318 s/step
# Meep progress: 1450.8700000000001/2000.0 = 72.5% done in 24.0s, 9.1s to go
# on time step 145166 (time=1451.66), 0.000165397 s/step
# Meep progress: 1693.0900000000001/2000.0 = 84.7% done in 28.0s, 5.1s to go
# on time step 169398 (time=1693.98), 0.000165072 s/step
# Meep progress: 1934.83/2000.0 = 96.7% done in 32.0s, 1.1s to go
# on time step 193575 (time=1935.75), 0.000165451 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 95%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.00010705 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00183511 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 240.59/2000.0 = 12.0% done in 4.0s, 29.3s to go
# on time step 24141 (time=241.41), 0.000165693 s/step
# Meep progress: 482.62/2000.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 48355 (time=483.55), 0.000165199 s/step
# Meep progress: 722.73/2000.0 = 36.1% done in 12.0s, 21.2s to go
# on time step 72394 (time=723.94), 0.000166403 s/step
# Meep progress: 965.57/2000.0 = 48.3% done in 16.0s, 17.1s to go
# on time step 96684 (time=966.84), 0.000164682 s/step
# Meep progress: 1207.4/2000.0 = 60.4% done in 20.0s, 13.1s to go
# on time step 120882 (time=1208.82), 0.000165306 s/step
# Meep progress: 1437.75/2000.0 = 71.9% done in 24.0s, 9.4s to go
# on time step 143925 (time=1439.25), 0.000173589 s/step
# Meep progress: 1671.67/2000.0 = 83.6% done in 28.0s, 5.5s to go
# on time step 167320 (time=1673.2), 0.000170978 s/step
# Meep progress: 1914.75/2000.0 = 95.7% done in 32.0s, 1.4s to go
# on time step 191640 (time=1916.4), 0.000164478 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 96%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000117064 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.00116587 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 237.68/2000.0 = 11.9% done in 4.0s, 29.7s to go
# on time step 23808 (time=238.08), 0.000168015 s/step
# Meep progress: 480.44/2000.0 = 24.0% done in 8.0s, 25.3s to go
# on time step 48094 (time=480.94), 0.000164706 s/step
# Meep progress: 724.01/2000.0 = 36.2% done in 12.0s, 21.1s to go
# on time step 72459 (time=724.59), 0.000164171 s/step
# Meep progress: 965.82/2000.0 = 48.3% done in 16.0s, 17.1s to go
# on time step 96645 (time=966.45), 0.000165386 s/step
# Meep progress: 1209.18/2000.0 = 60.5% done in 20.0s, 13.1s to go
# on time step 120985 (time=1209.85), 0.00016434 s/step
# Meep progress: 1450.1000000000001/2000.0 = 72.5% done in 24.0s, 9.1s to go
# on time step 145084 (time=1450.84), 0.000165983 s/step
# Meep progress: 1692.58/2000.0 = 84.6% done in 28.0s, 5.1s to go
# on time step 169303 (time=1693.03), 0.000165162 s/step
# Meep progress: 1935.15/2000.0 = 96.8% done in 32.0s, 1.1s to go
# on time step 193607 (time=1936.07), 0.000164586 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 97%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000109196 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000931978 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.98000000000002/2000.0 = 12.0% done in 4.0s, 29.3s to go
# on time step 24049 (time=240.49), 0.000166331 s/step
# Meep progress: 478.47/2000.0 = 23.9% done in 8.0s, 25.4s to go
# on time step 47911 (time=479.11), 0.000167636 s/step
# Meep progress: 720.08/2000.0 = 36.0% done in 12.0s, 21.3s to go
# on time step 72080 (time=720.8), 0.000165505 s/step
# Meep progress: 962.16/2000.0 = 48.1% done in 16.0s, 17.3s to go
# on time step 96295 (time=962.95), 0.000165192 s/step
# Meep progress: 1203.27/2000.0 = 60.2% done in 20.0s, 13.2s to go
# on time step 120418 (time=1204.18), 0.00016582 s/step
# Meep progress: 1434.53/2000.0 = 71.7% done in 24.0s, 9.5s to go
# on time step 143546 (time=1435.46), 0.000172951 s/step
# Meep progress: 1675.97/2000.0 = 83.8% done in 28.0s, 5.4s to go
# on time step 167700 (time=1677), 0.00016561 s/step
# Meep progress: 1916.92/2000.0 = 95.8% done in 32.0s, 1.4s to go
# on time step 191799 (time=1917.99), 0.000165983 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 98%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000106096 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000929117 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 241.96/2000.0 = 12.1% done in 4.0s, 29.1s to go
# on time step 24239 (time=242.39), 0.000165023 s/step
# Meep progress: 483.92/2000.0 = 24.2% done in 8.0s, 25.1s to go
# on time step 48463 (time=484.63), 0.000165131 s/step
# Meep progress: 725.17/2000.0 = 36.3% done in 12.0s, 21.1s to go
# on time step 72595 (time=725.95), 0.000165756 s/step
# Meep progress: 953.57/2000.0 = 47.7% done in 16.0s, 17.6s to go
# on time step 95446 (time=954.46), 0.000175054 s/step
# Meep progress: 1193.3700000000001/2000.0 = 59.7% done in 20.0s, 13.5s to go
# on time step 119445 (time=1194.45), 0.000166677 s/step
# Meep progress: 1433.65/2000.0 = 71.7% done in 24.0s, 9.5s to go
# on time step 143491 (time=1434.91), 0.000166348 s/step
# Meep progress: 1675.0/2000.0 = 83.8% done in 28.0s, 5.4s to go
# on time step 167638 (time=1676.38), 0.000165657 s/step
# Meep progress: 1916.0/2000.0 = 95.8% done in 32.0s, 1.4s to go
# on time step 191741 (time=1917.41), 0.00016596 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 99%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000119925 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 7 with resolution 100
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-1.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-0.6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-0.1)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,0.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,0.9)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,1.4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,2)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
# time for set_epsilon = 0.000928879 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=2000.0)
# Meep progress: 239.45000000000002/2000.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 23990 (time=239.9), 0.000166738 s/step
# Meep progress: 481.3/2000.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 48187 (time=481.87), 0.000165312 s/step
# Meep progress: 723.64/2000.0 = 36.2% done in 12.0s, 21.2s to go
# on time step 72444 (time=724.44), 0.000164902 s/step
# Meep progress: 966.9200000000001/2000.0 = 48.3% done in 16.0s, 17.1s to go
# on time step 96780 (time=967.8), 0.000164369 s/step
# Meep progress: 1207.8/2000.0 = 60.4% done in 20.0s, 13.1s to go
# on time step 120880 (time=1208.8), 0.000165981 s/step
# Meep progress: 1450.38/2000.0 = 72.5% done in 24.0s, 9.1s to go
# on time step 145155 (time=1451.55), 0.000164784 s/step
# Meep progress: 1693.55/2000.0 = 84.7% done in 28.0s, 5.1s to go
# on time step 169499 (time=1694.99), 0.000164316 s/step
# Meep progress: 1937.1200000000001/2000.0 = 96.9% done in 32.0s, 1.0s to go
# on time step 193864 (time=1938.64), 0.000164177 s/step
# run 0 finished at t = 2000.0 (200000 timesteps)

# %%
freqs = np.linspace(3e14,9e14,1000)
plt.plot(freqs,Efavg*tsim*eps0*4*np.pi*3/M,'g''.')
#plt.xlim(4e15,20e15)
#plt.yscale("log")
#plt.ylim(0.1e-28,400e-28)
plt.grid()
plt.savefig('3AB100.png')
plt.show()

np.savez("3AB100.npz", Efavg_30000 = Efavg)
