# %%
import numpy as np
Nf = 1000
fmin = 0.5 # 1/micron => 150 THz
fmax = 1.5 # 1/micron => 450 THz
fre = np.linspace(fmin, fmax, Nf)
d1 = 0.2 # thickness in micron
d2 = 0.8 # thickness in micron
d = d1 + d2
epsi1 = 2
epsi2 = 13
omega = 2 * np.pi * fre

# %%
import meep as mp

resolution = 100                # pixels/um
dpml = 1.0                      # PML thickness
sz = 16 + 2*dpml
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]

fcen = (fmin+fmax)/2          # center frequency
df = (fmax-fmin)                  # frequency width
dimensions = 1

# %%
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df), component=mp.Ex, 
                     center=mp.Vector3(z=-8))]

# %%
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        #Courant = 0.1,
                        resolution=resolution)
sim_vac.reset_meep()

refl_fr = mp.FluxRegion(center=mp.Vector3(z=-8))
refl = sim_vac.add_flux(fcen, df, Nf, refl_fr)
tran_fr = mp.FluxRegion(center=mp.Vector3(z= 8 ))
tran = sim_vac.add_flux(fcen, df, Nf, tran_fr)
   
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex,
                                                        mp.Vector3(z=0), 1e-3))

empty_flux = mp.get_fluxes(tran)
empty_data = sim_vac.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000180006 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
# time for set_epsilon = 0.00334287 s
# -----------
# field decay(t = 50.005): 0.2502233161583911 / 0.2502233161583911 = 1.0
# field decay(t = 100.01): 9.664963505198853e-16 / 0.2502233161583911 = 3.862535136046611e-15
# run 0 finished at t = 100.01 (20002 timesteps)

# %%
# add a block with n=3.5 for the air-dielectric interface
geometry = []
Np = 10 ## number of repeating
for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d1), center=mp.Vector3(z = -6 + d * i),
                     material= mp.Medium(epsilon=epsi1)))
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d2), center=mp.Vector3(z = -6 + d * i + d /2),
                     material= mp.Medium(epsilon=epsi2))) 
    
sim = mp.Simulation(cell_size=cell_size,
                        geometry=geometry,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
tran = sim.add_flux(fcen, df, Nf, tran_fr)
refl = sim.add_flux(fcen, df, Nf, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(z=0), 1e-4))
#sim.run(until=10000)
refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
freqs = mp.get_flux_freqs(refl)

R = np.empty(Nf)
T = np.empty(Nf)
for i in range(Nf):
        R[i] = -refl_flux[i]/empty_flux[i]
        T[i] = tran_flux[i]/empty_flux[i]
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000185966 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
#      block, center = (0,0,-6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-5.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-5)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-4.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-3.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-3)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-2.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2,2,2)
#      block, center = (0,0,-1.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (13,13,13)
#      ...(+ 10 objects not shown)...
# time for set_epsilon = 0.004107 s
# -----------
# field decay(t = 50.005): 0.038430047350483644 / 0.038430047350483644 = 1.0
# field decay(t = 100.01): 0.004076213512267005 / 0.038430047350483644 = 0.10606839682219923
# field decay(t = 150.01500000000001): 0.0018262999471810298 / 0.038430047350483644 = 0.04752270874207096
# field decay(t = 200.02): 0.00036000462995477295 / 0.038430047350483644 = 0.00936779043417552
# field decay(t = 250.025): 0.00048797582005038017 / 0.038430047350483644 = 0.012697767858572231
# field decay(t = 300.03000000000003): 0.00042553543145309065 / 0.038430047350483644 = 0.0110729874353833
# field decay(t = 350.035): 0.0002513058268769976 / 0.038430047350483644 = 0.006539305678837133
# field decay(t = 400.04): 0.0002011647623373595 / 0.038430047350483644 = 0.005234569723600089
# field decay(t = 450.045): 0.0001512044310420218 / 0.038430047350483644 = 0.003934536683315298
# field decay(t = 500.05): 0.00011210048070728718 / 0.038430047350483644 = 0.0029170008479283437
# field decay(t = 550.0550000000001): 6.492795530598389e-05 / 0.038430047350483644 = 0.001689510156306554
# field decay(t = 600.0600000000001): 5.87211742976574e-05 / 0.038430047350483644 = 0.001528001611918867
# field decay(t = 650.065): 4.786864132007295e-05 / 0.038430047350483644 = 0.0012456045365624698
# field decay(t = 700.07): 3.2335697461755784e-05 / 0.038430047350483644 = 0.000841417060115822
# field decay(t = 750.075): 3.179133790022289e-05 / 0.038430047350483644 = 0.0008272521136985484
# on time step 155407 (time=777.035), 2.5739e-05 s/step
# field decay(t = 800.08): 2.5546770565481207e-05 / 0.038430047350483644 = 0.0006647603197699339
# field decay(t = 850.085): 1.411823330519762e-05 / 0.038430047350483644 = 0.00036737486104138095
# field decay(t = 900.09): 8.595666099830143e-06 / 0.038430047350483644 = 0.00022367045300353933
# field decay(t = 950.095): 5.732138714874641e-06 / 0.038430047350483644 = 0.00014915773229726457
# field decay(t = 1000.1): 6.470688068661242e-06 / 0.038430047350483644 = 0.00016837575061118962
# field decay(t = 1050.105): 6.384045633618663e-06 / 0.038430047350483644 = 0.00016612120134528845
# field decay(t = 1100.1100000000001): 4.547599881292926e-06 / 0.038430047350483644 = 0.00011833448550866004
# field decay(t = 1150.115): 2.360244851910083e-06 / 0.038430047350483644 = 6.141665219364814e-05
# run 0 finished at t = 1150.115 (230023 timesteps)

# %%
## compare numerical and analytical
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(fre*3e14,T,'-',label='$T_{nur}$')
plt.xlabel("fre")
plt.ylabel("$T$")
#plt.legend(loc="upper right")
#plt.xlim([fmin,fmax])
plt.ylim([0,1])
plt.savefig('10AB.png')
plt.show()
# Out:
# /home/311514089/anaconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/311514089/anaconda3/envs/mp/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
